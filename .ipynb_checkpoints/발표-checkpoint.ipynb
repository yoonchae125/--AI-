# %% [markdown]
# ## 필요한 Library import

# %%
import requests 
from bs4 import BeautifulSoup

import pandas as pd
from datetime import datetime
import time
import re

# %% [markdown]
# ## 네이버 뉴스에서 '부동산 대책 검사' 해 5페이지까지 기사 URL 수집

# %%
query = '부동산+대책'
url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query='+query 

urls_list = [] #기사 url 담을 list
for i in range(4): #0~4=> 5페이지까지
    url=url+"&start="+str(i*10+1) 

    web = requests.get(url).content
    source = BeautifulSoup(web, 'html.parser')

    for urls in source.find_all('a', {'class' : "_sp_each_url"}):
        if urls["href"].startswith("https://news.naver.com"): # 네이버 기사만 담기
            urls_list.append(urls["href"])

# %% [markdown]
# ## Selenium 과 BeautifulSoup <mark>이용한 기사의 댓글 수집</mark>

# %%
from selenium import webdriver

from bs4 import BeautifulSoup

import time


driver = webdriver.Chrome('./chromedriver') 
comments=[] #댓글들 담을 list
for url in urls_list:
    try:
        print(url+' 크롤링중')
        driver.get(url+'&m_view=1&includeAllCount=true') #댓글 페이지
        time.sleep(3) #댓글 불러오는 거 기다리기

        try:
            for i in range(0, 2) : #댓글 더보기 2페이지만
                driver.find_element_by_css_selector(".u_cbox_btn_more").click() #댓글 더보기 클릭
                time.sleep(3)
                i +=1



            html = driver.page_source

            bs = BeautifulSoup(html, 'html.parser')
        
            contents = bs.find_all("span", {"class" : "u_cbox_contents"}) #댓글 담긴 span tag 찾기
            for content in contents :
                comments.append(content.text)

        except: 
            print("댓글 2페이지까지 없어")
    except:
        print("없는 url")

print(comments)
# Out:
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=055&aid=0000779436 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004344799 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=215&aid=0000832238 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=025&aid=0002961267 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=023&aid=0003494200 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0011283042 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=214&aid=0001001360 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=056&aid=0010774336 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=028&aid=0002478636 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=047&aid=0002250186 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004344765 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=022&aid=0003423082 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=119&aid=0002371325 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=029&aid=0002575224 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=079&aid=0003302895 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=055&aid=0000779436 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004344799 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=215&aid=0000832238 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=025&aid=0002961267 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=023&aid=0003494200 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0011283042 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=214&aid=0001001360 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=056&aid=0010774336 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=028&aid=0002478636 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=047&aid=0002250186 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004344765 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=022&aid=0003423082 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=119&aid=0002371325 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=029&aid=0002575224 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=079&aid=0003302895 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=055&aid=0000779436 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004344799 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=215&aid=0000832238 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=025&aid=0002961267 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=023&aid=0003494200 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0011283042 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=214&aid=0001001360 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=056&aid=0010774336 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=028&aid=0002478636 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=047&aid=0002250186 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004344765 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=022&aid=0003423082 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=119&aid=0002371325 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=029&aid=0002575224 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=079&aid=0003302895 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=055&aid=0000779436 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004344799 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=215&aid=0000832238 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=025&aid=0002961267 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=023&aid=0003494200 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0011283042 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=214&aid=0001001360 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=056&aid=0010774336 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=028&aid=0002478636 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=047&aid=0002250186 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004344765 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=022&aid=0003423082 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=119&aid=0002371325 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=029&aid=0002575224 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=079&aid=0003302895 크롤링중
# 댓글 2페이지까지 없어
# ['서울시상 급여는 최저임수준으로 낮추어야합니다.박원순시장 말고도  잘 할사람 많습니다.', '10년 가까운 세월동안 서울시 경쟁력 망가트린 못난이 그런대도 시장 노릇을 하고 있으니 이게 서울의 민도인가... 하기사 지방선거 대부분이 북풍 영향 받아 싹쓸이 좌파세상으로 변했지. 아들이나 찾아라 이것아.. 뭔 애비가 자식 어디 있는지 모른다 시침이를 떼는것인지. 사회주의화 되는 서울시를 더는 못 보것다', '김현미장관과 비슷하게 시장을 잘못 파악하고 있구먼... 그런 식견으로 무슨 대권을 넘보시나? 시골내려가셔서 이장님 하시면 딱인데...', '왜 차라리 몰수해서 정은이에게 바치지', '시민의 혈세를 물쓰듯 펑펑 쓰는 박원순 시장은 퇴진하라.', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
의 망말을 듣고 있자니 분노가 치밀어올라 미칠지경이네요 니때매 자한당 찍을 명분이 주변에서 생기더라 ㅋㅋ 부동산 개폭등 책임은 물론, 문재인과 김현미가 제일 크지만 박원순도 그 다음 다음 수준으로 적지 않다. 제3자처럼 말하는게 토나온다. . . 세금걷어 이북에 투자하려고? 집 가지고 있는 게 죄인가? 세금을 3배 인상한다는 ...

# %%
# comments_str 저장
save=open("comments.txt", 'w' , encoding='utf-8' )
save.write(comments_str)
save.close()

# %%
# comments_str 불러오기
with open('comments.txt', 'r', encoding= 'utf-8') as f: 
    doc = ''  # 리뷰 데이터를 담기 위한 String 변수 생성
    lines = f.readlines()  # 영화 리뷰 파일의 모든 라인을 읽어와 리스트로 저장
    for line in lines:  # for문을 통해 lines에 있는 모든 텍스트를 doc2에 이어 붙임
        doc += line

# %%
doc
# Out:
# '서울시상 급여는 최저임수준으로 낮추어야합니다.박원순시장 말고도  잘 할사람 많습니다. 10년 가까운 세월동안 서울시 경쟁력 망가트린 못난이 그런대도 시장 노릇을 하고 있으니 이게 서울의 민도인가... 하기사 지방선거 대부분이 북풍 영향 받아 싹쓸이 좌파세상으로 변했지. 아들이나 찾아라 이것아.. 뭔 애비가 자식 어디 있는지 모른다 시침이를 떼는것인지. 사회주의화 되는 서울시를 더는 못 보것다 김현미장관과 비슷하게 시장을 잘못 파악하고 있구먼... 그런 식견으로 무슨 대권을 넘보시나? 시골내려가셔서 이장님 하시면 딱인데... 왜 차라리 몰수해서 정은이에게 바치지 시민의 혈세를 물쓰듯 펑펑 쓰는 박원순 시장은 퇴진하라. ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ지는 재산 다 돌려놓고 마이너스라고 저지랄하네 재산이 마이너스인데 어찌 그리 고급품만 갖고 사냐?그리고 아들새끼 유학은 어떻게 보냈냐? 아직도 아들 못찾았어? 니 아들 어딨냐고?? 군면제 받으려고 남의 엑스레이 제출한 니 아들 었다 빼돌렸는데??? 끌고와.당장! 너같은위선적인종자 새키가뮌소릴못하냐  그세금걷어서  너처럼세금을  물쓰듯이 하는놈은 후에 그댓가을 톡톡히받아야한다 시장님! 시장님에 의하여 서울에 재건축 재개발 아파트를 35층으로 규제하여 (깍두기 아파트 규제) 부동산 가격 폭등을 만드는데 일조했습니다. 공정하고 공평한 세금인상도 필요하지만 규제를 파기히여 고층을 건설 공급량 증가도 검토대상입니다. 종부세 3배. 완전 ㅁㅊ네. 그럼 처음부터 아파트 가격을 잘 조정하지. 왜 뒷북치지. ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 사회주의가 정권을 잡으면 하향평준화로 고만고만해진다이게 좋나 기회만 공정하면되지 왜 결과가 공정해야하지 북한인가 북한이 좋으면 제발그리로 가라 좌파놈들 세금 뜯어내서 국민은 가난하게 만들은 ㄱ지들이 펑펑 쓰며 해처먹는 거 다 안다. 경제효과는? 나라 점점 더 가난해짐. 박원순이 지난 12년간 서울에 뭔 짓을 했는지 서울은 점점 퇴보하는데 집값만 폭등함 기생충들만 살찌고 국민은 점점가난해 지는 아이러니 지 책임은 또 하나도 없음??? 민주당인사들은 말만 번지르르하고 서민들 위하는척하지만 하는거보면  한국당놈들보다 더 교활하
site-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# /Users/chaeyoon/opt/anaconda3/lib/python3.7/site-packages/jpype/_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)
# [('서울시', 'Noun'),
#  ('상', 'Suffix'),
#  ('급여', 'Noun'),
#  ('는', 'Josa'),
#  ('최저', 'Noun'),
#  ('임', 'Noun'),
#  ('수준', 'Noun'),
#  ('으로', 'Josa'),
#  ('낮추다', 'Verb'),
#  ('야하다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('박원순', 'Noun'),
#  ('시장', 'Noun'),
#  ('말고도', 'Josa'),
#  ('자다', 'Verb'),
#  ('하다', 'Verb'),
#  ('사람', 'Noun'),
#  ('많다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('10년', 'Number'),
#  ('가깝다', 'Adjective'),
#  ('세월', 'Noun'),
#  ('동안', 'Noun'),
#  ('서울시', 'Noun'),
#  ('경쟁력', 'Noun'),
#  ('망', 'Noun'),
#  ('가트', 'Noun'),
#  ('린', 'Noun'),
#  ('못난이', 'Noun'),
#  ('그런', 'Modifier'),
#  ('대도', 'Noun'),
#  ('시장', 'Noun'),
#  ('노릇', 'Noun'),
#  ('을', 'Josa'),
#  ('하다', 'Verb'),
#  ('있다', 'Adjective'),
#  ('이', 'Noun'),
#  ('게', 'Josa'),
#  ('서울', 'Noun'),
#  ('의', 'Josa'),
#  ('민', 'Noun'),
#  ('도인', 'Noun'),
#  ('가', 'Josa'),
#  ('...', 'Punctuation'),
#  ('하다', 'Verb'),
#  ('지방선거', 'Noun'),
#  ('대부분', 'Noun'),
#  ('이', 'Josa'),
#  ('북풍', 'Noun'),
#  ('영향', 'Noun'),
#  ('받다', 'Verb'),
#  ('싹', 'Noun'),
#  ('쓸다', 'Verb'),
#  ('좌파', 'Noun'),
#  ('세상', 'Noun'),
#  ('으로', 'Josa'),
#  ('변하다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('아들', 'Noun'),
#  ('이나', 'Josa'),
#  ('찾다', 'Verb'),
#  ('이', 'Determiner'),
#  ('것', 'Noun'),
#  ('아', 'Josa'),
#  ('..', 'Punctuation'),
#  ('뭔', 'Modifier'),
#  ('애비', 'Noun'),
#  ('가', 'Josa'),
#  ('자식', 'Noun'),
#  ('어디', 'Noun'),
#  ('있다', 'Adjective'),
#  ('모르다', 'Verb'),
#  ('시침', 'Noun'),
#  ('이를', 'Josa'),
#  ('떼다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('사회주의', 'Noun'),
#  ('화', 'Suffix'),
#  ('되다', 'Verb'),
#  ('서울시', 'Noun'),
#  ('를', 'Josa'),
#  ('더', 'Noun'),
#  ('는', 'Josa'),
#  ('못', 'Noun'),
#  ('보다', 'Verb'),
#  ('김현미', 'Noun'),
#  ('장관', 'Noun'),
#  ('과', 'Josa'),
#  ('비슷하다', 'Adjective'),
#  ('시장', 'Noun'),
#  ('을', 'Josa'),
#  ('잘못', 'Noun'),
#  ('파악', 'Noun'),
#  ('하고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('...', 'Punctuation'),
#  ('그렇다', 'Adjective'),
#  ('식견', 'Noun'),
#  ('으로', 'Josa'),
#  ('무슨', 'Noun'),
#  ('대권', 'Noun'),
#  ('을', 'Josa'),
#  ('넘다', 'Verb'),
#  ('보시', 'Noun'),
#  ('나', 'Josa'),
#  ('?', 'Punctuation'),
#  ('시골', 'Noun'),
#  ('내려가다', 'Verb'),
#  ('이장님', 'Noun'),
#  ('하다', 'Verb'),
#  ('딱이다', 'Adjective'),
#  ('...', 'Punctuation'),
#  ('왜', 'Noun'),
#  ('차라리', 'Noun'),
#  ('몰수', 'Noun'),
#  ('하다', 'Verb'),
#  ('정은', 'Noun'),
#  ('이', 'Suffix'),
#  ('에게', 'Josa'),
#  ('바치', 'Noun'),
#  ('지', 'Josa'),
#  ('시민', 'Noun'),
#  ('의', 'Josa'),
#  ('혈세', 'Noun'),
#  ('를', 'Josa'),
#  ('물', 'Noun'),
#  ('쓰다', 'Verb'),
#  ('펑펑', 'Noun'),
#  ('쓰다', 'Verb'),
#  ('박원순', 'Noun'),
#  ('시장', 'Noun'),
#  ('은', 'Josa'),
#  ('퇴진', 'Noun'),
#  ('하', 'Suffix'),
#  ('라', 'Josa'),
#  ('.', 'Punctuation'),
#  ('ㅋㅋㅋ', 'KoreanParticle'),
#  ('지다', 'Verb'),
#  ('재산', 'Noun'),
#  ('다', 'Adverb'),
#  ('돌리다', 'Verb'),
#  ('마이너스', 'Noun'),
#  ('라고', 'Josa'),
#  ('저', 'Determiner'),
#  ('지랄', 'Noun'),
#  ('하', 'Suffix'),
#  ('네', 'Josa'),
#  ('재산', 'Noun'),
#  ('이', 'Josa'),
#  ('마이너스', 'Noun'),
#  ('인데', 'Josa'),
#  ('어찌', 'Noun'),
#  ('그리다', 'Verb'),
#  ('고급', 'Noun'),
#  ('품', 'Noun'),
#  ('만', 'Josa'),
#  ('갖다', 'Verb'),
#  ('사다', 'Verb'),
#  ('?', 'Punctuation'),
#  ('그리고', 'Conjunction'),
#  ('아들', 'Noun'),
#  ('새끼', 'Noun'),
#  ('유학', 'Noun'),
#  ('은', 'Josa'),
#  ('어떻다', 'Adjective'),
#  ('보내다', 'Verb'),
#  ('?', 'Punctuation'),
#  ('아직도', 'Adverb'),
#  ('아들', 'Noun'),
#  ('못', 'VerbPrefix'),
#  ('찾다', 'Verb'),
#  ('?', 'Punctuation'),
#  ('니', 'Noun'),
#  ('아들', 'Noun'),
#  ('어딨다', 'Verb'),
#  ('??', 'Punctuation'),
#  ('군', 'Noun'),
#  ('면제', 'Noun'),
#  ('받다', 'Verb'),
#  ('남', 'Noun'),
#  ('의', 'Josa'),
#  ('엑스레이', 'Noun'),
#  ('제출', 'Noun'),
#  ('한', 'Josa'),
#  ('니', 'Noun'),
#  ('아들', 'Noun'),
#  ('었다', 'Noun'),
#  ('빼', 'Noun'),
#  ('돌리다', 'Verb'),
#  ('???', 'Punctuation'),
#  ('끄다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('당장', 'Noun'),
#  ('!', 'Punctuation'),
#  ('너', 'Noun'),
#  ('같다', 'Adjective'),
#  ('위선', 'Noun'),
#  ('적', 'Suffix'),
#  ('인종', 'Noun'),
#  ('자', 'Suffix'),
#  ('새', 'Modifier'),
#  ('키', 'Noun'),
#  ('가', 'Josa'),
#  ('뮌소릴', 'Noun'),
#  ('못', 'VerbPrefix'),
#  ('하다', 'Verb'),
#  ('그', 'Determiner'),
#  ('세금', 'Noun'),
#  ('걷다', 'Verb'),
#  ('너', 'Modifier'),
#  ('처럼', 'Noun'),
#  ('세금', 'Noun'),
#  ('을', 'Josa'),
#  ('물', 'Noun'),
#  ('쓰다', 'Verb'),
#  ('하다', 'Verb'),
#  ('놈', 'Noun'),
#  ('은', 'Josa'),
#  ('후', 'Noun'),
#  ('에', 'Josa'),
#  ('그대', 'Noun'),
#  ('가을', 'Noun'),
#  ('톡톡하다', 'Adjective'),
#  ('받다', 'Verb'),
#  ('야하다', 'Adjective'),
#  ('시장님', 'Noun'),
#  ('!', 'Punctuation'),
#  ('시장님', 'Noun'),
#  ('에', 'Josa'),
#  ('의하다', 'Adjective'),
#  ('서울', 'Noun'),
#  ('에', 'Josa'),
#  ('재건축', 'Noun'),
#  ('재개발', 'Noun'),
#  ('아파트', 'Noun'),
#  ('를', 'Josa'),
#  ('35', 'Number'),
#  ('층', 'Noun'),
#  ('으로', 'Josa'),
#  ('규제', 'Noun'),
#  ('하다', 'Verb'),
#  ('(', 'Punctuation'),
#  ('깍두기', 'Noun'),
#  ('아파트', 'Noun'),
#  ('규제', 'Noun'),
#  (')', 'Punctuation'),
#  ('부동산', 'Noun'),
#  ('가격', 'Noun'),
#  ('폭등', 'Noun'),
#  ('을', 'Josa'),
#  ('만들다', 'Verb'),
#  ('일조', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('공정하다', 'Adjective'),
#  ('공평하다', 'Adjective'),
#  ('세금', 'Noun'),
#  ('인상', 'Noun'),
#  ('도', 'Josa'),
#  ('필요하다', 'Adjective'),
#  ('규제', 'Noun'),
#  ('를', 'Josa'),
#  ('파다', 'Verb'),
#  ('고층', 'Noun'),
#  ('을', 'Josa'),
#  ('건설', 'Noun'),
#  ('공', 'Modifier'),
#  ('급량', 'Noun'),
#  ('증가', 'Noun'),
#  ('도', 'Josa'),
#  ('검토', 'Noun'),
#  ('대상', 'Noun'),
#  ('이다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('종부세', 'Noun'),
#  ('3', 'Number'),
#  ('배', 'Noun'),
#  ('.', 'Punctuation'),
#  ('완전', 'Noun'),
#  ('ㅁㅊ', 'KoreanParticle'),
#  ('네', 'Noun'),
#  ('.', 'Punctuation'),
#  ('그렇다', 'Adjective'),
#  ('처음', 'Noun'),
#  ('부터', 'Josa'),
#  ('아파트', 'Noun'),
#  ('가격', 'Noun'),
#  ('을', 'Josa'),
#  ('자다', 'Verb'),
#  ('조정', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('왜', 'Noun'),
#  ('뒷북', 'Noun'),
#  ('치', 'Noun'),
#  ('지', 'Josa'),
#  ('.', 'Punctuation'),
#  ('ㅋㅋㅋ', 'KoreanParticle'),
#  ('사회주의', 'Noun'),
#  ('가', 'Josa'),
#  ('정권', 'Noun'),
#  ('을', 'Josa'),
#  ('잡다', 'Verb'),
#  ('하향', 'Noun'),
#  ('평준화', 'Noun'),
#  ('로', 'Josa'),
#  ('고만고만하다', 'Adjective'),
#  ('좋다', 'Adjective'),
#  ('기회', 'Noun'),
#  ('만', 'Josa'),
#  ('공정하다', 'Adjective'),
#  ('지다', 'Verb'),
#  ('왜', 'Noun'),
#  ('결과', 'Noun'),
#  ('가', 'Josa'),
#  ('공정하다', 'Adjective'),
#  ('북한', 'Noun'),
#  ('인가', 'Josa'),
#  ('북한', 'Noun'),
#  ('이', 'Josa'),
#  ('좋다', 'Adjective'),
#  ('제발', 'Noun'),
#  ('그리로', 'Adverb'),
#  ('가라', 'Noun'),
#  ('좌파', 'Noun'),
#  ('놈', 'Noun'),
#  ('들', 'Suffix'),
#  ('세금', 'Noun'),
#  ('뜯다', 'Verb'),
#  ('국민', 'Noun'),
#  ('은', 'Josa'),
#  ('가난하다', 'Adjective'),
#  ('만들다', 'Verb'),
#  ('ㄱ', 'KoreanParticle'),
#  ('지다', 'Verb'),
#  ('들이다', 'Verb'),
#  ('펑펑', 'Noun'),
#  ('쓰다', 'Verb'),
#  ('해처', 'Noun'),
#  ('먹다', 'Verb'),
#  ('거', 'Noun'),
#  ('다', 'Adverb'),
#  ('안다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('경', 'Modifier'),
#  ('제', 'Modifier'),
#  ('효과', 'Noun'),
#  ('는', 'Josa'),
#  ('?', 'Punctuation'),
#  ('나라', 'Noun'),
#  ('점점', 'Noun'),
#  ('더', 'Noun'),
#  ('가난하다', 'Adjective'),
#  ('짐', 'Noun'),
#  ('.', 'Punctuation'),
#  ('박원순', 'Noun'),
#  ('이', 'Josa'),
#  ('지난', 'Noun'),
#  ('12년', 'Number'),
#  ('간', 'Foreign'),
#  ('서울', 'Noun'),
#  ('에', 'Josa'),
#  ('뭔', 'Modifier'),
#  ('짓', 'Noun'),
#  ('을', 'Josa'),
#  ('하다', 'Verb'),
#  ('서울', 'Noun'),
#  ('은', 'Josa'),
#  ('점점', 'Noun'),
#  ('퇴보하다', 'Adjective'),
#  ('집값', 'Noun'),
#  ('만', 'Josa'),
#  ('폭등', 'Noun'),
#  ('함', 'Noun'),
#  ('기생충', 'Noun'),
#  ('들', 'Suffix'),
#  ('만', 'Josa'),
#  ('살찌다', 'Adjective'),
#  ('국민', 'Noun'),
#  ('은', 'Josa'),
#  ('점점', 'Noun'),
#  ('가난하다', 'Adjective'),
#  ('지다', 'Verb'),
#  ('아이러니', 'Noun'),
#  ('지다', 'Verb'),
#  ('책임', 'Noun'),
#  ('은', 'Josa'),
#  ('또', 'Noun'),
#  ('하나', 'Noun'),
#  ('도', 'Josa'),
#  ('없다', 'Adjective'),
#  ('???', 'Punctuation'),
#  ('민주당', 'Noun'),
#  ('인사', 'Noun'),
#  ('들', 'Suffix'),
#  ('은', 'Josa'),
#  ('말', 'Noun'),
#  ('만', 'Josa'),
#  ('번지르르하다', 'Adjective'),
#  ('서민', 'Noun'),
#  ('들', 'Suffix'),
#  ('위', 'Noun'),
#  ('하다', 'Verb'),
#  ('척', 'Noun'),
#  ('하', 'Suffix'),
#  ('지만', 'Josa'),
#  ('하다', 'Verb'),
#  ('보다', 'Verb'),
#  ('한국', 'Noun'),
#  ('당', 'Modifier'),
#  ('놈', 'Noun'),
#  ('들', 'Suffix'),
#  ('보다', 'Josa'),
#  ('더', 'Noun'),
#  ('교활하다', 'Adjective'),
#  ('악랄하다', 'Adjective'),
#  ('.......', 'Punctuation'),
#  ('서울시', 'Noun'),
#  ('만', 'Josa'),
#  ('3', 'Number'),
#  ('배', 'Noun'),
#  ('올리다', 'Verb'),
#  ('!', 'Punctuation'),
#  ('박원숭', 'Noun'),
#  ('서울시장', 'Noun'),
#  ('님', 'Suffix'),
#  ('!', 'Punctuation'),
#  ('돈', 'Noun'),
#  ('걷다', 'Verb'),
#  ('김어준', 'Noun'),
#  ('씨', 'Suffix'),
#  ('한테', 'Josa'),
#  ('도', 'Noun'),
#  ('좀', 'Noun'),
#  ('띠', 'Noun'),
#  ('어', 'Suffix'),
#  ('주', 'Modifier'),
#  ('고요', 'Noun'),
#  ('ㅋ', 'KoreanParticle'),
#  ('밥맛', 'Noun'),
#  ('떨어지다', 'Verb'),
#  ('놈', 'Noun'),
#  ('...', 'Punctuation'),
#  ('면상', 'Noun'),
#  ('을', 'Josa'),
#  ('갈겨', 'Adverb'),
#  ('주다', 'Verb'),
#  ('보', 'Noun'),
#  ('유세', 'Noun'),
#  ('올리다', 'Verb'),
#  ('한다는', 'Modifier'),
#  ('말', 'Noun'),
#  ('에는', 'Josa'),
#  ('하다', 'Verb'),
#  ('표', 'Noun'),
#  ('...', 'Punctuation'),
#  ('서울시장', 'Noun'),
#  ('은', 'Josa'),
#  ('수고', 'Noun'),
#  ('가', 'Josa'),
#  ('많다', 'Adjective'),
#  ('남다', 'Verb'),
#  ('생', 'Noun'),
#  ('까지', 'Josa'),
#  ('국민', 'Noun'),
#  ('들', 'Suffix'),
#  ('이', 'Josa'),
#  ('책임지다', 'Verb'),
#  ('야하다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('감옥', 'Noun'),
#  ('소', 'Noun'),
#  ('에서', 'Josa'),
#  ('죽', 'Noun'),
#  ('을', 'Josa'),
#  ('때', 'Noun'),
#  ('까지', 'Josa'),
#  ('보호', 'Noun'),
#  ('해주다', 'Verb'),
#  ('야하다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('박원순', 'Noun'),
#  ('딱', 'Adverb'),
#  ('200만원', 'Number'),
#  ('만', 'Foreign'),
#  ('받다', 'Verb'),
#  ('그', 'Noun'),
#  ('이상', 'Noun'),
#  ('도', 'Josa'),
#  ('그이', 'Noun'),
#  ('하다', 'Verb'),
#  ('아니다', 'Adjective'),
#  ('딱', 'Adverb'),
#  ('북한', 'Noun'),
#  ('정은', 'Noun'),
#  ('이', 'Josa'),
#  ('수준', 'Noun'),
#  ('의', 'Josa'),
#  ('사고방식', 'Noun'),
#  ('.', 'Punctuation'),
#  ('박원순', 'Noun'),
#  ('너', 'Noun'),
#  ('는', 'Josa'),
#  ('이제', 'Noun'),
#  ('아웃', 'Noun'),
#  ('이다', 'Josa'),
#  ('이', 'Noun'),
#  ('게', 'Josa'),
#  ('돌다', 'Verb'),
#  ('?', 'Punctuation'),
#  ('총선', 'Noun'),
#  ('더불다', 'Verb'),
#  ('서', 'Modifier'),
#  ('울', 'Modifier'),
#  ('쪽', 'Noun'),
#  ('은', 'Josa'),
#  ('작살', 'Noun'),
#  ('날다', 'Verb'),
#  ('같다', 'Adjective'),
#  ('머리', 'Noun'),
#  ('까지', 'Josa'),
#  ('심다', 'Verb'),
#  ('먹고살다', 'Verb'),
#  ('만하', 'Noun'),
#  ('군', 'Suffix'),
#  ('ᆢ', 'Foreign'),
#  ('얼굴', 'Noun'),
#  ('만', 'Josa'),
#  ('보다', 'Verb'),
#  ('구역질', 'Noun'),
#  ('나다', 'Verb'),
#  ('ᆢ', 'Foreign'),
#  ('하여튼', 'Noun'),
#  (',', 'Punctuation'),
#  ('좌빨', 'Noun'),
#  ('들', 'Suffix'),
#  ('뽑다', 'Verb'),
#  ('혼란', 'Noun'),
#  ('의', 'Josa'),
#  ('정국', 'Noun'),
#  ('을', 'Josa'),
#  ('피', 'Noun'),
#  ('하다', 'Verb'),
#  ('수', 'Noun'),
#  ('없다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('국론', 'Noun'),
#  ('분열', 'Noun'),
#  ('.', 'Punctuation'),
#  ('경제', 'Noun'),
#  ('파탄', 'Noun'),
#  ('.', 'Punctuation'),
#  ('외교', 'Noun'),
#  ('무능', 'Noun'),
#  ('.', 'Punctuation'),
#  ('포', 'Noun'),
#  ('플', 'Exclamation'),
#  ('리즘', 'Noun'),
#  ('으로', 'Josa'),
#  ('인하다', 'Adjective'),
#  ('세금', 'Noun'),
#  ('인상', 'Noun'),
#  ('.....', 'Punctuation'),
#  ('사탕', 'Noun'),
#  ('녹이다', 'Verb'),
#  ('먹듯', 'Noun'),
#  ('나라', 'Noun'),
#  ('를', 'Josa'),
#  ('말', 'Noun'),
#  ('아', 'Josa'),
#  ('치다', 'Verb'),
#  ('먹다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('다', 'Adverb'),
#  ('주택', 'Noun'),
#  ('은', 'Josa'),
#  ('종부세', 'Noun'),
#  ('가중', 'Noun'),
#  ('부담', 'Noun'),
#  ('가즈', 'Noun'),
#  ('아', 'Josa'),
#  ('~~~', 'Punctuation'),
#  ('차다', 'Verb'),
#  ('현', 'Modifier'),
#  ('실감', 'Noun'),
#  ('없다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('그렇게', 'Adverb'),
#  ('말다', 'Verb'),
#  ('올리다', 'Verb'),
#  ('엇', 'VerbPrefix'),
#  ('따다', 'Verb'),
#  ('쓰개', 'Noun'),
#  ('?', 'Punctuation'),
#  ('퍼주개', 'Noun'),
#  ('?', 'Punctuation'),
#  ('니', 'Noun'),
#  ('꼴리다', 'Verb'),
#  ('쓰개', 'Noun'),
#  ('?', 'Punctuation'),
#  ('완전', 'Noun'),
#  ('사유재산', 'Noun'),
#  ('몰수', 'Noun'),
#  ('계획', 'Noun'),
#  ('?', 'Punctuation'),
#  ('누가', 'Noun'),
#  ('시키다', 'Verb'),
#  ('댕', 'Noun'),
#  ('?', 'Punctuation'),
#  ('시장님', 'Noun'),
#  ('최근', 'Noun'),
#  ('100년', 'Number'),
#  ('동안', 'Foreign'),
#  ('사회주의', 'Noun'),
#  ('가', 'Josa'),
#  ('성공하다', 'Adjective'),
#  ('국가', 'Noun'),
#  ('는', 'Josa'),
#  ('없다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('남미', 'Noun'),
#  ('베네수엘라', 'Noun'),
#  (',', 'Punctuation'),
#  ('소련', 'Noun'),
#  ('과', 'Josa'),
#  ('동구권', 'Noun'),
#  ('도', 'Josa'),
#  ('붕괴', 'Noun'),
#  ('되어다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('대한민국', 'Noun'),
#  ('의', 'Josa'),
#  ('사회주의', 'Noun'),
#  ('도', 'Josa'),
#  ('성공하다', 'Adjective'),
#  ('못', 'Noun'),
#  ('하다', 'Verb'),
#  ('것', 'Noun'),
#  ('이다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('중국', 'Noun'),
#  ('과', 'Josa'),
#  ('싱가폴', 'Noun'),
#  ('은', 'Josa'),
#  ('박정희', 'Noun'),
#  ('대통령', 'Noun'),
#  ('이', 'Josa'),
#  ('일군', 'Noun'),
#  ('한강', 'Noun'),
#  ('의', 'Josa'),
#  ('기적', 'Noun'),
#  ('을', 'Josa'),
#  ('배우다', 'Verb'),
#  ('중국', 'Noun'),
#  ('은', 'Josa'),
#  ('G', 'Alpha'),
#  ('2', 'Number'),
#  ('싱가폴', 'Noun'),
#  ('은', 'Josa'),
#  ('1', 'Number'),
#  ('이다', 'Verb'),
#  ('GDP', 'Alpha'),
#  ('6만', 'Number'),
#  ('$', 'Punctuation'),
#  ('의', 'Noun'),
#  ('선진국', 'Noun'),
#  ('이', 'Josa'),
#  ('되어다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('국민', 'Noun'),
#  ('대다수', 'Noun'),
#  ('의', 'Josa'),
#  ('생각', 'Noun'),
#  ('하다', 'Verb'),
#  ('이야기', 'Noun'),
#  ('를', 'Josa'),
#  ('정확하다', 'Adjective'),
#  ('애기', 'Noun'),
#  ('하다', 'Verb'),
#  ('주어', 'Noun'),
#  ('서', 'Josa'),
#  ('감사하다', 'Verb'),
#  ('집값', 'Noun'),
#  ('몇', 'Modifier'),
#  ('억', 'Noun'),
#  ('오르다', 'Verb'),
#  ('세금', 'Noun'),
#  ('몇십', 'Modifier'),
#  ('만원', 'Noun'),
#  ('오르다', 'Verb'),
#  ('투기', 'Noun'),
#  ('꾼', 'Suffix'),
#  ('들이다', 'Verb'),
#  ('계속', 'Noun'),
#  ('생겨나다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('집다', 'Verb'),
#  ('투기', 'Noun'),
#  ('하다', 'Verb'),
#  ('그렇다', 'Adjective'),
#  ('물건', 'Noun'),
#  ('이', 'Josa'),
#  ('아니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('맞다', 'Verb'),
#  ('보', 'Noun'),
#  ('유세', 'Noun'),
#  ('더', 'Noun'),
#  ('높이다', 'Verb'),
#  ('야하다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('부동산', 'Noun'),
#  ('투기', 'Noun'),
#  ('잡다', 'Verb'),
#  ('출산율', 'Noun'),
#  ('도', 'Josa'),
#  ('늘', 'Noun'),
#  ('고', 'Josa'),
#  ('기업', 'Noun'),
#  ('투자', 'Noun'),
#  ('로', 'Josa'),
#  ('경제', 'Noun'),
#  ('가', 'Josa'),
#  ('사다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('종부세', 'Noun'),
#  ('강화', 'Noun'),
#  ('지지', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('일', 'Modifier'),
#  ('을해', 'Noun'),
#  ('서', 'Josa'),
#  ('돈', 'Noun'),
#  ('을', 'Josa'),
#  ('벌다', 'Verb'),
#  ('땅', 'Noun'),
#  ('이나', 'Josa'),
#  ('아파트', 'Noun'),
#  ('가지', 'Noun'),
#  ('고', 'Josa'),
#  ('돈', 'Noun'),
#  ('을', 'Josa'),
#  ('번', 'Noun'),
#  ('달다', 'Verb'),
#  ('생각', 'Noun'),
#  ('을', 'Josa'),
#  ('못', 'Noun'),
#  ('하다', 'Verb'),
#  ('야하다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('선진국', 'Noun'),
#  ('은', 'Josa'),
#  ('전', 'Modifier'),
#  ('세', 'Modifier'),
#  ('제도', 'Noun'),
#  ('가', 'Josa'),
#  ('없다', 'Adjective'),
#  ('월세', 'Noun'),
#  ('받다', 'Verb'),
#  ('보', 'Noun'),
#  ('유세', 'Noun'),
#  ('내지', 'Noun'),
#  ('만', 'Josa'),
#  ('한국', 'Noun'),
#  ('은', 'Josa'),
#  ('전세', 'Noun'),
#  ('제도로', 'Noun'),
#  ('전', 'Modifier'),
#  ('세', 'Modifier'),
#  ('보증금', 'Noun'),
#  ('으로', 'Josa'),
#  ('선진국', 'Noun'),
#  ('처럼', 'Josa'),
#  ('보유', 'Noun'),
#  ('세다', 'Verb'),
#  ('내면', 'Noun'),
#  ('집주인', 'Noun'),
#  ('이', 'Josa'),
#  ('손', 'Noun'),
#  ('해보다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('원숭이', 'Noun'),
#  ('말다', 'Verb'),
#  ('라면', 'Noun'),
#  ('전세', 'Noun'),
#  ('제도', 'Noun'),
#  ('없애다', 'Verb'),
#  ('월세', 'Noun'),
#  ('내다', 'Verb'),
#  ('하다', 'Verb'),
#  ('보', 'Noun'),
#  ('유세', 'Noun'),
#  ('올리다', 'Verb'),
#  ('거지', 'Noun'),
#  ('고액', 'Noun'),
#  ('주택', 'Noun'),
#  ('에', 'Josa'),
#  ('대한', 'Noun'),
#  ('보', 'Noun'),
#  ('유세', 'Noun'),
#  ('를', 'Josa'),
#  ('올리다', 'Verb'),
#  ('것', 'Noun'),
#  ('은', 'Josa'),
#  ('맞다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('대신', 'Noun'),
#  ('양', 'Modifier'),
#  ('도세', 'Noun'),
#  ('를', 'Josa'),
#  ('낮추다', 'Verb'),
#  ('가지다', 'Verb'),
#  ('사람', 'Noun'),
#  ('들', 'Suffix'),
#  ('이', 'Josa'),
#  ('팔지', 'Noun'),
#  ('...', 'Punctuation'),
#  ('공산당', 'Noun'),
#  ('놈', 'Noun'),
#  ('들', 'Suffix'),
#  ('진정', 'Noun'),
#  ('으로', 'Josa'),
#  ('서민', 'Noun'),
#  ('을', 'Josa'),
#  ('위해', 'Noun'),
#  ('일', 'Noun'),
#  ('하다', 'Verb'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('쓸데없다', 'Adjective'),
#  ('말', 'Noun'),
#  ('말고', 'Josa'),
#  ('공급', 'Noun'),
#  ('이', 'Josa'),
#  ('필요하다', 'Adjective'),
#  ('정권', 'Noun'),
#  ('빨리', 'Adverb'),
#  ('바뀌다', 'Verb'),
#  ('좋다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('온', 'Noun'),
#  ('나라', 'Noun'),
#  ('가', 'Josa'),
#  ('혼란', 'Noun'),
#  ('뒤', 'Noun'),
#  ('숭숭', 'Noun'),
#  ('..', 'Punctuation'),
#  ('정치', 'Noun'),
#  ('경제', 'Noun'),
#  ('안보', 'Noun'),
#  ('민생', 'Noun'),
#  ('불안하다', 'Adjective'),
#  ('바람', 'Noun'),
#  ('잘나다', 'Adjective'),
#  ('없다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('못', 'VerbPrefix'),
#  ('살다', 'Verb'),
#  ('진짜', 'Noun'),
#  ('재산', 'Noun'),
#  ('몰수', 'Noun'),
#  ('하', 'Suffix'),
#  ('여', 'Josa'),
#  ('민노총', 'Noun'),
#  ('에', 'Josa'),
#  ('주다', 'Verb'),
#  ('박원순', 'Noun'),
#  ('공산주의', 'Noun'),
#  ('빨갱이', 'Noun'),
#  ('어쩔', 'Modifier'),
#  ('고', 'Noun'),
#  ('엠벼헐', 'Noun'),
#  ('안철수', 'Noun'),
#  ('가', 'Josa'),
#  ('원망', 'Noun'),
#  ('스럽다', 'Adjective'),
#  ('움', 'Noun'),
#  ('!', 'Punctuation'),
#  ('미치다', 'Adjective'),
#  ('소리', 'Noun'),
#  ('하고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('이제', 'Noun'),
#  ('돈', 'Noun'),
#  ('뿌리다', 'Verb'),
#  ('~', 'Punctuation'),
#  ('돈', 'Noun'),
#  ('떨어지다', 'Verb'),
#  ('?~', 'Punctuation'),
#  ('서민', 'Noun'),
#  ('이나', 'Josa'),
#  ('극빈', 'Noun'),
#  ('층', 'Noun'),
#  ('들', 'Suffix'),
#  ('보기', 'Noun'),
#  ('에는', 'Josa'),
#  ('~~', 'Punctuation'),
#  ('내', 'Determiner'),
#  ('돈', 'Noun'),
#  ('과', 'Josa'),
#  ('상관없다', 'Adjective'),
#  ('같다', 'Adjective'),
#  ('?~', 'Punctuation'),
#  ('민주당', 'Noun'),
#  ('찍다', 'Verb'),
#  ('사람', 'Noun'),
#  ('들', 'Suffix'),
#  ('~~', 'Punctuation'),
#  ('책임지다', 'Verb'),
#  ('~~~', 'Punctuation'),
#  ('이', 'Noun'),
#  ('사람', 'Noun'),
#  ('들', 'Suffix'),
#  ('은', 'Josa'),
#  ('오로지', 'Adverb'),
#  ('세금', 'Noun'),
#  ('걷다', 'Verb'),
#  ('밖에', 'Josa'),
#  ('생각', 'Noun'),
#  ('알다', 'Verb'),
#  ('ㅠㅠ', 'KoreanParticle'),
#  ('집다', 'Verb'),
#  ('주거', 'Noun'),
#  ('기능', 'Noun'),
#  ('뿐', 'Suffix'),
#  ('만', 'Josa'),
#  ('아니다', 'Adjective'),
#  ('재산', 'Noun'),
#  ('수단', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('기숙사', 'Noun'),
#  ('가', 'Josa'),
#  ('아니다', 'Adjective'),
#  ('말', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('좌익', 'Noun'),
#  ('들', 'Suffix'),
#  ('의', 'Josa'),
#  ('개념', 'Noun'),
#  ('속', 'Noun'),
#  ('에는', 'Josa'),
#  ('사유재산', 'Noun'),
#  ('을', 'Josa'),
#  ('인정', 'Noun'),
#  ('하다', 'Verb'),
#  ('않다', 'Verb'),
#  ('공산주의', 'Noun'),
#  ('와', 'Josa'),
#  ('같다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('남', 'Noun'),
#  ('잘', 'VerbPrefix'),
#  ('되다', 'Verb'),
#  ('꼴', 'Noun'),
#  ('을', 'Josa'),
#  ('못', 'VerbPrefix'),
#  ('보다', 'Verb'),
#  ('ᆢ', 'Foreign'),
#  ('잠깐', 'Noun'),
#  ('!', 'Punctuation'),
#  ('본인', 'Noun'),
#  ('이', 'Josa'),
#  ('좌익', 'Noun'),
#  ('인지', 'Josa'),
#  ('아니다', 'Adjective'),
#  ('가름', 'Noun'),
#  ('하다', 'Verb'),
#  ('척도', 'Noun'),
#  ('?', 'Punctuation'),
#  ('강남', 'Noun'),
#  ('집값', 'Noun'),
#  ('이', 'Josa'),
#  ('오르다', 'Verb'),
#  ('부럽다', 'Adjective'),
#  (',', 'Punctuation'),
#  ('나다', 'Verb'),
#  ('사다', 'Verb'),
#  ('ㅡ', 'KoreanParticle'),
#  ('우익', 'Noun'),
#  ('저걸', 'Noun'),
#  ('세금', 'Noun'),
#  ('으로', 'Josa'),
#  ('재산', 'Noun'),
#  ('을', 'Josa'),
#  ('뺏다', 'Verb'),
#  ('ㅡ', 'KoreanParticle'),
#  ('좌익', 'Noun'),
#  ('재개발', 'Noun'),
#  ('막다', 'Verb'),
#  ('신규', 'Noun'),
#  ('분양', 'Noun'),
#  ('늦추다', 'Verb'),
#  ('니', 'Noun'),
#  ('가', 'Josa'),
#  ('공급', 'Noun'),
#  ('이야기', 'Noun'),
#  ('를', 'Josa'),
#  ...]

# %%
# test_str='완전 위해 절대 그게 아무'
# test=twitter.pos(test_str, norm=True, stem=True)
# print(test)
# Out:
# [('완전', 'Noun'), ('위해', 'Noun'), ('절대', 'Noun'), ('그게', 'Noun'), ('아무', 'Noun')]

# %%
del_list = ['하다', '있다', '되다', '이다', '돼다', '않다', '그렇다', '아니다', '이렇다', '그렇다','어떻다','ㅋㅋ','ㅋㅋㅋ','ㅠㅠ','ㅉㅉ','ㅎㅎ','없다','위해','완전','절대','그게','아무','건가','나다','모두','이미','저런','같다'] #삭제할 것들
word_cleaned = []
for word in raw_pos_tagged:
    if not word[1] in ["Josa", "Eomi", "Punctuation", "Foreign","Adverb","Suffix"]: # Foreign == ”, “ 와 같이 제외되어야할 항목들
        if (len(word[0]) != 1) & (word[0] not in del_list): # 한 글자로 이뤄진 단어들을 제외 & 원치 않는 단어들을 제외
            if(word[0].isalpha()): #숫자 뺌
                word_cleaned.append(word[0])

word_counted = Counter(word_cleaned)
word_dic = dict(word_counted)
        
sorted_word_dic = sorted(word_dic.items(), key=lambda x:x[1], reverse=True)

sorted_word_dic
# Out:
# [('세금', 265),
#  ('부동산', 191),
#  ('사람', 167),
#  ('정책', 157),
#  ('집값', 146),
#  ('올리다', 146),
#  ('시장', 139),
#  ('국민', 134),
#  ('종부세', 132),
#  ('보다', 122),
#  ('오르다', 105),
#  ('투기', 103),
#  ('살다', 101),
#  ('서울', 100),
#  ('원숭이', 98),
#  ('내다', 98),
#  ('주택', 93),
#  ('잡다', 81),
#  ('나라', 81),
#  ('생각', 81),
#  ('정권', 80),
#  ('정부', 78),
#  ('아파트', 77),
#  ('지다', 76),
#  ('만들다', 76),
#  ('박원순', 73),
#  ('들다', 70),
#  ('모르다', 69),
#  ('유세', 64),
#  ('전세', 64),
#  ('공급', 64),
#  ('서울시장', 62),
#  ('인간', 61),
#  ('뽑다', 60),
#  ('시키다', 60),
#  ('사회주의', 58),
#  ('시민', 57),
#  ('이상', 56),
#  ('먹다', 55),
#  ('쓰다', 53),
#  ('걷다', 53),
#  ('소리', 53),
#  ('알다', 52),
#  ('재산', 50),
#  ('맞다', 50),
#  ('아들', 49),
#  ('하나', 49),
#  ('야하다', 48),
#  ('좋다', 48),
#  ('서민', 48),
#  ('받다', 44),
#  ('나오다', 43),
#  ('진짜', 42),
#  ('문재인', 42),
#  ('공산주의', 41),
#  ('미치다', 41),
#  ('가다', 41),
#  ('가격', 40),
#  ('월세', 40),
#  ('강남', 40),
#  ('들이다', 39),
#  ('넘다', 38),
#  ('가지다', 38),
#  ('빨갱이', 38),
#  ('선진국', 37),
#  ('주다', 36),
#  ('이제', 36),
#  ('국가', 36),
#  ('보유', 36),
#  ('해보다', 36),
#  ('많다', 34),
#  ('무슨', 34),
#  ('사다', 34),
#  ('서다', 34),
#  ('수준', 33),
#  ('좌파', 33),
#  ('폭등', 33),
#  ('규제', 32),
#  ('북한', 32),
#  ('경제', 32),
#  ('정도', 32),
#  ('올려놓다', 32),
#  ('거래', 32),
#  ('정신', 31),
#  ('되어다', 30),
#  ('대통령', 30),
#  ('당신', 30),
#  ('떨어지다', 29),
#  ('오다', 29),
#  ('버리다', 29),
#  ('인생', 29),
#  ('갖다', 28),
#  ('한국', 28),
#  ('누가', 28),
#  ('쓰레기', 28),
#  ('나가다', 28),
#  ('때문', 28),
#  ('말다', 27),
#  ('치다', 26),
#  ('차다', 26),
#  ('집다', 26),
#  ('싶다', 26),
#  ('대출', 26),
#  ('지금', 26),
#  ('인상', 25),
#  ('본인', 25),
#  ('때리다', 25),
#  ('서울시', 24),
#  ('돌리다', 24),
#  ('그리고', 24),
#  ('제발', 24),
#  ('뜯다', 24),
#  ('좌빨', 24),
#  ('사유재산', 24),
#  ('투자', 24),
#  ('정치', 24),
#  ('안철수', 24),
#  ('다른', 24),
#  ('아예', 24),
#  ('문제', 24),
#  ('자기', 24),
#  ('모든', 24),
#  ('신뢰', 24),
#  ('자다', 23),
#  ('새끼', 22),
#  ('보지', 22),
#  ('따르다', 22),
#  ('안되다', 22),
#  ('고가', 22),
#  ('결과', 21),
#  ('책임', 21),
#  ('지지', 21),
#  ('충분하다', 21),
#  ('대가리', 21),
#  ('자식', 20),
#  ('어디', 20),
#  ('잘못', 20),
#  ('민주당', 20),
#  ('한다는', 20),
#  ('이야기', 20),
#  ('계속', 20),
#  ('벌다', 20),
#  ('공산당', 20),
#  ('바뀌다', 20),
#  ('늘다', 20),
#  ('강력하다', 20),
#  ('국토부', 20),
#  ('민주주의', 20),
#  ('진보', 20),
#  ('죽다', 20),
#  ('싫다', 19),
#  ('힘들다', 19),
#  ('자본주의', 19),
#  ('펑펑', 18),
#  ('이런', 18),
#  ('크다', 18),
#  ('그냥', 18),
#  ('부자', 18),
#  ('거지', 17),
#  ('법대', 17),
#  ('전과', 17),
#  ('부족하다', 17),
#  ('무조건', 17),
#  ('장관', 16),
#  ('재건축', 16),
#  ('공정하다', 16),
#  ('점점', 16),
#  ('박원숭', 16),
#  ('해주다', 16),
#  ('무능', 16),
#  ('대한민국', 16),
#  ('기업', 16),
#  ('라면', 16),
#  ('도세', 16),
#  ('팔지', 16),
#  ('보기', 16),
#  ('찍다', 16),
#  ('늘리다', 16),
#  ('두다', 16),
#  ('개다', 16),
#  ('생기다', 16),
#  ('집도', 16),
#  ('자신', 16),
#  ('짖다', 16),
#  ('한번', 16),
#  ('임대주택', 16),
#  ('안정', 16),
#  ('세대', 16),
#  ('사고', 16),
#  ('부과', 16),
#  ('놓다', 16),
#  ('자도', 16),
#  ('보수', 16),
#  ('호남', 16),
#  ('전라도', 16),
#  ('시장님', 15),
#  ('중국', 15),
#  ('불로소득', 15),
#  ('좋아하다', 15),
#  ('동안', 14),
#  ('그런', 14),
#  ('세상', 14),
#  ('찾다', 14),
#  ('파다', 14),
#  ('ㅁㅊ', 14),
#  ('책임지다', 14),
#  ('머리', 14),
#  ('따다', 14),
#  ('원숭', 14),
#  ('거두다', 14),
#  ('자꾸', 14),
#  ('한심하다', 14),
#  ('찬성', 14),
#  ('건지다', 14),
#  ('망하다', 14),
#  ('역대', 14),
#  ('뜨다', 14),
#  ('우리나라', 14),
#  ('건설', 13),
#  ('심다', 13),
#  ('분양', 13),
#  ('이유', 13),
#  ('내년', 13),
#  ('시장경제', 13),
#  ('살기', 13),
#  ('죽이다', 13),
#  ('해도', 13),
#  ('낮추다', 12),
#  ('대부분', 12),
#  ('떼다', 12),
#  ('김현미', 12),
#  ('몰수', 12),
#  ('마이너스', 12),
#  ('유학', 12),
#  ('재개발', 12),
#  ('가라', 12),
#  ('가난하다', 12),
#  ('남다', 12),
#  ('돌다', 12),
#  ('총선', 12),
#  ('날다', 12),
#  ('혼란', 12),
#  ('성공하다', 12),
#  ('가지', 12),
#  ('제도', 12),
#  ('대한', 12),
#  ('주거', 12),
#  ('좌익', 12),
#  ('웃기다', 12),
#  ('풀다', 12),
#  ('민주', 12),
#  ('왕창', 12),
#  ('개발', 12),
#  ('취득세', 12),
#  ('상속세', 12),
#  ('쉬다', 12),
#  ('유지', 12),
#  ('죄인', 12),
#  ('팔고', 12),
#  ('더럽다', 12),
#  ('주제', 12),
#  ('평양', 12),
#  ('짓거리', 12),
#  ('임대', 12),
#  ('수도', 12),
#  ('아주', 12),
#  ('편하다', 12),
#  ('중요하다', 12),
#  ('금리', 12),
#  ('이상하다', 12),
#  ('소득', 12),
#  ('가로', 12),
#  ('옳다', 12),
#  ('생산', 12),
#  ('마련', 12),
#  ('소유', 12),
#  ('발악', 12),
#  ('싸다', 12),
#  ('통제', 12),
#  ('전국', 12),
#  ('모양', 12),
#  ('노무현', 12),
#  ('뉴욕', 12),
#  ('런던', 12),
#  ('개돼지', 12),
#  ('확실하다', 12),
#  ('너희', 12),
#  ('실패', 12),
#  ('중산층', 12),
#  ('강하다', 12),
#  ('공무원', 12),
#  ('체제', 12),
#  ('ㅈㄹ', 12),
#  ('위선', 11),
#  ('달다', 11),
#  ('뺏다', 11),
#  ('정말', 11),
#  ('평생', 11),
#  ('보내다', 10),
#  ('대신', 10),
#  ('물리다', 10),
#  ('본색', 10),
#  ('멀다', 10),
#  ('거의', 10),
#  ('준비', 10),
#  ('상황', 10),
#  ('수백', 10),
#  ('보고', 10),
#  ('제대로', 10),
#  ('대폭', 10),
#  ('갚다', 10),
#  ('임기', 10),
#  ('협찬', 10),
#  ('당연하다', 10),
#  ('월급', 10),
#  ('된거', 10),
#  ('소비', 10),
#  ('맞추다', 10),
#  ('배다', 9),
#  ('나쁘다', 9),
#  ('잡히다', 9),
#  ('줄다', 9),
#  ('미대', 9),
#  ('그동안', 9),
#  ('망치다', 9),
#  ('하지만', 9),
#  ('맡다', 9),
#  ('여기', 9),
#  ('노예', 9),
#  ('떨다', 9),
#  ('수당', 9),
#  ('파악', 8),
#  ('시골', 8),
#  ('정은', 8),
#  ('지랄', 8),
#  ('당장', 8),
#  ('공평하다', 8),
#  ('필요하다', 8),
#  ('대상', 8),
#  ('기회', 8),
#  ('기생충', 8),
#  ('감옥', 8),
#  ('사고방식', 8),
#  ('아웃', 8),
#  ('만하', 8),
#  ('얼굴', 8),
#  ('리즘', 8),
#  ('인하다', 8),
#  ('부담', 8),
#  ('쓰개', 8),
#  ('계획', 8),
#  ('최근', 8),
#  ('싱가폴', 8),
#  ('대다수', 8),
#  ('정확하다', 8),
#  ('없애다', 8),
#  ('고액', 8),
#  ('안보', 8),
#  ('원망', 8),
#  ('스럽다', 8),
#  ('수단', 8),
#  ('개념', 8),
#  ('저걸', 8),
#  ('막다', 8),
#  ('하니', 8),
#  ('그린벨트', 8),
#  ('지방', 8),
#  ('마인드', 8),
#  ('탄핵', 8),
#  ('세도', 8),
#  ('당근', 8),
#  ('만세', 8),
#  ('저러다', 8),
#  ('망국', 8),
#  ('발언', 8),
#  ('반성', 8),
#  ('지네', 8),
#  ('올라가다', 8),
#  ('기다', 8),
#  ('증여세', 8),
#  ('이중과세', 8),
#  ('키우다', 8),
#  ('그만하다', 8),
#  ('빼앗다', 8),
#  ('지키다', 8),
#  ('권력', 8),
#  ('드러나다', 8),
#  ('실수', 8),
#  ('듣다', 8),
#  ('지경', 8),
#  ('제일', 8),
#  ('다음', 8),
#  ('이북', 8),
#  ('새롭다', 8),
#  ('산다', 8),
#  ('실행', 8),
#  ('당선', 8),
#  ('해외', 8),
#  ('뒤지다', 8),
#  ('이번', 8),
#  ('두르다', 8),
#  ('어이없다', 8),
#  ('장난', 8),
#  ('잡기', 8),
#  ('집산', 8),
#  ('사업자', 8),
#  ('현실', 8),
#  ('가장', 8),
#  ('신기하다', 8),
#  ('발전', 8),
#  ('작년', 8),
#  ('추진', 8),
#  ('화가', 8),
#  ('기자', 8),
#  ('내리다', 8),
#  ('비교', 8),
#  ('차리다', 8),
#  ('여의도', 8),
#  ('걱정', 8),
#  ('중과', 8),
#  ('나누다', 8),
#  ('걸다', 8),
#  ('선거', 8),
#  ('몰다', 8),
#  ('재앙', 8),
#  ('내려놓다', 8),
#  ('지원', 8),
#  ('개미', 8),
#  ('공시지가', 8),
#  ('주식', 8),
#  ('세력', 8),
#  ('자유', 8),
#  ('부정', 8),
#  ('자고', 8),
#  ('잡고', 8),
#  ('독재', 8),
#  ('도배', 8),
#  ('무료', 8),
#  ('빠지다', 8),
#  ('안달', 8),
#  ('아깝다', 8),
#  ('왜곡', 8),
#  ('채찍', 8),
#  ('어차피', 8),
#  ('더하다', 8),
#  ('우리', 8),
#  ('정치인', 8),
#  ('리지', 8),
#  ('정신병', 8),
#  ('내주', 8),
#  ('안내', 8),
#  ('쏟아내다', 8),
#  ('과거', 8),
#  ('가보다', 8),
#  ('행방', 8),
#  ('시세', 8),
#  ('양도소득세', 8),
#  ('물리', 8),
#  ('자리', 8),
#  ('공관', 8),
#  ('대해', 8),
#  ('원가', 8),
#  ('시대', 8),
#  ('등락', 8),
#  ('개입', 8),
#  ('개판', 8),
#  ('토지', 8),
#  ('보이다', 8),
#  ('아가리', 8),
#  ('깔다', 8),
#  ('나서다', 8),
#  ('실패하다', 8),
#  ('깨문', 8),
#  ('구라', 8),
#  ('다시', 8),
#  ('협박', 8),
#  ('막말', 8),
#  ('한숨', 8),
#  ('좌좀', 8),
#  ('모이다', 8),
#  ('의지', 8),
#  ('대다', 8),
#  ('청와대', 8),
#  ('불신', 8),
#  ('최고', 8),
#  ('평균', 8),
#  ('조사', 8),
#  ('그릇', 8),
#  ('래야', 8),
#  ('인구', 8),
#  ('울다', 8),
#  ('박근혜', 8),
#  ('개인', 8),
#  ('부채', 8),
#  ('어렵다', 8),
#  ('반발', 8),
#  ('현재', 8),
#  ('덩어리', 8),
#  ('능력', 8),
#  ('제제', 8),
#  ('방법', 8),
#  ('기준', 8),
#  ('신나다', 8),
#  ('발표', 8),
#  ('상류층', 8),
#  ('산업', 8),
#  ('확대', 8),
#  ('여부', 8),
#  ('조정', 7),
#  ('소련', 7),
#  ('인정', 7),
#  ('엄청나다', 7),
#  ('발상', 7),
#  ('아저씨', 7),
#  ('공짜', 7),
#  ('챙기다', 7),
#  ('지껄이다', 7),
#  ('필요없다', 7),
#  ('꾸다', 7),
#  ('지지자', 7),
#  ('높다', 7),
#  ('선동', 7),
#  ('물가', 7),
#  ('관사', 7),
#  ('자빠지다', 7),
#  ('묻다', 7),
#  ('대권', 6),
#  ('그리다', 6),
#  ('끄다', 6),
#  ('더불다', 6),
#  ('구역질', 6),
#  ('만원', 6),
#  ('을해', 6),
#  ('어쩔', 6),
#  ('정작', 6),
#  ('정신차리다', 6),
#  ('집사', 6),
#  ('지출', 6),
#  ('대선', 6),
#  ('틀어막다', 6),
#  ('선하다', 6),
#  ('폭락', 6),
#  ('시작', 6),
#  ('서민이', 6),
#  ('논리', 6),
#  ('치우다', 6),
#  ('산놈', 6),
#  ('올린다', 6),
#  ('언제', 6),
#  ('상태', 6),
#  ('도대체', 6),
#  ('원래', 6),
#  ('이해', 6),
#  ('뛰다', 6),
#  ('우파', 6),
#  ('장기', 6),
#  ('양보', 6),
#  ('모으다', 6),
#  ('신경', 6),
#  ('손가락', 6),
#  ('궁금하다', 6),
#  ('최악', 6),
#  ('먹튀', 6),
#  ('싫어하다', 6),
#  ('로만', 6),
#  ('재미', 6),
#  ('끼리', 6),
#  ('갈다', 6),
#  ('핵심', 6),
#  ('낙원', 6),
#  ('살리다', 6),
#  ('설치다', 6),
#  ('절반', 6),
#  ('홍어', 6),
#  ('흐름', 6),
#  ('믿다', 6),
#  ('면제', 5),
#  ('때매', 5),
#  ('자네', 5),
#  ('금지', 5),
#  ('내놓다', 5),
#  ('공산', 5),
#  ('주의자', 5),
#  ('잘살다', 5),
#  ('갈리다', 5),
#  ('숨기다', 5),
#  ('시청', 5),
#  ('증명', 5),
#  ('가야', 5),
#  ('읽다', 5),
#  ('여기다', 5),
#  ('삶다', 5),
#  ('자체', 5),
#  ('광주', 5),
#  ('은행', 5),
#  ('급여', 4),
#  ('최저', 4),
#  ('가깝다', 4),
#  ('세월', 4),
#  ('경쟁력', 4),
#  ('가트', 4),
#  ('못난이', 4),
#  ('대도', 4),
#  ('노릇', 4),
#  ('도인', 4),
#  ('지방선거', 4),
#  ('북풍', 4),
#  ('영향', 4),
#  ('쓸다', 4),
#  ('변하다', 4),
#  ('애비', 4),
#  ('시침', 4),
#  ('비슷하다', 4),
#  ('식견', 4),
#  ('보시', 4),
#  ('내려가다', 4),
#  ('이장님', 4),
#  ('딱이다', 4),
#  ('차라리', 4),
#  ('바치', 4),
#  ('혈세', 4),
#  ('퇴진', 4),
#  ('어찌', 4),
#  ('고급', 4),
#  ('어딨다', 4),
#  ('엑스레이', 4),
#  ('제출', 4),
#  ('었다', 4),
#  ('인종', 4),
#  ('뮌소릴', 4),
#  ('처럼', 4),
#  ('그대', 4),
#  ('가을', 4),
#  ('톡톡하다', 4),
#  ('의하다', 4),
#  ('깍두기', 4),
#  ('일조', 4),
#  ('고층', 4),
#  ('급량', 4),
#  ('증가', 4),
#  ('검토', 4),
#  ('처음', 4),
#  ('뒷북', 4),
#  ('하향', 4),
#  ('평준화', 4),
#  ('고만고만하다', 4),
#  ('해처', 4),
#  ('안다', 4),
#  ('효과', 4),
#  ('지난', 4),
#  ('퇴보하다', 4),
#  ('살찌다', 4),
#  ('아이러니', 4),
#  ('인사', 4),
#  ('번지르르하다', 4),
#  ('교활하다', 4),
#  ('악랄하다', 4),
#  ('김어준', 4),
#  ('고요', 4),
#  ('밥맛', 4),
#  ('면상', 4),
#  ('수고', 4),
#  ('보호', 4),
#  ('그이', 4),
#  ('작살', 4),
#  ('먹고살다', 4),
#  ('하여튼', 4),
#  ('정국', 4),
#  ('국론', 4),
#  ('분열', 4),
#  ('파탄', 4),
#  ('외교', 4),
#  ('사탕', 4),
#  ('녹이다', 4),
#  ('먹듯', 4),
#  ('가중', 4),
#  ('가즈', 4),
#  ('실감', 4),
#  ('퍼주개', 4),
#  ('꼴리다', 4),
#  ('남미', 4),
#  ('베네수엘라', 4),
#  ('동구권', 4),
#  ('붕괴', 4),
#  ('박정희', 4),
#  ('일군', 4),
#  ('한강', 4),
#  ('기적', 4),
#  ('배우다', 4),
#  ('GDP', 4),
#  ('애기', 4),
#  ('주어', 4),
#  ('감사하다', 4),
#  ('몇십', 4),
#  ('생겨나다', 4),
#  ('물건', 4),
#  ('높이다', 4),
#  ('출산율', 4),
#  ('강화', 4),
#  ('내지', 4),
#  ('제도로', 4),
#  ('보증금', 4),
#  ('세다', 4),
#  ('내면', 4),
#  ('집주인', 4),
#  ('진정', 4),
#  ('쓸데없다', 4),
#  ('숭숭', 4),
#  ('민생', 4),
#  ('불안하다', 4),
#  ('바람', 4),
#  ('잘나다', 4),
#  ('민노총', 4),
#  ('엠벼헐', 4),
#  ('뿌리다', 4),
#  ('극빈', 4),
#  ('상관없다', 4),
#  ('기능', 4),
#  ('기숙사', 4),
#  ('잠깐', 4),
#  ('가름', 4),
#  ('척도', 4),
#  ('부럽다', 4),
#  ('우익', 4),
#  ('신규', 4),
#  ('늦추다', 4),
#  ('코스', 4),
#  ('푸다', 4),
#  ('어딧', 4),
#  ('직장', 4),
#  ('얘기', 4),
#  ('한해', 4),
#  ('땅값', 4),
#  ('출신', 4),
#  ('특성', 4),
#  ('판자촌', 4),
#  ('면장', 4),
#  ('군수', 4),
#  ('수작', 4),
#  ('부리다', 4),
#  ('조선인', 4),
#  ('공화국', 4),
#  ('하루', 4),
#  ('이틀', 4),
#  ('의도', 4),
#  ('다분하다', 4),
#  ('이쁘다', 4),
#  ('하든', 4),
#  ('젊은이', 4),
#  ('결혼', 4),
#  ('애도', 4),
#  ('낳다', 4),
#  ('이롭다', 4),
#  ('널뛰기', 4),
#  ('선시', 4),
#  ('자신감', 4),
#  ('여기저기', 4),
#  ('죄안', 4),
#  ('유지될런', 4),
#  ('조세', 4),
#  ('적다', 4),
#  ('전세계', 4),
#  ('소득세', 4),
#  ('번돈', 4),
#  ('무의미하다', 4),
#  ('자수', 4),
#  ('가해', 4),
#  ('경영', 4),
#  ('방어', 4),
#  ('리좀', 4),
#  ('소유권', 4),
#  ('생명', 4),
#  ('존재', 4),
#  ('진자', 4),
#  ('위험천만', 4),
#  ('서서히', 4),
#  ('보구', 4),
#  ('쉐이', 4),
#  ('판잣집', 4),
#  ('노후', 4),
#  ('빌라', 4),
#  ('괴쉐', 4),
#  ('저축', 4),
#  ('태반', 4),
#  ('삥떧어', 4),
#  ('포플지즘', 4),
#  ('시정', 4),
#  ('잡배', 4),
#  ('뿐이다', 4),
#  ('자의', 4),
#  ('망말', 4),
#  ('분노', 4),
#  ('치밀다', 4),
#  ('명분', 4),
#  ('주변', 4),
#  ('적지', 4),
#  ('토나오다', 4),
#  ('징벌', 4),
#  ('올라서다', 4),
#  ('전체', 4),
#  ('들어오다', 4),
#  ('오히려', 4),
#  ('팔면', 4),
#  ('내야', 4),
#  ('이르다', 4),
#  ('다물다', 4),
#  ('양도', 4),
#  ('성과', 4),
#  ('소용없다', 4),
#  ('리기', 4),
#  ('수사', 4),
#  ('명의', 4),
#  ('비겁하다', 4),
#  ('서울대', 4),
#  ('최초', 4),
#  ('따님', 4),
#  ('박다', 4),
#  ('인양', 4),
#  ('수년', 4),
#  ('행방불명', 4),
#  ('아드님', 4),
#  ('박주신', 4),
#  ('아버님', 4),
#  ('응원', 4),
#  ('빨갛다', 4),
#  ('부역', 4),
#  ('쪼다들', 4),
#  ('반대', 4),
#  ('하므다', 4),
#  ('거리', 4),
#  ('전부', 4),
#  ('삐라', 4),
#  ('시나', 4),
#  ('서도', 4),
#  ('환영', 4),
#  ('위인', 4),
#  ('양쪽', 4),
#  ('영혼', 4),
#  ('탈곡', 4),
#  ('인지', 4),
#  ('ㅈㅅ', 4),
#  ('평수', 4),
#  ('뭐보', 4),
#  ('사태', 4),
#  ('표현', 4),
#  ('것임', 4),
#  ('무책임하다', 4),
#  ('바보', 4),
#  ('알고잏는', 4),
#  ('듯함', 4),
#  ('옥상', 4),
#  ('텃밭', 4),
#  ('꼬추', 4),
#  ('달동네', 4),
#  ('체험', 4),
#  ('살림', 4),
#  ('멍청하다', 4),
#  ('감당', 4),
#  ('고작', 4),
#  ('이집', 4),
#  ('청아', 4),
#  ('윈숭', 4),
#  ('놔두다', 4),
#  ('슬럼', 4),
#  ('앞장서다', 4),
#  ('말씀', 4),
#  ('걸이', 4),
#  ('구나', 4),
#  ('수십', 4),
#  ('동떨어지다', 4),
#  ('의식주', 4),
#  ('기본', 4),
#  ('가정', 4),
#  ('잡지', 4),
#  ('이꼬', 4),
#  ('등기', 4),
#  ('호의호식', 4),
#  ('써다', 4),
#  ('뭐합', 4),
#  ('금년', 4),
#  ('등장', 4),
#  ('요즘', 4),
#  ('격해지다', 4),
#  ('상대', 4),
#  ('자극', 4),
#  ('말로', 4),
#  ('언론', 4),
#  ('타다', 4),
#  ('조건', 4),
#  ('뱃으', 4),
#  ('무엇', 4),
#  ('앞날', 4),
#  ('각성', 4),
#  ('해먹', 4),
#  ('깨어나다', 4),
#  ('필히', 4),
#  ('이후', 4),
#  ('단위', 4),
#  ('수치', 4),
#  ('물가상승률', 4),
#  ('감안', 4),
#  ('가능하다', 4),
#  ('부탁드리다', 4),
#  ('올려주다', 4),
#  ('부탁', 4),
#  ('어르다', 4),
#  ('띁어가', 4),
#  ('악질', 4),
#  ('운전기사', 4),
#  ('구장', 4),
#  ('저리', 4),
#  ('차갑다', 4),
#  ('연금', 4),
#  ('국회의원', 4),
#  ('런가', 4),
#  ('떠들다', 4),
#  ('커녕', 4),
#  ('일개', 4),
#  ('등록', 4),
#  ('팔다', 4),
#  ('어떻', 4),
#  ('가요', 4),
#  ('침팬지', 4),
#  ('벽보', 4),
#  ('폭탄', 4),
#  ('시스템', 4),
#  ('생충', 4),
#  ('손볼때', 4),
#  ('무기징역', 4),
#  ('다스리다', 4),
#  ('내전', 4),
#  ('일어나다', 4),
#  ('선량하다', 4),
#  ('세수', 4),
#  ('온갖', 4),
#  ('관료', 4),
#  ('정년', 4),
#  ('퇴직', 4),
#  ('도입', 4),
#  ('짜증나다', 4),
#  ('자시다', 4),
#  ('주둥이', 4),
#  ('찢다', 4),
#  ('앉히다', 4),
#  ('적폐놈', 4),
#  ('임시', 4),
#  ('전액', 4),
#  ('멈추다', 4),
#  ('취임', 4),
#  ('수놈', 4),
#  ('전무하다', 4),
#  ('베짱이', 4),
#  ('배부르다', 4),
#  ('속편', 4),
#  ('한나라', 4),
#  ('무일푼', 4),
#  ('별반', 4),
#  ('차이', 4),
#  ('홀라당', 4),
#  ('엉뚱하다', 4),
#  ('쏟다', 4),
#  ('붓다', 4),
#  ('집갑', 4),
#  ('젊다', 4),
#  ('강력', 4),
#  ('이제야', 4),
#  ('절절', 4),
#  ('토착', 4),
#  ('왜구', 4),
#  ('유충', 4),
#  ('흔들리다', 4),
#  ('빅원순', 4),
#  ('오랫', 4),
#  ('부종', 4),
#  ('예금', 4),
#  ('설비', 4),
#  ('아무렇다', 4),
#  ('투자가', 4),
#  ('줄어들다', 4),
#  ('말리다', 4),
#  ('공격', 4),
#  ('나가야', 4),
#  ('지름길', 4),
#  ('근절', 4),
#  ('허가', 4),
#  ('낼때', 4),
#  ('법적', 4),
#  ('다해', 4),
#  ('꼭지', 4),
#  ('기금', 4),
#  ('주사파', 4),
#  ('남로당', 4),
#  ('새다', 4),
#  ('수급', 4),
#  ('복지', 4),
#  ('끊다', 4),
#  ('김치', 4),
#  ('여름', 4),
#  ('에어콘', 4),
#  ('겨울', 4),
#  ...]

# %%
# 빈도 순으로 상위 100개에 해당하는 단어까지만 추려내기
translation_target = sorted_word_dic[:100]

# %%
translation_target = {}
for item in word_dic: #item에 키값 들어감
    if word_dic[item] >= 31: # 위에서 확인한 빈도수를 기반으로 번역 대상 단어를 선정합니다.
        translation_target[item] = word_dic[item]

# %%
print(translation_target)
# Out:
# {'수준': 33, '야하다': 48, '박원순': 73, '시장': 139, '사람': 167, '많다': 34, '서울': 100, '받다': 44, '좌파': 33, '아들': 49, '모르다': 69, '사회주의': 58, '보다': 122, '무슨': 34, '넘다': 38, '시민': 57, '쓰다': 53, '지다': 76, '재산': 50, '사다': 34, '세금': 265, '걷다': 53, '아파트': 77, '규제': 32, '부동산': 191, '가격': 40, '폭등': 33, '만들다': 76, '종부세': 132, '정권': 80, '잡다': 81, '좋다': 48, '북한': 32, '국민': 134, '들이다': 39, '먹다': 55, '나라': 81, '집값': 146, '하나': 49, '서민': 48, '올리다': 146, '서울시장': 62, '주다': 36, '유세': 64, '이상': 56, '이제': 36, '뽑다': 60, '경제': 32, '주택': 93, '시키다': 60, '국가': 36, '선진국': 37, '생각': 81, '오르다': 105, '투기': 103, '맞다': 50, '월세': 40, '전세': 64, '보유': 36, '해보다': 36, '원숭이': 98, '내다': 98, '가지다': 38, '공급': 64, '살다': 101, '진짜': 42, '공산주의': 41, '빨갱이': 38, '미치다': 41, '소리': 53, '알다': 52, '강남': 40, '서다': 34, '정도': 32, '정책': 157, '정부': 78, '나오다': 43, '들다': 70, '올려놓다': 32, '가다': 41, '인간': 61, '문재인': 42, '정신': 31, '거래': 32}

# %%
#워드 클라우드
# WordCloud 패키지를 import 합니다.
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image # 만약 "No module named 'PIL'" 에러가 발생하면 [ pip install Pillow==5.4.1 ] 로 라이브러리를 설치해줍니다.

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# WordCloud 객체를 생성합니다.
# 아래 보이는 코드의 font_path 에 해당하는 부분이 워드클라우드의 폰트에 적용됩니다. (대체로 고딕 계열 폰트가 이쁘게 나옵니다)
# 만약 다른 폰트를 적용하려면, C > Windows > Fonts 폴더에 원하시는 폰트 파일(.ttf)을 넣은 후 아래 코드에서 font 이름을 수정해줍니다.

word_cloud = WordCloud(font_path="fonts/malgun.ttf", 
                       width=2000, height=1000, # 이 부분을 수정하시면 실제 워드클라우드의 크기가 바뀝니다 (해상도가 바뀝니다)
                       # prefer_horizontal= 1.0, # 이 부분의 주석을 해제하시면 단어들이 가로로만 그려지게 됩니다. (0~1)
                       background_color='white')

# %%
word_cloud.generate_from_frequencies(word_dic) # Generate wordcloud from word "frequency" data.

# %%
# # 생성한 WordCloud 객체로부터 워드클라우드를 보여주는 코드입니다.

# plt.figure(figsize=(15,15)) # 이 부분을 수정하시면 화면에서 보여지는 워드클라우드의 크기가 바뀝니다 
# plt.imshow(word_cloud) # image show
# plt.axis("off")
# plt.tight_layout(pad=0)
# plt.show()

# %%
# word_cloud.to_file("word_cloud.png")

# %%
from wordcloud import ImageColorGenerator # Image 로부터 Color 를 생성(Generate)해내는 객체입니다.

coloring = np.array(Image.open("./yellow-house.png"))
image_colors = ImageColorGenerator(coloring)

word_cloud = WordCloud(font_path="fonts/malgun.ttf", 
                       width=2000, height=1000,  
                       mask=coloring, 
                       background_color='white').generate_from_frequencies(word_dic)

plt.figure(figsize=(15,15))
plt.imshow(word_cloud.recolor(color_func=image_colors), interpolation='bilinear') # 다시(re) 색칠하기
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
word_cloud.to_file("word_cloud_coloring.png")

# %%
# coloring = np.array(Image.open("./yellow-house.png"))
# image_colors = ImageColorGenerator(coloring)

# word_cloud = WordCloud(font_path="fonts/malgun.ttf", # font_path="C:/Windows/Fonts/NanumSquareB.ttf"
#                        width=2000, height=1000,  
#                        mask=coloring, 
#                        background_color='white').generate(doc)

# plt.figure(figsize=(15,15)) # 이 부분을 수정하시면 화면에서 보여지는 워드클라우드의 크기가 바뀝니다 
# plt.imshow(word_cloud) # image show
# plt.axis("off")
# plt.tight_layout(pad=0)
# plt.show()
