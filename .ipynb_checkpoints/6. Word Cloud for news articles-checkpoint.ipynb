# %% [markdown]
# <br>
# <br>
#
# ## 1. 텍스트 데이터 분석을 위한 라이브러리 설치 및 세팅

# %% [markdown]
# <br>
#
# ### 1-1) NLTK 설치

# %% [markdown]
# - Text Processing을 위한 라이브러리인 **nltk** library(Natural Language Toolkit)를 설치 및 세팅합니다.

# %%
# !pip install nltk==3.4
# Out:
# Requirement already satisfied: nltk==3.4 in c:\programdata\anaconda3\lib\site-packages (3.4)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from nltk==3.4) (1.12.0)
# Requirement already satisfied: singledispatch in c:\programdata\anaconda3\lib\site-packages (from nltk==3.4) (3.4.0.3)

# %%
import nltk

# %% [markdown]
# 아래 명령어를 통해 download 대화상자를 열어 패키지를 다운로드 받아야 합니다.
# <br>인터넷 속도 저하 시 매우 오래 걸리므로, 패키지 설치 경로만 확인한 다음 \[ (nltk, downloaded) nltk_data.zip ] 의 파일들을 복사합니다.
# <br><br>경로 예시 : **"C:\Users\{컴퓨터 이름}\AppData\Roaming\nltk_data"**
# <br>
# **<p style='color:red;'>nltk_data 폴더 안에 corpora, taggers, tokenizers 폴더가 바로 위치하도록 복사해줘야 합니다.</p>**

# %%
# nltk.download()  # 텍스트 데이터 처리를 위한 패키지 다운로더

# Download following packages
# Corpora : stopwords, wordnet
# Models : averaged_perceptron_tagger, maxnet_treebank_pos_tagger, punkt

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <br>
#
# ### 1-2) NLTK 테스트

# %%
# 전처리하고자 하는 문장을 String 변수로 저장한다
sentence = 'NLTK is a leading platform for building Python programs to work with human language data. It provides easy-to-use interfaces to over 50 corpora and lexical resources such as WordNet, along with a suite of text processing libraries for classification, tokenization, stemming, tagging, parsing, and semantic reasoning, wrappers for industrial-strength NLP libraries, and an active discussion forum.'

# 각 문장을 토큰화한 결과를 출력한다
nltk.word_tokenize(sentence)[:10]  # 문장을 '단어 수준에서' 토큰화해 출력한다
# Out:
# ['NLTK',
#  'is',
#  'a',
#  'leading',
#  'platform',
#  'for',
#  'building',
#  'Python',
#  'programs',
#  'to']

# %% [markdown]
# <br>
#
# ### 1-3) Konlpy 설치

# %% [markdown]
# #### 1) Microsoft Build Tools 2015 를 설치합니다.
#
# - 첨부해드린 **BuildTools_Full.exe** 파일을 실행하여 Microsoft Build Tools 2015 를 설치해줍니다.
# <br><br>
#
# #### 2) Java SE Development Kit (JDK) 를 설치합니다.
#
# - 첨부해드린 **jdk-8u221-windows-x64.exe** 파일을 실행하여 JDK 를 설치해줍니다. (설정을 모두 그대로 유지한 채 설치해주셔야 합니다.)
# - Mac OS 사용자는 http://j.mp/2lBBj1h 에서 OS 버전에 맞는 설치 파일을 다운로드하여 설치합니다.
# <br><br>
#
# #### 3) 설치가 완료되면 아래 2개의 셀을 차례대로 실행하여 JPype1과 konlpy를 설치해줍니다.

# %%
# !pip install JPype1-0.6.3-cp37-cp37m-win_amd64.whl
# Mac OS 사용자는 https://www.lfd.uci.edu/~gohlke/pythonlibs/#jpype 에서 OS 버전에 맞는 .whl 파일을 다운로드합니다. 
# * JPype1 0.6.3 버전으로 선택합니다.
# * cp37 == Python 3.7.x 버전
# Out:
# Requirement already satisfied: JPype1==0.6.3 from file:///C:/Users/student/%EA%B9%80%EC%B1%84%EC%9C%A4/Part%203/%EC%8B%A4%EC%8A%B5%20%ED%8C%8C%EC%9D%BC/2-1.%20Advanced%20scraping%20%26%20Wordcloud%20%28Problem%29/JPype1-0.6.3-cp37-cp37m-win_amd64.whl in c:\programdata\anaconda3\lib\site-packages (0.6.3)

# %%
# !pip install konlpy==0.5.1
# Out:
# Requirement already satisfied: konlpy==0.5.1 in c:\programdata\anaconda3\lib\site-packages (0.5.1)
# Requirement already satisfied: JPype1>=0.5.7 in c:\programdata\anaconda3\lib\site-packages (from konlpy==0.5.1) (0.6.3)

# %% [markdown]
# <br>
#
# ### 1-4) Konlpy 테스트

# %%
# Twitter 라이브러리가 정상적으로 작동하는지 확인합니다.
from konlpy.tag import Twitter

twitter = Twitter()
malist = twitter.pos("아버지 가방에 들어가신다.", norm=True, stem=True)
print(malist)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# [('아버지', 'Noun'), ('가방', 'Noun'), ('에', 'Josa'), ('들어가다', 'Verb'), ('.', 'Punctuation')]

# %% [markdown]
# <br>
# <br>
#
# ## 2. 크롤링 데이터 전처리

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <br>
#
# ### 2-1) 크롤링 데이터 불러오기

# %%
df = pd.read_excel('result_190729_0552.xlsx', encoding='utf-8')
df.head()

# df['Article']
# Out:
#                                   Title                 Date  \
# 0  "6살 한국 유튜버 90억원 건물 매입" CNN '보람튜브' 소개  2019.07.27. 오후 5:18
# 1     CNN도 주목한 '보람튜브'…"아동 유튜버, 과거에도 논란"  2019.07.27. 오후 4:03
# 2         CNN, '보람튜브' 주목… "아동유튜버 논란 우려"  2019.07.27. 오후 5:39
# 3              '보람튜브 빌딩 매입'보다 주목해야 할 사실  2019.07.27. 오후 4:54
# 4  [오태훈의 시사본부] 강남 빌딩 매입한 ‘보람튜브’ 고수익의 비밀  2019.07.26. 오후 3:42
#
#                                              Article  \
# 0  【서울=뉴시스】CNN이 27일 한국의 인기 아동 유튜브 콘텐츠 '보람채널'의 흥행을...
# 1  보람튜브 갈무리 © 뉴스1(서울=뉴스1) 이원준 기자 = 유명 유튜브 채널 '보람튜...
# 2  /사진=보람튜브 유튜브채널 캡처유명 유튜브채널 ‘보람튜브’에 대해 외신들도 주목하기...
# 3  키즈콘텐츠 성공, 영유아 시청시간에 비례…스마트폰 ‘과의존’ 아이들 늘었다 영유아기...
# 4  - 보람튜브 위상 어마어마해…해외 크리에이터와 견줘도 뒤쳐지지 않는 글로벌 콘텐츠 ...
#
#                                                  URL PressCompany
# 0  https://news.naver.com/main/read.nhn?mode=LSD&...          뉴시스
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...          뉴스1
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...          머니S
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...        미디어오늘
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...          KBS

# %%
articles = df['Article'].tolist()
len(articles)
# Out:
# 57

# %%
s = 'python is easy'
result = s.split()
print(result)

new_result = '___'.join(result)
print(new_result)
# Out:
# ['python', 'is', 'easy']
# python___is___easy

# %%
articles = ''.join(articles) # 리스트의 아이템들을 특정한 문자를 기준으로 이어 붙이기
articles[:1000]
# Out:
# "【서울=뉴시스】CNN이 27일 한국의 인기 아동 유튜브 콘텐츠 '보람채널'의 흥행을 소개하는 기사를 실었다. 사진은 CNN 인터넷판 보도내용을 갈무리한 것이다. 2019.07.27【서울=뉴시스】우은식 기자 = CNN이 한국의 아동용 인기 유튜브 콘텐츠 '보람튜브'의 흥행과 최근 부동산 매입 소식을 소개하는 기사를 실었다.CNN은 26일(현지시간) 3000만명의 구독자수를 가진 한국의 6살 유튜브 스타가 최근 95억원에 달하는 서울의 5층짜리 부동산 건물을 사들였다고 보도했다. 보람채널에 출연하는 이보람(6)양은 1360만명의 구독자가 있는 '보람튜브 토이리뷰'와 1760만명의 구독자가 있는 '보람튜브 브이로그' 2개 채널의 주인공이다. 보람양 부모가 설립한 ㈜보람패밀리는 지난 4월 서울 강남구 청담동에 있는 D빌딩을 95억원에 사들인 것으로 알려졌다.  부동산 업계와 인터넷등기소에 따르면 보람패밀리는 대지면적 258.3㎡에 지하 1층, 지상 5층 규모의 빌딩을 단독으로 매입했다. CNN은 보람튜브가 지난 2017년 일부 콘텐츠가 아동들의 정서와 윤리에 악영향을 미친다며 소송을 당한 사실을 소개하기도 했다. 유튜브 분석사이트인 소셜블레이드에 따르면 보람패밀리는 '보람튜브 토이리뷰'와 '보람튜브 브이로그' 등 2개 채널을 통해 각각 월 160만달러(19억원)와 150만달러(17억8000만원) 등 총 37억원 이상의 광고매출을 내는 등 국내 유튜브 콘텐츠 중 가장 많은 광고수익을 올리는 것으로 알려졌다.  포브스에 따르면 지난해 가장 많은 수입을 올린 유튜버는 라이언 토이즈리뷰의 진행자 라이언 카지(7)로 그 역시 7살 소년이었다. 라이언은 지난해 2080만명의 구독자수를 기록하며 2200만달러(260억6000만원)를 벌어들였다. 미 가족 유튜브 채널 '트라브&코'에 출연하는 아동 유튜브 스타 타이더스(5)는 310만명의 구독자수를 기록하고 있다. 유튜버는 비디오 콘텐츠에 삽입되는 광고 수익과 함께 제품 노출, 브랜드 제휴 등 다양한 방법으로 돈을 벌 수 있다. 유"

# %% [markdown]
# <br>
#
# ### 2-2) 단어 정규화 및 어근화, 품사 태깅

# %%
# input data 에 품사를 태깅(tagging)합니다.
# 이 때, stem 및 norm 옵션의 기능은 다음과 같습니다.

# norm == 정규화(normalization)
# 한국어를 처리하는 예시입니닼ㅋㅋㅋ -> 한국어를 처리하는 예시입니다ㅋㅋ

# stem == 어근화(stemming)
# 한국어를 처리하는 예시입니다 ㅋㅋ -> 한국어Noun, 를Josa, 처리Noun, 하다Verb, 예시Noun, 이다Adjective, ㅋㅋKoreanParticle

from konlpy.tag import Twitter

twitter = Twitter()
raw_pos_tagged = twitter.pos(articles, norm=True, stem=True) # POS Tagging
raw_pos_tagged
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# [('【', 'Foreign'),
#  ('서울', 'Noun'),
#  ('=', 'Punctuation'),
#  ('뉴시스', 'Noun'),
#  ('】', 'Foreign'),
#  ('CNN', 'Alpha'),
#  ('이', 'Noun'),
#  ('27일', 'Number'),
#  ('한국', 'Noun'),
#  ('의', 'Josa'),
#  ('인기', 'Noun'),
#  ('아동', 'Noun'),
#  ('유튜브', 'Noun'),
#  ('콘텐츠', 'Noun'),
#  ("'", 'Punctuation'),
#  ('보람', 'Noun'),
#  ('채널', 'Noun'),
#  ("'", 'Punctuation'),
#  ('의', 'Noun'),
#  ('흥행', 'Noun'),
#  ('을', 'Josa'),
#  ('소개', 'Noun'),
#  ('하다', 'Verb'),
#  ('기사', 'Noun'),
#  ('를', 'Josa'),
#  ('실었다', 'Noun'),
#  ('.', 'Punctuation'),
#  ('사진', 'Noun'),
#  ('은', 'Josa'),
#  ('CNN', 'Alpha'),
#  ('인터넷', 'Noun'),
#  ('판', 'Noun'),
#  ('보도', 'Noun'),
#  ('내용', 'Noun'),
#  ('을', 'Josa'),
#  ('갈무리', 'Noun'),
#  ('한', 'Josa'),
#  ('것', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('2019.07', 'Number'),
#  ('.', 'Punctuation'),
#  ('27', 'Number'),
#  ('【', 'Foreign'),
#  ('서울', 'Noun'),
#  ('=', 'Punctuation'),
#  ('뉴시스', 'Noun'),
#  ('】', 'Foreign'),
#  ('우', 'Adverb'),
#  ('은', 'Noun'),
#  ('식', 'Suffix'),
#  ('기자', 'Noun'),
#  ('=', 'Punctuation'),
#  ('CNN', 'Alpha'),
#  ('이', 'Noun'),
#  ('한국', 'Noun'),
#  ('의', 'Josa'),
#  ('아동', 'Noun'),
#  ('용', 'Noun'),
#  ('인기', 'Noun'),
#  ('유튜브', 'Noun'),
#  ('콘텐츠', 'Noun'),
#  ("'", 'Punctuation'),
#  ('보람', 'Noun'),
#  ('튜브', 'Noun'),
#  ("'", 'Punctuation'),
#  ('의', 'Noun'),
#  ('흥행', 'Noun'),
#  ('과', 'Josa'),
#  ('최근', 'Noun'),
#  ('부동산', 'Noun'),
#  ('매입', 'Noun'),
#  ('소식', 'Noun'),
#  ('을', 'Josa'),
#  ('소개', 'Noun'),
#  ('하다', 'Verb'),
#  ('기사', 'Noun'),
#  ('를', 'Josa'),
#  ('실었다', 'Noun'),
#  ('.', 'Punctuation'),
#  ('CNN', 'Alpha'),
#  ('은', 'Noun'),
#  ('26일', 'Number'),
#  ('(', 'Punctuation'),
#  ('현지', 'Noun'),
#  ('시간', 'Noun'),
#  (')', 'Punctuation'),
#  ('3000만', 'Number'),
#  ('명의', 'Foreign'),
#  ('구독', 'Noun'),
#  ('자수', 'Noun'),
#  ('를', 'Josa'),
#  ('가지다', 'Verb'),
#  ('한국', 'Noun'),
#  ('의', 'Josa'),
#  ('6', 'Number'),
#  ('살', 'Noun'),
#  ('유튜브', 'Noun'),
#  ('스타', 'Noun'),
#  ('가', 'Josa'),
#  ('최근', 'Noun'),
#  ('95억원', 'Number'),
#  ('에', 'Foreign'),
#  ('달', 'Noun'),
#  ('하다', 'Verb'),
#  ('서울', 'Noun'),
#  ('의', 'Josa'),
#  ('5', 'Number'),
#  ('층', 'Noun'),
#  ('짜다', 'Verb'),
#  ('부동산', 'Noun'),
#  ('건물', 'Noun'),
#  ('을', 'Josa'),
#  ('사들이다', 'Verb'),
#  ('보도', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('보람', 'Noun'),
#  ('채널', 'Noun'),
#  ('에', 'Josa'),
#  ('출연', 'Noun'),
#  ('하다', 'Verb'),
#  ('이보람', 'Noun'),
#  ('(', 'Punctuation'),
#  ('6', 'Number'),
#  (')', 'Punctuation'),
#  ('양은', 'Noun'),
#  ('1360만', 'Number'),
#  ('명의', 'Foreign'),
#  ('구', 'Modifier'),
#  ('독자', 'Noun'),
#  ('가', 'Josa'),
#  ('있다', 'Adjective'),
#  ("'", 'Punctuation'),
#  ('보람', 'Noun'),
#  ('튜브', 'Noun'),
#  ('토이', 'Noun'),
#  ('리뷰', 'Noun'),
#  ("'", 'Punctuation'),
#  ('오다', 'Verb'),
#  ('1760만', 'Number'),
#  ('명의', 'Foreign'),
#  ('구', 'Modifier'),
#  ('독자', 'Noun'),
#  ('가', 'Josa'),
#  ('있다', 'Adjective'),
#  ("'", 'Punctuation'),
#  ('보람', 'Noun'),
#  ('튜브', 'Noun'),
#  ('브이', 'Noun'),
#  ('로그', 'Noun'),
#  ("'", 'Punctuation'),
#  ('2', 'Number'),
#  ('개', 'Noun'),
#  ('채널', 'Noun'),
#  ('의', 'Josa'),
#  ('주인공', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('보람', 'Noun'),
#  ('양', 'Suffix'),
#  ('부모', 'Noun'),
#  ('가', 'Josa'),
#  ('설립', 'Noun'),
#  ('한', 'Josa'),
#  ('㈜', 'Foreign'),
#  ('보람', 'Noun'),
#  ('패밀리', 'Noun'),
#  ('는', 'Josa'),
#  ('지난', 'Noun'),
#  ('4월', 'Number'),
#  ('서울', 'Noun'),
#  ('강남구', 'Noun'),
#  ('청담동', 'Noun'),
#  ('에', 'Josa'),
#  ('있다', 'Adjective'),
#  ('D', 'Alpha'),
#  ('빌딩', 'Noun'),
#  ('을', 'Josa'),
#  ('95억원', 'Number'),
#  ('에', 'Foreign'),
#  ('사들이다', 'Verb'),
#  ('것', 'Noun'),
#  ('으로', 'Josa'),
#  ('알려지다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('부동산', 'Noun'),
#  ('업계', 'Noun'),
#  ('와', 'Josa'),
#  ('인터넷', 'Noun'),
#  ('등기', 'Noun'),
#  ('소', 'Noun'),
#  ('에', 'Josa'),
#  ('따르다', 'Verb'),
#  ('보람', 'Noun'),
#  ('패밀리', 'Noun'),
#  ('는', 'Josa'),
#  ('대지면적', 'Noun'),
#  ('258.3', 'Number'),
#  ('㎡', 'Foreign'),
#  ('에', 'Josa'),
#  ('지하', 'Noun'),
#  ('1', 'Number'),
#  ('층', 'Noun'),
#  (',', 'Punctuation'),
#  ('지상', 'Noun'),
#  ('5', 'Number'),
#  ('층', 'Noun'),
#  ('규모', 'Noun'),
#  ('의', 'Josa'),
#  ('빌딩', 'Noun'),
#  ('을', 'Josa'),
#  ('단독', 'Noun'),
#  ('으로', 'Josa'),
#  ('매입', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('CNN', 'Alpha'),
#  ('은', 'Noun'),
#  ('보람', 'Noun'),
#  ('튜브', 'Noun'),
#  ('가', 'Josa'),
#  ('지난', 'Noun'),
#  ('2017년', 'Number'),
#  ('일부', 'Noun'),
#  ('콘텐츠', 'Noun'),
#  ('가', 'Josa'),
#  ('아동', 'Noun'),
#  ('들', 'Suffix'),
#  ('의', 'Josa'),
#  ('정서', 'Noun'),
#  ('와', 'Josa'),
#  ('윤리', 'Noun'),
#  ('에', 'Josa'),
#  ('악', 'Noun'),
#  ('영향', 'Noun'),
#  ('을', 'Josa'),
#  ('미치다', 'Adjective'),
#  ('소송', 'Noun'),
#  ('을', 'Josa'),
#  ('당한', 'Noun'),
#  ('사실', 'Noun'),
#  ('을', 'Josa'),
#  ('소개', 'Noun'),
#  ('하다', 'Verb'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('유튜브', 'Noun'),
#  ('분석', 'Noun'),
#  ('사이트', 'Noun'),
#  ('인', 'Josa'),
#  ('소셜', 'Noun'),
#  ('블레이드', 'Noun'),
#  ('에', 'Josa'),
#  ('따르다', 'Verb'),
#  ('보람', 'Noun'),
#  ('패밀리', 'Noun'),
#  ('는', 'Josa'),
#  ("'", 'Punctuation'),
#  ('보람', 'Noun'),
#  ('튜브', 'Noun'),
#  ('토이', 'Noun'),
#  ('리뷰', 'Noun'),
#  ("'", 'Punctuation'),
#  ('오다', 'Verb'),
#  ("'", 'Punctuation'),
#  ('보람', 'Noun'),
#  ('튜브', 'Noun'),
#  ('브이', 'Noun'),
#  ('로그', 'Noun'),
#  ("'", 'Punctuation'),
#  ('등', 'Noun'),
#  ('2', 'Number'),
#  ('개', 'Noun'),
#  ('채널', 'Noun'),
#  ('을', 'Josa'),
#  ('통해', 'Noun'),
#  ('각각', 'Noun'),
#  ('월', 'Noun'),
#  ('160만달러', 'Number'),
#  ('(', 'Punctuation'),
#  ('19억원', 'Number'),
#  (')', 'Punctuation'),
#  ('오다', 'Verb'),
#  ('150만달러', 'Number'),
#  ('(', 'Punctuation'),
#  ('17억', 'Number'),
#  ('8000만원', 'Number'),
#  (')', 'Punctuation'),
#  ('등', 'Noun'),
#  ('총', 'Noun'),
#  ('37억원', 'Number'),
#  ('이상', 'Noun'),
#  ('의', 'Josa'),
#  ('광고', 'Noun'),
#  ('매출', 'Noun'),
#  ('을', 'Josa'),
#  ('내다', 'Verb'),
#  ('등', 'Noun'),
#  ('국내', 'Noun'),
#  ('유튜브', 'Noun'),
#  ('콘텐츠', 'Noun'),
#  ('중', 'Noun'),
#  ('가장', 'Noun'),
#  ('많다', 'Adjective'),
#  ('광고', 'Noun'),
#  ('수익', 'Noun'),
#  ('을', 'Josa'),
#  ('올리다', 'Verb'),
#  ('것', 'Noun'),
#  ('으로', 'Josa'),
#  ('알려지다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('포브스', 'Noun'),
#  ('에', 'Josa'),
#  ('따르다', 'Verb'),
#  ('지난해', 'Noun'),
#  ('가장', 'Noun'),
#  ('많다', 'Adjective'),
#  ('수입', 'Noun'),
#  ('을', 'Josa'),
#  ('올리다', 'Verb'),
#  ('유튜버', 'Noun'),
#  ('는', 'Josa'),
#  ('라이언', 'Noun'),
#  ('토이', 'Noun'),
#  ('즈', 'Modifier'),
#  ('리뷰', 'Noun'),
#  ('의', 'Josa'),
#  ('진행자', 'Noun'),
#  ('라이언', 'Noun'),
#  ('카', 'Noun'),
#  ('지', 'Josa'),
#  ('(', 'Punctuation'),
#  ('7', 'Number'),
#  (')', 'Punctuation'),
#  ('로', 'Noun'),
#  ('그', 'Noun'),
#  ('역시', 'Noun'),
#  ('7', 'Number'),
#  ('살', 'Noun'),
#  ('소년', 'Noun'),
#  ('이다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('라이언', 'Noun'),
#  ('은', 'Josa'),
#  ('지난해', 'Noun'),
#  ('2080만', 'Number'),
#  ('명의', 'Foreign'),
#  ('구독', 'Noun'),
#  ('자수', 'Noun'),
#  ('를', 'Josa'),
#  ('기록', 'Noun'),
#  ('하다', 'Verb'),
#  ('2200만달러', 'Number'),
#  ('(', 'Punctuation'),
#  ('260억', 'Number'),
#  ('6000만원', 'Number'),
#  (')', 'Punctuation'),
#  ('를', 'Noun'),
#  ('벌다', 'Verb'),
#  ('들이다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('밉다', 'Adjective'),
#  ('가족', 'Noun'),
#  ('유튜브', 'Noun'),
#  ('채널', 'Noun'),
#  ("'", 'Punctuation'),
#  ('트라브', 'Noun'),
#  ('&', 'Punctuation'),
#  ('코', 'Noun'),
#  ("'", 'Punctuation'),
#  ('에', 'Josa'),
#  ('출연', 'Noun'),
#  ('하다', 'Verb'),
#  ('아동', 'Noun'),
#  ('유튜브', 'Noun'),
#  ('스타', 'Noun'),
#  ('타이', 'Noun'),
#  ('더스', 'Noun'),
#  ('(', 'Punctuation'),
#  ('5', 'Number'),
#  (')', 'Punctuation'),
#  ('늘다', 'Verb'),
#  ('310만', 'Number'),
#  ('명의', 'Foreign'),
#  ('구독', 'Noun'),
#  ('자수', 'Noun'),
#  ('를', 'Josa'),
#  ('기록', 'Noun'),
#  ('하고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('유튜버', 'Noun'),
#  ('는', 'Josa'),
#  ('비디오', 'Noun'),
#  ('콘텐츠', 'Noun'),
#  ('에', 'Josa'),
#  ('삽입', 'Noun'),
#  ('되다', 'Verb'),
#  ('광고', 'Noun'),
#  ('수익', 'Noun'),
#  ('과', 'Josa'),
#  ('함께', 'Adverb'),
#  ('제품', 'Noun'),
#  ('노출', 'Noun'),
#  (',', 'Punctuation'),
#  ('브랜드', 'Noun'),
#  ('제휴', 'Noun'),
#  ('등', 'Noun'),
#  ('다양하다', 'Adjective'),
#  ('방법', 'Noun'),
#  ('으로', 'Josa'),
#  ('돈', 'Noun'),
#  ('을', 'Josa'),
#  ('벌', 'Noun'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('유튜브', 'Noun'),
#  ('관계자', 'Noun'),
#  ('는', 'Josa'),
#  ('CNN', 'Alpha'),
#  ('에', 'Josa'),
#  ('미성년', 'Noun'),
#  ('자', 'Suffix'),
#  ('출연', 'Noun'),
#  ('콘텐츠', 'Noun'),
#  ('와', 'Josa'),
#  ('관련', 'Noun'),
#  ('되다', 'Verb'),
#  ('아동학대', 'Noun'),
#  ('논란', 'Noun'),
#  ('과', 'Josa'),
#  ('관련', 'Noun'),
#  ('"', 'Punctuation'),
#  ('수천', 'Noun'),
#  ('건의', 'Noun'),
#  ('부적절하다', 'Adjective'),
#  ('댓글', 'Noun'),
#  ('을', 'Josa'),
#  ('검토', 'Noun'),
#  ('하다', 'Verb'),
#  ('삭제', 'Noun'),
#  ('하다', 'Verb'),
#  ('아동학대', 'Noun'),
#  ('와', 'Josa'),
#  ('관련', 'Noun'),
#  ('있다', 'Adjective'),
#  ('400', 'Number'),
#  ('여개', 'Noun'),
#  ('채널', 'Noun'),
#  ('은', 'Josa'),
#  ('중단', 'Noun'),
#  ('하다', 'Verb'),
#  ('"', 'Punctuation'),
#  ('고', 'Noun'),
#  ('밝히다', 'Verb'),
#  ('.eswoo@newsis.com', 'Email'),
#  ('▶', 'Foreign'),
#  ('네이버', 'Noun'),
#  ('에서', 'Josa'),
#  ('뉴시스', 'Noun'),
#  ('채널', 'Noun'),
#  ('구독', 'Noun'),
#  ('하다', 'Verb'),
#  ('▶', 'Foreign'),
#  ('뉴시스', 'Noun'),
#  ('빅데이터', 'Noun'),
#  ('MSI', 'Alpha'),
#  ('주가', 'Noun'),
#  ('시세', 'Noun'),
#  ('표', 'Noun'),
#  ('바로가기', 'Noun'),
#  ('<', 'Punctuation'),
#  ('저작권', 'Noun'),
#  ('자', 'Suffix'),
#  ('ⓒ', 'Foreign'),
#  ('공감', 'Noun'),
#  ('언론', 'Noun'),
#  ('뉴시스', 'Noun'),
#  ('통신사', 'Noun'),
#  ('.', 'Punctuation'),
#  ('무단', 'Noun'),
#  ('전', 'Modifier'),
#  ('재', 'Noun'),
#  ('-', 'Punctuation'),
#  ('재', 'Noun'),
#  ('배포', 'Noun'),
#  ('금지', 'Noun'),
#  ('.>', 'Punctuation'),
#  ('보람', 'Noun'),
#  ('튜브', 'Noun'),
#  ('갈무리', 'Noun'),
#  ('©', 'Foreign'),
#  ('뉴스', 'Noun'),
#  ('1', 'Number'),
#  ('(', 'Punctuation'),
#  ('서울', 'Noun'),
#  ('=', 'Punctuation'),
#  ('뉴스', 'Noun'),
#  ('1', 'Number'),
#  (')', 'Punctuation'),
#  ('이원준', 'Noun'),
#  ('기자', 'Noun'),
#  ('=', 'Punctuation'),
#  ('유명', 'Noun'),
#  ('유튜브', 'Noun'),
#  ('채널', 'Noun'),
#  ("'", 'Punctuation'),
#  ('보람', 'Noun'),
#  ('튜브', 'Noun'),
#  ("'", 'Punctuation'),
#  ('의', 'Noun'),
#  ('주인공', 'Noun'),
#  ('이보람', 'Noun'),
#  ('(', 'Punctuation'),
#  ('6', 'Number'),
#  (')', 'Punctuation'),
#  ('양', 'Noun'),
#  ('을', 'Josa'),
#  ('둘러싸다', 'Verb'),
#  ('아동학대', 'Noun'),
#  ('등', 'Noun'),
#  ('논란', 'Noun'),
#  ('은', 'Josa'),
#  ('외신', 'Noun'),
#  ('에서도', 'Josa'),
#  ('주목', 'Noun'),
#  ('받다', 'Verb'),
#  ('있다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('26일', 'Number'),
#  ('(', 'Punctuation'),
#  ('현지', 'Noun'),
#  ('시간', 'Noun'),
#  (')', 'Punctuation'),
#  ('미국', 'Noun'),
#  ('CNN', 'Alpha'),
#  ('방송', 'Noun'),
#  ('은', 'Josa'),
#  ('"', 'Punctuation'),
#  ('3천만', 'Number'),
#  ('명의', 'Foreign'),
#  ('구', 'Modifier'),
#  ('독자', 'Noun'),
#  ('를', 'Josa'),
#  ('보유', 'Noun'),
#  ('한', 'Josa'),
#  ('6', 'Number'),
#  ('살', 'Noun'),
#  ('한국', 'Noun'),
#  ('의', 'Josa'),
#  ('유튜브', 'Noun'),
#  ('스타', 'Noun'),
#  ('가', 'Josa'),
#  ('서울', 'Noun'),
#  ('에', 'Josa'),
#  ('있다', 'Adjective'),
#  ('수백만', 'Modifier'),
#  ('달러', 'Noun'),
#  ('짜다', 'Verb'),
#  ('5', 'Number'),
#  ('층', 'Noun'),
#  ('빌딩', 'Noun'),
#  ('을', 'Josa'),
#  ('구입', 'Noun'),
#  ('하다', 'Verb'),
#  ('"', 'Punctuation'),
#  ('며', 'Noun'),
#  ('관련', 'Noun'),
#  ('소식', 'Noun'),
#  ('을', 'Josa'),
#  ('소개', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('CNN', 'Alpha'),
#  ('은', 'Noun'),
#  ('보람', 'Noun'),
#  ('튜브', 'Noun'),
#  ('에', 'Josa'),
#  ('대해', 'Noun'),
#  ('"', 'Punctuation'),
#  ('조회', 'Noun'),
#  ('수만', 'Noun'),
#  ('3억', 'Number'),
#  ('7600만', 'Number'),
#  ('건이', 'Foreign'),
#  ('넘다', 'Verb'),
#  ('가장', 'Noun'),
#  ('인기', 'Noun'),
#  ('있다', 'Adjective'),
#  ('동영상', 'Noun'),
#  ('에서', 'Josa'),
#  ('보람', 'Noun'),
#  ('양은', 'Noun'),
#  ('장난감', 'Noun'),
#  ('주방', 'Noun'),
#  ('을', 'Josa'),
#  ('사용', 'Noun'),
#  ('하다', 'Verb'),
#  ('라면', 'Noun'),
#  ('을', 'Josa'),
#  ('만들다', 'Verb'),
#  ('다음', 'Noun'),
#  (',', 'Punctuation'),
#  ('카메라', 'Noun'),
#  ('앞', 'Noun'),
#  ('에서', 'Josa'),
#  ('열정', 'Noun'),
#  ('적', 'Suffix'),
#  ('으로', 'Josa'),
#  ('후루룩', 'Noun'),
#  ('먹다', 'Verb'),
#  ('"', 'Punctuation'),
#  ('며', 'Noun'),
#  ('그러나', 'Conjunction'),
#  ('영상', 'Noun'),
#  ('중', 'Noun'),
#  ('일부', 'Noun'),
#  ('는', 'Josa'),
#  ('한국', 'Noun'),
#  ('에서', 'Josa'),
#  ('논란', 'Noun'),
#  ('을', 'Josa'),
#  ('불러일으키다', 'Verb'),
#  ('있다', 'Adjective'),
#  ('전', 'Noun'),
#  ('하다', 'Verb'),
#  ('..', 'Punctuation'),
#  ('일례', 'Noun'),
#  ('로', 'Josa'),
#  ('CNN', 'Alpha'),
#  ('은', 'Noun'),
#  ('보람', 'Noun'),
#  ('튜브', 'Noun'),
#  ('가', 'Josa'),
#  ('2017년', 'Number'),
#  ('9월', 'Number'),
#  ('국제', 'Noun'),
#  ('구호', 'Noun'),
#  ('개발', 'Noun'),
#  ('단체', 'Noun'),
#  ('인', 'Josa'),
#  ('세이브더칠드런', 'Noun'),
#  ('측', 'Noun'),
#  ('에', 'Josa'),
#  ('고발', 'Noun'),
#  ('당', 'Suffix'),
#  ('한', 'Josa'),
#  ('사실', 'Noun'),
#  ('을', 'Josa'),
#  ('자세하다', 'Adjective'),
#  ('소개', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('당시', 'Noun'),
#  ('보람', 'Noun'),
#  ('양', 'Suffix'),
#  ('의', 'Josa'),
#  ('부모', 'Noun'),
#  ('는', 'Josa'),
#  ('서', 'Modifier'),
#  ('울', 'Modifier'),
#  ('가정법원', 'Noun'),
#  ('으로부터', 'Josa'),
#  ('아동', 'Noun'),
#  ('보호', 'Noun'),
#  ('전', 'Modifier'),
#  ('문', 'Modifier'),
#  ('기관', 'Noun'),
#  ('의', 'Josa'),
#  ('상담', 'Noun'),
#  ('을', 'Josa'),
#  ('받다', 'Verb'),
#  ('보호처분', 'Noun'),
#  ('을', 'Josa'),
#  ('받다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('또한', 'Noun'),
#  ('학대', 'Noun'),
#  ('논란', 'Noun'),
#  ('을', 'Josa'),
#  ('일으키다', 'Verb'),
#  ('영상', 'Noun'),
#  ('을', 'Josa'),
#  ('모두', 'Noun'),
#  ('비공개', 'Noun'),
#  ('로', 'Josa'),
#  ('전환', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('CNN', 'Alpha'),
#  ('은', 'Noun'),
#  ('"', 'Punctuation'),
#  ('유튜브', 'Noun'),
#  ('에서는', 'Josa'),
#  ('아동', 'Noun'),
#  ('스타', 'Noun'),
#  ('가', 'Josa'),
#  ('크다', 'Verb'),
#  ('사업', 'Noun'),
#  ('이', 'Josa'),
#  ('되다', 'Verb'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('"', 'Punctuation'),
#  ('며', 'Noun'),
#  ('미국', 'Noun'),
#  ('의', 'Josa'),
#  ('스타', 'Noun'),
#  ('유튜버', 'Noun'),
#  ('라이언', 'Noun'),
#  ('(', 'Punctuation'),
#  ('7', 'Number'),
#  (')', 'Punctuation'),
#  ('등', 'Noun'),
#  ('다른', 'Noun'),
#  ('사례', 'Noun'),
#  ('를', 'Josa'),
#  ('소개', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('라이언', 'Noun'),
#  ('은', 'Josa'),
#  ('새롭다', 'Adjective'),
#  ('나오다', 'Verb'),
#  ('장난감', 'Noun'),
#  ('을', 'Josa'),
#  ('소개', 'Noun'),
#  ('하다', 'Verb'),
#  ("'", 'Punctuation'),
#  ('라이언', 'Noun'),
#  ('토', 'Noun'),
#  ('이스', 'Noun'),
#  ('리뷰', 'Noun'),
#  ("'(", 'Punctuation'),
#  ('Ryan', 'Alpha'),
#  ('ToysReview', 'Alpha'),
#  (')', 'Punctuation'),
#  ('유튜브', 'Noun'),
#  ('채널', 'Noun'),
#  ('을', 'Josa'),
#  ('통해', 'Noun'),
#  ('2018년', 'Number'),
#  ('한해', 'Noun'),
#  ('2200만달러', 'Number'),
#  ('(', 'Punctuation'),
#  ('약', 'Noun'),
#  ('260억원', 'Number'),
#  (')', 'Punctuation'),
#  ('수익', 'Noun'),
#  ('을', 'Josa'),
#  ('올리다', 'Verb'),
#  ('것', 'Noun'),
#  ('으로', 'Josa'),
#  ('집계', 'Noun'),
#  ('돼다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('CNN', 'Alpha'),
#  ('은', 'Noun'),
#  ('"', 'Punctuation'),
#  ('과거', 'Noun'),
#  ('에도', 'Josa'),
#  ('사람', 'Noun'),
#  ('들', 'Suffix'),
#  ('은', 'Josa'),
#  ('아동', 'Noun'),
#  ('영상', 'Noun'),
#  ('을', 'Josa'),
#  ('둘러싸다', 'Verb'),
#  ('유튜브', 'Noun'),
#  ('의', 'Josa'),
#  ('정책', 'Noun'),
#  ('에', 'Josa'),
#  ('우려', 'Noun'),
#  ('를', 'Josa'),
#  ('표시', 'Noun'),
#  ('하다', 'Verb'),
#  ('"', 'Punctuation'),
#  ('며', 'Noun'),
#  ('소아성애', 'Noun'),
#  ('자', 'Suffix'),
#  ('가', 'Josa'),
#  ('해당', 'Noun'),
#  ('영상', 'Noun'),
#  ('을', 'Josa'),
#  ('악용', 'Noun'),
#  ('하다', 'Verb'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('우려', 'Noun'),
#  ('가', 'Josa'),
#  ('제기', 'Noun'),
#  ('돼다', 'Verb'),
#  ('적', 'Noun'),
#  ('이', 'Josa'),
#  ('있다', 'Adjective'),
#  ('부연', 'Noun'),
#  ('하다', 'Verb'),
#  ('.wonjun44@news1.kr', 'Email'),
#  ('▶', 'Foreign'),
#  ('[', 'Punctuation'),
#  ('크립', 'Noun'),
#  ('토', 'Noun'),
#  ('허브', 'Noun'),
#  (']', 'Punctuation'),
#  ('▶', 'Foreign'),
#  ('[', 'Punctuation'),
#  ('해', 'Noun'),
#  ('피펫', 'Noun'),
#  (']', 'Punctuation'),
#  ('▶', 'Foreign'),
#  ('네이버', 'Noun'),
#  ('메인', 'Noun'),
#  ('에서', 'Josa'),
#  ('[', 'Punctuation'),
#  ('뉴스', 'Noun'),
#  ('1', 'Number'),
#  (']', 'Punctuation'),
#  ('구독', 'Noun'),
#  ('하다', 'Verb'),
#  ('![', 'Punctuation'),
#  ('©', 'Foreign'),
#  ('뉴스', 'Noun'),
#  ('1', 'Number'),
#  ('코리아', 'Noun'),
#  ('(', 'Punctuation'),
#  ('news', 'Alpha'),
#  ('1', 'Number'),
#  ('.', 'Punctuation'),
#  ('kr', 'Alpha'),
#  ('),', 'Punctuation'),
#  ('무단', 'Noun'),
#  ('전', 'Modifier'),
#  ('재', 'Noun'),
#  ('및', 'Noun'),
#  ('재', 'Noun'),
#  ('배포', 'Noun'),
#  ('금지', 'Noun'),
#  (']/', 'Punctuation'),
#  ('사진', 'Noun'),
#  ('=', 'Punctuation'),
#  ('보람', 'Noun'),
#  ('튜브', 'Noun'),
#  ('유튜브', 'Noun'),
#  ('채널', 'Noun'),
#  ('캡처', 'Noun'),
#  ('유명', 'Noun'),
#  ('유튜브', 'Noun'),
#  ('채널', 'Noun'),
#  ('‘', 'Foreign'),
#  ('보람', 'Noun'),
#  ('튜브', 'Noun'),
#  ('’', 'Punctuation'),
#  ('에', 'Josa'),
#  ('대해', 'Noun'),
#  ('외신', 'Noun'),
#  ('들', 'Suffix'),
#  ('도', 'Josa'),
#  ('주목', 'Noun'),
#  ('하다', 'Verb'),
#  ('시작', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('해당', 'Noun'),
#  ('외신', 'Noun'),
#  ('들', 'Suffix'),
#  ('은', 'Josa'),
#  ('보람', 'Noun'),
#  ('튜브', 'Noun'),
#  ('의', 'Josa'),
#  ('주인공', 'Noun'),
#  ('이보람', 'Noun'),
#  ('(', 'Punctuation'),
#  ('6', 'Number'),
#  (')', 'Punctuation'),
#  ('양', 'Noun'),
#  ('에', 'Josa'),
#  ('대한', 'Noun'),
#  ('소식', 'Noun'),
#  ('을', 'Josa'),
#  ('전하', 'Noun'),
#  ('면서', 'Noun'),
#  ('아동', 'Noun'),
#  ('유튜', 'Noun'),
#  ('버들', 'Noun'),
#  ('이', 'Josa'),
#  ('학대', 'Noun'),
#  ('등', 'Noun'),
#  ('범죄', 'Noun'),
#  ('의', 'Josa'),
#  ('대상', 'Noun'),
#  ('으로', 'Josa'),
#  ('지목', 'Noun'),
#  ('되다', 'Verb'),
#  ('가능성', 'Noun'),
#  ('에', 'Josa'),
#  ('대해', 'Noun'),
#  ('우려', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('26일', 'Number'),
#  ('(', 'Punctuation'),
#  ('현지', 'Noun'),
#  ('시간', 'Noun'),
#  (')', 'Punctuation'),
#  ('미국', 'Noun'),
#  ('CNN', 'Alpha'),
#  ('방송', 'Noun'),
#  ('은', 'Josa'),
#  ('“', 'Foreign'),
#  ('3000만', 'Number'),
#  ('명의', 'Foreign'),
#  ('구', 'Modifier'),
#  ('독자', 'Noun'),
#  ('를', 'Josa'),
#  ('보유', 'Noun'),
#  ('한', 'Josa'),
#  ('한국', 'Noun'),
#  ('의', 'Josa'),
#  ('6', 'Number'),
#  ('살', 'Noun'),
#  ('유튜브', 'Noun'),
#  ('스타', 'Noun'),
#  ('가', 'Josa'),
#  ('서울', 'Noun'),
#  ('에', 'Josa'),
#  ('있다', 'Adjective'),
#  ('수백만', 'Modifier'),
#  ('달러', 'Noun'),
#  ('짜다', 'Verb'),
#  ('5', 'Number'),
#  ('층', 'Noun'),
#  ('빌딩', 'Noun'),
#  ('을', 'Josa'),
#  ('구입', 'Noun'),
#  ('하다', 'Verb'),
#  ('”', 'Foreign'),
#  ('며', 'Noun'),
#  ('보람', 'Noun'),
#  ('튜브', 'Noun'),
#  ('관련', 'Noun'),
#  ('소식', 'Noun'),
#  ('을', 'Josa'),
#  ('전', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('CNN', 'Alpha'),
#  ('은', 'Noun'),
#  ('“', 'Foreign'),
#  ('조회', 'Noun'),
#  ('수만', 'Noun'),
#  ('3억', 'Number'),
#  ('7600만', 'Number'),
#  ('건이', 'Foreign'),
#  ('넘다', 'Verb'),
#  ('인기', 'Noun'),
#  ('있다', 'Adjective'),
#  ('동영상', 'Noun'),
#  ('에서', 'Josa'),
#  ('보람', 'Noun'),
#  ('양은', 'Noun'),
#  ('장난감', 'Noun'),
#  ('주방', 'Noun'),
#  ('을', 'Josa'),
#  ('사용', 'Noun'),
#  ('하다', 'Verb'),
#  ('라면', 'Noun'),
#  ('을', 'Josa'),
#  ('만들다', 'Verb'),
#  ('다음', 'Noun'),
#  ('카메라', 'Noun'),
#  ('앞', 'Noun'),
#  ('에서', 'Josa'),
#  ('열정', 'Noun'),
#  ('적', 'Suffix'),
#  ('으로', 'Josa'),
#  ('먹다', 'Verb'),
#  ('”', 'Foreign'),
#  ('면서도', 'Eomi'),
#  ('영상', 'Noun'),
#  ('중', 'Noun'),
#  ('일부', 'Noun'),
#  ('는', 'Josa'),
#  ('한국', 'Noun'),
#  ('에서', 'Josa'),
#  ('논란', 'Noun'),
#  ('을', 'Josa'),
#  ('부르다', 'Verb'),
#  ('설명', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('일례', 'Noun'),
#  ('로', 'Josa'),
#  ('CNN', 'Alpha'),
#  ('은', 'Noun'),
#  ('보람', 'Noun'),
#  ('튜브', 'Noun'),
#  ('가', 'Josa'),
#  ...]

# %% [markdown]
# <br>
#
# ### 2-3) 단어 등장 빈도 카운팅

# %%
# 정규화 및 어근화를 마치고 품사 태깅까지 마친 상태에서,
# 조사, 어미, 구두점을 제외한 나머지 단어들을 모두 word_cleaned 리스트에 담습니다.
# 이 때에는 여러번 나온 단어들도 복수 허용되어 여러번 리스트에 담기게 됩니다.

# 유의미한 의미를 갖고 있지 않은 단어를 제외할 수 있습니다.
del_list = ['하다', '있다', '되다', '이다', '돼다', '않다', '그렇다', '아니다', '이렇다', '그렇다', '어떻다'] 

word_cleaned = []
for word in raw_pos_tagged: #  ('서울', 'Noun'),
    if not word[1] in ["Josa", "Eomi", "Punctuation", "Foreign"]: # Foreign == ”, “ 와 같이 제외되어야할 항목들
        if (len(word[0]) != 1) & (word[0] not in del_list): # 한 글자로 이뤄진 단어들을 제외 & 원치 않는 단어들을 제외
            word_cleaned.append(word[0])
        
word_cleaned
# Out:
# ['서울',
#  '뉴시스',
#  'CNN',
#  '27일',
#  '한국',
#  '인기',
#  '아동',
#  '유튜브',
#  '콘텐츠',
#  '보람',
#  '채널',
#  '흥행',
#  '소개',
#  '기사',
#  '실었다',
#  '사진',
#  'CNN',
#  '인터넷',
#  '보도',
#  '내용',
#  '갈무리',
#  '2019.07',
#  '27',
#  '서울',
#  '뉴시스',
#  '기자',
#  'CNN',
#  '한국',
#  '아동',
#  '인기',
#  '유튜브',
#  '콘텐츠',
#  '보람',
#  '튜브',
#  '흥행',
#  '최근',
#  '부동산',
#  '매입',
#  '소식',
#  '소개',
#  '기사',
#  '실었다',
#  'CNN',
#  '26일',
#  '현지',
#  '시간',
#  '3000만',
#  '구독',
#  '자수',
#  '가지다',
#  '한국',
#  '유튜브',
#  '스타',
#  '최근',
#  '95억원',
#  '서울',
#  '짜다',
#  '부동산',
#  '건물',
#  '사들이다',
#  '보도',
#  '보람',
#  '채널',
#  '출연',
#  '이보람',
#  '양은',
#  '1360만',
#  '독자',
#  '보람',
#  '튜브',
#  '토이',
#  '리뷰',
#  '오다',
#  '1760만',
#  '독자',
#  '보람',
#  '튜브',
#  '브이',
#  '로그',
#  '채널',
#  '주인공',
#  '보람',
#  '부모',
#  '설립',
#  '보람',
#  '패밀리',
#  '지난',
#  '4월',
#  '서울',
#  '강남구',
#  '청담동',
#  '빌딩',
#  '95억원',
#  '사들이다',
#  '알려지다',
#  '부동산',
#  '업계',
#  '인터넷',
#  '등기',
#  '따르다',
#  '보람',
#  '패밀리',
#  '대지면적',
#  '258.3',
#  '지하',
#  '지상',
#  '규모',
#  '빌딩',
#  '단독',
#  '매입',
#  'CNN',
#  '보람',
#  '튜브',
#  '지난',
#  '2017년',
#  '일부',
#  '콘텐츠',
#  '아동',
#  '정서',
#  '윤리',
#  '영향',
#  '미치다',
#  '소송',
#  '당한',
#  '사실',
#  '소개',
#  '유튜브',
#  '분석',
#  '사이트',
#  '소셜',
#  '블레이드',
#  '따르다',
#  '보람',
#  '패밀리',
#  '보람',
#  '튜브',
#  '토이',
#  '리뷰',
#  '오다',
#  '보람',
#  '튜브',
#  '브이',
#  '로그',
#  '채널',
#  '통해',
#  '각각',
#  '160만달러',
#  '19억원',
#  '오다',
#  '150만달러',
#  '17억',
#  '8000만원',
#  '37억원',
#  '이상',
#  '광고',
#  '매출',
#  '내다',
#  '국내',
#  '유튜브',
#  '콘텐츠',
#  '가장',
#  '많다',
#  '광고',
#  '수익',
#  '올리다',
#  '알려지다',
#  '포브스',
#  '따르다',
#  '지난해',
#  '가장',
#  '많다',
#  '수입',
#  '올리다',
#  '유튜버',
#  '라이언',
#  '토이',
#  '리뷰',
#  '진행자',
#  '라이언',
#  '역시',
#  '소년',
#  '라이언',
#  '지난해',
#  '2080만',
#  '구독',
#  '자수',
#  '기록',
#  '2200만달러',
#  '260억',
#  '6000만원',
#  '벌다',
#  '들이다',
#  '밉다',
#  '가족',
#  '유튜브',
#  '채널',
#  '트라브',
#  '출연',
#  '아동',
#  '유튜브',
#  '스타',
#  '타이',
#  '더스',
#  '늘다',
#  '310만',
#  '구독',
#  '자수',
#  '기록',
#  '유튜버',
#  '비디오',
#  '콘텐츠',
#  '삽입',
#  '광고',
#  '수익',
#  '함께',
#  '제품',
#  '노출',
#  '브랜드',
#  '제휴',
#  '다양하다',
#  '방법',
#  '유튜브',
#  '관계자',
#  'CNN',
#  '미성년',
#  '출연',
#  '콘텐츠',
#  '관련',
#  '아동학대',
#  '논란',
#  '관련',
#  '수천',
#  '건의',
#  '부적절하다',
#  '댓글',
#  '검토',
#  '삭제',
#  '아동학대',
#  '관련',
#  '400',
#  '여개',
#  '채널',
#  '중단',
#  '밝히다',
#  '.eswoo@newsis.com',
#  '네이버',
#  '뉴시스',
#  '채널',
#  '구독',
#  '뉴시스',
#  '빅데이터',
#  'MSI',
#  '주가',
#  '시세',
#  '바로가기',
#  '저작권',
#  '공감',
#  '언론',
#  '뉴시스',
#  '통신사',
#  '무단',
#  '배포',
#  '금지',
#  '보람',
#  '튜브',
#  '갈무리',
#  '뉴스',
#  '서울',
#  '뉴스',
#  '이원준',
#  '기자',
#  '유명',
#  '유튜브',
#  '채널',
#  '보람',
#  '튜브',
#  '주인공',
#  '이보람',
#  '둘러싸다',
#  '아동학대',
#  '논란',
#  '외신',
#  '주목',
#  '받다',
#  '26일',
#  '현지',
#  '시간',
#  '미국',
#  'CNN',
#  '방송',
#  '3천만',
#  '독자',
#  '보유',
#  '한국',
#  '유튜브',
#  '스타',
#  '서울',
#  '수백만',
#  '달러',
#  '짜다',
#  '빌딩',
#  '구입',
#  '관련',
#  '소식',
#  '소개',
#  'CNN',
#  '보람',
#  '튜브',
#  '대해',
#  '조회',
#  '수만',
#  '3억',
#  '7600만',
#  '넘다',
#  '가장',
#  '인기',
#  '동영상',
#  '보람',
#  '양은',
#  '장난감',
#  '주방',
#  '사용',
#  '라면',
#  '만들다',
#  '다음',
#  '카메라',
#  '열정',
#  '후루룩',
#  '먹다',
#  '그러나',
#  '영상',
#  '일부',
#  '한국',
#  '논란',
#  '불러일으키다',
#  '일례',
#  'CNN',
#  '보람',
#  '튜브',
#  '2017년',
#  '9월',
#  '국제',
#  '구호',
#  '개발',
#  '단체',
#  '세이브더칠드런',
#  '고발',
#  '사실',
#  '자세하다',
#  '소개',
#  '당시',
#  '보람',
#  '부모',
#  '가정법원',
#  '아동',
#  '보호',
#  '기관',
#  '상담',
#  '받다',
#  '보호처분',
#  '받다',
#  '또한',
#  '학대',
#  '논란',
#  '일으키다',
#  '영상',
#  '모두',
#  '비공개',
#  '전환',
#  'CNN',
#  '유튜브',
#  '아동',
#  '스타',
#  '크다',
#  '사업',
#  '미국',
#  '스타',
#  '유튜버',
#  '라이언',
#  '다른',
#  '사례',
#  '소개',
#  '라이언',
#  '새롭다',
#  '나오다',
#  '장난감',
#  '소개',
#  '라이언',
#  '이스',
#  '리뷰',
#  'Ryan',
#  'ToysReview',
#  '유튜브',
#  '채널',
#  '통해',
#  '2018년',
#  '한해',
#  '2200만달러',
#  '260억원',
#  '수익',
#  '올리다',
#  '집계',
#  'CNN',
#  '과거',
#  '사람',
#  '아동',
#  '영상',
#  '둘러싸다',
#  '유튜브',
#  '정책',
#  '우려',
#  '표시',
#  '소아성애',
#  '해당',
#  '영상',
#  '악용',
#  '우려',
#  '제기',
#  '부연',
#  '.wonjun44@news1.kr',
#  '크립',
#  '허브',
#  '피펫',
#  '네이버',
#  '메인',
#  '뉴스',
#  '구독',
#  '뉴스',
#  '코리아',
#  'news',
#  'kr',
#  '무단',
#  '배포',
#  '금지',
#  '사진',
#  '보람',
#  '튜브',
#  '유튜브',
#  '채널',
#  '캡처',
#  '유명',
#  '유튜브',
#  '채널',
#  '보람',
#  '튜브',
#  '대해',
#  '외신',
#  '주목',
#  '시작',
#  '해당',
#  '외신',
#  '보람',
#  '튜브',
#  '주인공',
#  '이보람',
#  '대한',
#  '소식',
#  '전하',
#  '면서',
#  '아동',
#  '유튜',
#  '버들',
#  '학대',
#  '범죄',
#  '대상',
#  '지목',
#  '가능성',
#  '대해',
#  '우려',
#  '26일',
#  '현지',
#  '시간',
#  '미국',
#  'CNN',
#  '방송',
#  '3000만',
#  '독자',
#  '보유',
#  '한국',
#  '유튜브',
#  '스타',
#  '서울',
#  '수백만',
#  '달러',
#  '짜다',
#  '빌딩',
#  '구입',
#  '보람',
#  '튜브',
#  '관련',
#  '소식',
#  'CNN',
#  '조회',
#  '수만',
#  '3억',
#  '7600만',
#  '넘다',
#  '인기',
#  '동영상',
#  '보람',
#  '양은',
#  '장난감',
#  '주방',
#  '사용',
#  '라면',
#  '만들다',
#  '다음',
#  '카메라',
#  '열정',
#  '먹다',
#  '영상',
#  '일부',
#  '한국',
#  '논란',
#  '부르다',
#  '설명',
#  '일례',
#  'CNN',
#  '보람',
#  '튜브',
#  '2017년',
#  '9월',
#  '국제',
#  '구호',
#  '개발',
#  '단체',
#  '세이브더칠드런',
#  '고발',
#  '자세하다',
#  '소개',
#  '당시',
#  '보람',
#  '부모',
#  '가정법원',
#  '아동',
#  '보호',
#  '기관',
#  '상담',
#  '받다',
#  '늘다',
#  '보호처분',
#  '받다',
#  '학대',
#  '논란',
#  '일으키다',
#  '영상',
#  '모두',
#  '비공개',
#  '전환',
#  'CNN',
#  '유튜브',
#  '아동',
#  '스타',
#  '크다',
#  '사업',
#  '미국',
#  '유튜버',
#  '라이언',
#  '다른',
#  '사례',
#  '소개',
#  '라이언',
#  '새롭다',
#  '나오다',
#  '장난감',
#  '소개',
#  '라이언',
#  '이스',
#  '리뷰',
#  '유튜브',
#  '채널',
#  '지난해',
#  '2200만달러',
#  '260억원',
#  '수익',
#  '올리다',
#  '집계',
#  '그러나',
#  'CNN',
#  '과거',
#  '사람',
#  '아동',
#  '영상',
#  '둘러싸다',
#  '유튜브',
#  '정책',
#  '우려',
#  '표시',
#  '소아성애',
#  '해당',
#  '영상',
#  '악용',
#  '우려',
#  '제기',
#  '지적',
#  '성오',
#  '기자',
#  'cso86@mt.co.kr',
#  '고수',
#  '재테크',
#  '비법',
#  '박학',
#  '다식',
#  '은희',
#  '칼럼',
#  '저작권',
#  '성공',
#  '꿈꾸다',
#  '사람',
#  '경제',
#  '뉴스',
#  '멀다',
#  '무단',
#  '배포',
#  '금지',
#  '키즈',
#  '콘텐츠',
#  '성공',
#  '영유',
#  '시청',
#  '시간',
#  '비례',
#  '스마트폰',
#  '의존',
#  '아이',
#  '늘다',
#  '유아기',
#  '과도',
#  '미디어',
#  '이용',
#  'ADHD',
#  '이어지다',
#  '부모',
#  '문제',
#  '의식',
#  '중요',
#  '미디어오늘',
#  '정철운',
#  '기자',
#  '95억원',
#  '빌딩',
#  '매입',
#  '보람',
#  '튜브',
#  '자괴',
#  '느끼다',
#  '어른',
#  '매일경제',
#  '키즈',
#  '유튜버',
#  '얼마나',
#  '벌다',
#  '보람',
#  '95억',
#  '빌딩',
#  '사나',
#  '중앙',
#  '일보',
#  '키즈',
#  '콘텐츠',
#  '많다',
#  '수익',
#  '올리다',
#  '보람',
#  '튜브',
#  '주요',
#  '언론',
#  '보도',
#  '자괴',
#  '또는',
#  '매출',
#  '규모',
#  '주목',
#  '정작',
#  '언론',
#  '주목',
#  '지점',
#  '보람',
#  '튜브',
#  '시청자',
#  '들이다',
#  '1770만',
#  '명의',
#  '독자',
#  '보유',
#  '보람',
#  '튜브',
#  '수익',
#  '정확하다',
#  '영유',
#  '미만',
#  '어린이',
#  '시청',
#  '시간',
#  '비례',
#  '국회입법조사처',
#  '최근',
#  '발표',
#  '유아',
#  '디지털',
#  '미디어',
#  '이용',
#  '현황',
#  '해외',
#  '사례',
#  '개선',
#  '방안',
#  '보고서',
#  '따르다',
#  '유아',
#  '디지털',
#  '미디어',
#  '이용',
#  '연령',
#  '낮아지다',
#  '미디어',
#  '이용',
#  '이용',
#  '시간',
#  '증가',
#  '또한',
#  '2017년',
#  '전국',
#  '1만',
#  '가구',
#  '3~69',
#  '스마트폰',
#  '이용자',
#  '대상',
#  '스마트폰',
#  '의존',
#  '조사',
#  '의하다',
#  '3~9',
#  '유아',
#  '19.1%',
#  '가다',
#  '의존',
#  '위험',
#  '2015년',
#  '대비',
#  '다른',
#  '연령',
#  '비다',
#  '가장',
#  '크다',
#  '상승',
#  '2018년',
#  '과학기술',
#  '정보통신부',
#  '한국',
#  '인터넷',
#  '진흥',
#  '발표',
#  '인터넷',
#  '이용',
#  '실태',
#  '조사',
#  '따르다',
#  '3~9',
#  '스마트폰',
#  '이용',
#  '시간',
#  '일주일',
#  '평균',
#  '7.2시간',
#  '나타나다',
#  '하루',
#  '시간',
#  '부모',
#  '스마트폰',
#  '빼앗다',
#  '또는',
#  '넘겨받다',
#  '또는',
#  '자신',
#  '스마트폰',
#  '통해',
#  '유튜브',
#  '틱톡',
#  '디지털',
#  '미디어',
#  '이용',
#  '추정',
#  '해보다',
#  '그러나',
#  '부모',
#  '체감',
#  '아이',
#  '디지털',
#  '미디어',
#  '이용',
#  '시간',
#  '7.2시간',
#  '훌쩍',
#  '뛰어넘다',
#  '현실',
#  '안산시',
#  '아이',
#  '키우다',
#  '김아무개',
#  '보통',
#  '일어나다',
#  '30분',
#  '보고',
#  '어린이집',
#  '다녀오다',
#  '1시간',
#  '1시간',
#  '30분',
#  '정도',
#  '보다',
#  '주말',
#  '어린이집',
#  '가지',
#  '때문',
#  '많이',
#  '시청',
#  '통계',
#  '비현실적',
#  '지적',
#  '스마트폰',
#  '보고',
#  '어린이',
#  '게티',
#  '이미지',
#  '영유',
#  '어린이',
#  '유튜브',
#  '이용',
#  '시간',
#  '부모',
#  '소득',
#  '높다',
#  '줄어들다',
#  '소득',
#  '낮다',
#  '늘어나다',
#  '일반',
#  '태권도',
#  '피아노',
#  '학원',
#  '등원',
#  '여부',
#  '부모',
#  '엄격하다',
#  '관리',
#  '차이',
#  '비롯',
#  '부모',
#  '맞벌이',
#  '거나',
#  '야근',
#  '잦다',
#  '이용',
#  '시간',
#  '더욱',
#  '늘어나다',
#  '보고서',
#  '따르다',
#  '2012년',
#  '유아',
#  '1694',
#  '대상',
#  '연구',
#  '결과',
#  '유아기',
#  '과도',
#  '미디어',
#  '이용',
#  '주의력',
#  '결핍',
#  '과잉행동',
#  '장애',
#  'ADHD',
#  '오다',
#  '관련',
#  '주의',
#  '집중',
#  '떨어뜨리다',
#  '나타나다',
#  '부모',
#  '걱정',
#  '인천',
#  '아이',
#  '키우다',
#  '김아무개',
#  '아이',
#  '유튜브',
#  '중독',
#  '싶다',
#  '평소',
#  '시청',
#  '시간',
#  '관리',
#  '쉬다',
#  '당장',
#  '식당',
#  '편하다',
#  '먹기',
#  '위해',
#  '고속도로',
#  '조용하다',
#  '운전',
#  '위해',
#  '쉬다',
#  '위해',
#  '아이',
#  '스마트폰',
#  '쥐다',
#  '주기도',
#  '국회입법조사처',
#  '영유',
#  '미디어',
#  '이용',
#  '부모',
#  '또는',
#  '보호자',
#  '허락',
#  '통제',
#  '달다',
#  '때문',
#  '어린이',
#  '청소년',
#  '비다',
#  '어른',
#  '책임',
#  '크다',
#  '없다',
#  '특히',
#  '부모',
#  '스마트폰',
#  '미디어',
#  '이용',
#  '시간',
#  '많다',
#  '유아기',
#  '자녀',
#  '미디어',
#  '이용',
#  '시간',
#  '많다',
#  '연구',
#  '건전하다',
#  '미디어',
#  '이용',
#  '대한',
#  '인식',
#  '필요하다',
#  '강조',
#  '미국',
#  '소아과',
#  '학회',
#  '2016년',
#  '18',
#  '개월',
#  '이하',
#  '유아',
#  '스크린',
#  '미디어',
#  '이용',
#  '18~24',
#  '개월',
#  '유아',
#  '보호자',
#  '함께',
#  '시청',
#  '제안',
#  '2~5',
#  '어린이',
#  '하루',
#  '1시간',
#  '이내',
#  '시청',
#  '제한',
#  '이상',
#  '어린이',
#  '미디어',
#  '이용',
#  '시간',
#  '미디어',
#  '종류',
#  '제한',
#  '적절하다',
#  '수면',
#  '신체',
#  '활동',
#  '대체',
#  '유의',
#  '권고',
#  '현재',
#  '국가',
#  '정보화',
#  '기본',
#  '30조',
#  '의하다',
#  '국내',
#  '어린이집',
#  '유치원',
#  '1회',
#  ...]

# %%
# 방법 1
# 리스트에 담긴 단어들을 대상으로 갯수를 세어,
# 단어를 key로 등장 횟수를 value로 하는 dict를 만듭니다.

word_dic = {}

for word in word_cleaned:
    if word not in word_dic:
        word_dic[word] = 1 # changed from "0" to "1"
    else:
        word_dic[word] += 1
        
word_dic
# Out:
# {'서울': 46,
#  '뉴시스': 5,
#  'CNN': 16,
#  '27일': 1,
#  '한국': 71,
#  '인기': 55,
#  '아동': 75,
#  '유튜브': 316,
#  '콘텐츠': 100,
#  '보람': 517,
#  '채널': 276,
#  '흥행': 2,
#  '소개': 22,
#  '기사': 14,
#  '실었다': 2,
#  '사진': 36,
#  '인터넷': 16,
#  '보도': 12,
#  '내용': 18,
#  '갈무리': 4,
#  '2019.07': 1,
#  '27': 1,
#  '기자': 58,
#  '튜브': 356,
#  '최근': 57,
#  '부동산': 17,
#  '매입': 74,
#  '소식': 19,
#  '26일': 9,
#  '현지': 4,
#  '시간': 34,
#  '3000만': 12,
#  '구독': 59,
#  '자수': 12,
#  '가지다': 10,
#  '스타': 14,
#  '95억원': 46,
#  '짜다': 21,
#  '건물': 40,
#  '사들이다': 33,
#  '출연': 13,
#  '이보람': 35,
#  '양은': 11,
#  '1360만': 3,
#  '독자': 118,
#  '토이': 66,
#  '리뷰': 77,
#  '오다': 42,
#  '1760만': 1,
#  '브이': 68,
#  '로그': 70,
#  '주인공': 21,
#  '부모': 74,
#  '설립': 1,
#  '패밀리': 69,
#  '지난': 42,
#  '4월': 15,
#  '강남구': 27,
#  '청담동': 45,
#  '빌딩': 146,
#  '알려지다': 62,
#  '업계': 15,
#  '등기': 4,
#  '따르다': 72,
#  '대지면적': 6,
#  '258.3': 9,
#  '지하': 2,
#  '지상': 2,
#  '규모': 8,
#  '단독': 9,
#  '2017년': 35,
#  '일부': 18,
#  '정서': 10,
#  '윤리': 4,
#  '영향': 7,
#  '미치다': 6,
#  '소송': 1,
#  '당한': 2,
#  '사실': 66,
#  '분석': 48,
#  '사이트': 34,
#  '소셜': 26,
#  '블레이드': 23,
#  '통해': 21,
#  '각각': 6,
#  '160만달러': 2,
#  '19억원': 6,
#  '150만달러': 2,
#  '17억': 10,
#  '8000만원': 7,
#  '37억원': 5,
#  '이상': 43,
#  '광고': 155,
#  '매출': 28,
#  '내다': 8,
#  '국내': 47,
#  '가장': 27,
#  '많다': 85,
#  '수익': 187,
#  '올리다': 76,
#  '포브스': 2,
#  '지난해': 15,
#  '수입': 49,
#  '유튜버': 144,
#  '라이언': 10,
#  '진행자': 1,
#  '역시': 20,
#  '소년': 1,
#  '2080만': 1,
#  '기록': 11,
#  '2200만달러': 3,
#  '260억': 1,
#  '6000만원': 3,
#  '벌다': 33,
#  '들이다': 21,
#  '밉다': 4,
#  '가족': 79,
#  '트라브': 1,
#  '타이': 1,
#  '더스': 1,
#  '늘다': 81,
#  '310만': 5,
#  '비디오': 2,
#  '삽입': 1,
#  '함께': 20,
#  '제품': 9,
#  '노출': 8,
#  '브랜드': 1,
#  '제휴': 1,
#  '다양하다': 15,
#  '방법': 6,
#  '관계자': 16,
#  '미성년': 15,
#  '관련': 35,
#  '아동학대': 62,
#  '논란': 58,
#  '수천': 4,
#  '건의': 1,
#  '부적절하다': 5,
#  '댓글': 22,
#  '검토': 3,
#  '삭제': 12,
#  '400': 1,
#  '여개': 2,
#  '중단': 2,
#  '밝히다': 27,
#  '.eswoo@newsis.com': 1,
#  '네이버': 43,
#  '빅데이터': 1,
#  'MSI': 1,
#  '주가': 3,
#  '시세': 6,
#  '바로가기': 13,
#  '저작권': 22,
#  '공감': 3,
#  '언론': 9,
#  '통신사': 1,
#  '무단': 61,
#  '배포': 55,
#  '금지': 57,
#  '뉴스': 93,
#  '이원준': 1,
#  '유명': 21,
#  '둘러싸다': 6,
#  '외신': 3,
#  '주목': 9,
#  '받다': 102,
#  '미국': 36,
#  '방송': 33,
#  '3천만': 9,
#  '보유': 20,
#  '수백만': 4,
#  '달러': 31,
#  '구입': 3,
#  '대해': 24,
#  '조회': 30,
#  '수만': 5,
#  '3억': 10,
#  '7600만': 2,
#  '넘다': 51,
#  '동영상': 66,
#  '장난감': 59,
#  '주방': 2,
#  '사용': 12,
#  '라면': 5,
#  '만들다': 23,
#  '다음': 6,
#  '카메라': 4,
#  '열정': 2,
#  '후루룩': 1,
#  '먹다': 24,
#  '그러나': 13,
#  '영상': 188,
#  '불러일으키다': 1,
#  '일례': 2,
#  '9월': 9,
#  '국제': 17,
#  '구호': 15,
#  '개발': 20,
#  '단체': 25,
#  '세이브더칠드런': 25,
#  '고발': 33,
#  '자세하다': 4,
#  '당시': 19,
#  '가정법원': 11,
#  '보호': 23,
#  '기관': 6,
#  '상담': 5,
#  '보호처분': 10,
#  '또한': 8,
#  '학대': 24,
#  '일으키다': 3,
#  '모두': 21,
#  '비공개': 11,
#  '전환': 11,
#  '크다': 32,
#  '사업': 20,
#  '다른': 21,
#  '사례': 10,
#  '새롭다': 7,
#  '나오다': 61,
#  '이스': 2,
#  'Ryan': 1,
#  'ToysReview': 1,
#  '2018년': 5,
#  '한해': 1,
#  '260억원': 2,
#  '집계': 5,
#  '과거': 25,
#  '사람': 35,
#  '정책': 13,
#  '우려': 18,
#  '표시': 4,
#  '소아성애': 2,
#  '해당': 35,
#  '악용': 4,
#  '제기': 6,
#  '부연': 1,
#  '.wonjun44@news1.kr': 1,
#  '크립': 4,
#  '허브': 4,
#  '피펫': 4,
#  '메인': 18,
#  '코리아': 6,
#  'news': 4,
#  'kr': 4,
#  '캡처': 30,
#  '시작': 11,
#  '대한': 49,
#  '전하': 2,
#  '면서': 5,
#  '유튜': 3,
#  '버들': 3,
#  '범죄': 2,
#  '대상': 18,
#  '지목': 1,
#  '가능성': 10,
#  '부르다': 7,
#  '설명': 9,
#  '지적': 19,
#  '성오': 1,
#  'cso86@mt.co.kr': 1,
#  '고수': 1,
#  '재테크': 4,
#  '비법': 1,
#  '박학': 1,
#  '다식': 1,
#  '은희': 6,
#  '칼럼': 5,
#  '성공': 11,
#  '꿈꾸다': 5,
#  '경제': 37,
#  '멀다': 2,
#  '키즈': 61,
#  '영유': 6,
#  '시청': 22,
#  '비례': 4,
#  '스마트폰': 13,
#  '의존': 3,
#  '아이': 123,
#  '유아기': 3,
#  '과도': 5,
#  '미디어': 33,
#  '이용': 35,
#  'ADHD': 2,
#  '이어지다': 4,
#  '문제': 46,
#  '의식': 1,
#  '중요': 4,
#  '미디어오늘': 4,
#  '정철운': 2,
#  '자괴': 3,
#  '느끼다': 17,
#  '어른': 6,
#  '매일경제': 14,
#  '얼마나': 7,
#  '95억': 29,
#  '사나': 1,
#  '중앙': 19,
#  '일보': 19,
#  '주요': 10,
#  '또는': 5,
#  '정작': 1,
#  '지점': 2,
#  '시청자': 25,
#  '1770만': 1,
#  '명의': 10,
#  '정확하다': 8,
#  '미만': 5,
#  '어린이': 50,
#  '국회입법조사처': 3,
#  '발표': 9,
#  '유아': 30,
#  '디지털': 15,
#  '현황': 2,
#  '해외': 16,
#  '개선': 3,
#  '방안': 4,
#  '보고서': 3,
#  '연령': 6,
#  '낮아지다': 2,
#  '증가': 7,
#  '전국': 2,
#  '1만': 1,
#  '가구': 1,
#  '3~69': 1,
#  '이용자': 7,
#  '조사': 17,
#  '의하다': 6,
#  '3~9': 2,
#  '19.1%': 1,
#  '가다': 62,
#  '위험': 3,
#  '2015년': 4,
#  '대비': 5,
#  '비다': 4,
#  '상승': 1,
#  '과학기술': 1,
#  '정보통신부': 1,
#  '진흥': 1,
#  '실태': 2,
#  '일주일': 2,
#  '평균': 18,
#  '7.2시간': 2,
#  '나타나다': 10,
#  '하루': 11,
#  '빼앗다': 1,
#  '넘겨받다': 1,
#  '자신': 16,
#  '틱톡': 1,
#  '추정': 42,
#  '해보다': 5,
#  '체감': 1,
#  '훌쩍': 8,
#  '뛰어넘다': 2,
#  '현실': 13,
#  '안산시': 1,
#  '키우다': 14,
#  '김아무개': 2,
#  '보통': 6,
#  '일어나다': 2,
#  '30분': 3,
#  '보고': 20,
#  '어린이집': 3,
#  '다녀오다': 1,
#  '1시간': 3,
#  '정도': 50,
#  '보다': 131,
#  '주말': 1,
#  '가지': 20,
#  '때문': 47,
#  '많이': 38,
#  '통계': 1,
#  '비현실적': 1,
#  '게티': 1,
#  '이미지': 6,
#  '소득': 19,
#  '높다': 27,
#  '줄어들다': 3,
#  '낮다': 10,
#  '늘어나다': 7,
#  '일반': 6,
#  '태권도': 1,
#  '피아노': 1,
#  '학원': 6,
#  '등원': 1,
#  '여부': 5,
#  '엄격하다': 4,
#  '관리': 22,
#  '차이': 11,
#  '비롯': 12,
#  '맞벌이': 1,
#  '거나': 18,
#  '야근': 1,
#  '잦다': 2,
#  '더욱': 11,
#  '2012년': 4,
#  '1694': 1,
#  '연구': 6,
#  '결과': 15,
#  '주의력': 1,
#  '결핍': 1,
#  '과잉행동': 1,
#  '장애': 1,
#  '주의': 1,
#  '집중': 6,
#  '떨어뜨리다': 1,
#  '걱정': 6,
#  '인천': 4,
#  '중독': 2,
#  '싶다': 22,
#  '평소': 1,
#  '쉬다': 12,
#  '당장': 1,
#  '식당': 6,
#  '편하다': 3,
#  '먹기': 2,
#  '위해': 26,
#  '고속도로': 1,
#  '조용하다': 2,
#  '운전': 19,
#  '쥐다': 3,
#  '주기도': 4,
#  '보호자': 3,
#  '허락': 1,
#  '통제': 2,
#  '달다': 4,
#  '청소년': 3,
#  '책임': 11,
#  '없다': 50,
#  '특히': 13,
#  '자녀': 10,
#  '건전하다': 1,
#  '인식': 11,
#  '필요하다': 11,
#  '강조': 6,
#  '소아과': 1,
#  '학회': 1,
#  '2016년': 3,
#  '18': 1,
#  '개월': 8,
#  '이하': 7,
#  '스크린': 1,
#  '18~24': 1,
#  '제안': 1,
#  '2~5': 1,
#  '이내': 1,
#  '제한': 8,
#  '종류': 4,
#  '적절하다': 2,
#  '수면': 2,
#  '신체': 3,
#  '활동': 9,
#  '대체': 4,
#  '유의': 1,
#  '권고': 2,
#  '현재': 24,
#  '국가': 11,
#  '정보화': 1,
#  '기본': 2,
#  '30조': 1,
#  '유치원': 1,
#  '1회': 2,
#  '예방': 1,
#  '해소': 1,
#  '교육': 14,
#  '실시': 4,
#  '정부': 17,
#  '기적': 1,
#  '이용실': 1,
#  '태조': 1,
#  '사르다': 1,
#  '등장': 15,
#  '세부': 1,
#  '지침': 3,
#  '마련': 9,
#  '지키다': 5,
#  '고함': 1,
#  '기기': 1,
#  '고해': 1,
#  '부러워하다': 2,
#  '돌아보다': 1,
#  '우선': 3,
#  'TV': 21,
#  'Copyright': 5,
#  '위상': 2,
#  '어마어마하다': 9,
#  '크리에이터': 22,
#  '견줘': 1,
#  '치다': 11,
#  '글로벌': 6,
#  '기획': 3,
#  '비결': 7,
#  '또래': 4,
#  '친구': 12,
#  '마음': 6,
#  '알다': 18,
#  '굉장하다': 28,
#  '노력': 18,
#  '구조': 17,
#  '먼저': 7,
#  '스킵': 3,
#  '누르다': 6,
#  '발생': 14,
#  '30초': 2,
#  '플레이': 2,
#  '단시간': 2,
#  '빠르다': 3,
#  '얻다': 15,
#  'PPL': 5,
#  '요즘': 14,
#  '주로': 11,
#  '추다': 12,
#  '10만': 8,
#  '보장': 3,
#  '서로': 3,
#  '달라': 4,
#  '라이브': 6,
#  '슈퍼': 2,
#  '후원': 6,
#  '가능하다': 11,
#  '시스템': 3,
#  '수도': 5,
#  '구글': 14,
#  '계좌': 6,
#  '직접': 14,
#  '이체': 5,
#  '해주다': 12,
#  '예전': 9,
#  '수표': 2,
#  '우편': 4,
#  '전달': 3,
#  '1천': 4,
#  '1년': 8,
#  '동안': 9,
#  '4,000시간': 2,
#  '확보': 12,
#  '허가': 3,
#  '피에로': 2,
#  '강도': 3,
#  '대부분': 9,
#  '개인': 14,
#  '부족': 2,
#  '외국': 3,
#  '계속': 13,
#  '프로그램': 7,
#  '오태훈': 1,
#  '시사': 4,
#  '본부': 5,
#  '코너': 2,
#  '이슈': 13,
#  '7월': 4,
#  '금요일': 1,
#  '12:20': 1,
#  '14:00': 1,
#  'KBS': 8,
#  '라디오': 5,
#  '출연자': 3,
#  '강민': 49,
#  '대표': 18,
#  '최영일': 46,
#  '운영': 39,
#  '강남': 61,
#  '원대': 3,
#  '사다': 9,
#  '혹시': 1,
#  '들다': 35,
#  '올해': 3,
#  '살인': 7,
#  '한편': 16,
#  '허탈하다': 1,
#  '나다': 9,
#  '회사': 66,
#  '두다': 8,
#  '때리다': 2,
#  '치우다': 1,
#  '한번': 3,
#  '이렇게': 30,
#  '생각': 46,
#  '분들': 8,
#  '아마': 2,
#  '계시다': 10,
#  '유튜버들': 14,
#  '차다': 4,
#  '궁금하다': 7,
#  '비밀': 2,
#  '풀다': 3,
#  '전문가': 11,
#  '스튜디오': 3,
#  '모시다': 1,
#  '안녕하다': 3,
#  '버시겠네': 1,
#  '아주': 3,
#  '약소': 2,
#  '편입': 1,
#  '업로드': 9,
#  '주다': 19,
#  '전문': 3,
#  '그래서': 24,
#  '브랜딩': 1,
#  '디자인': 1,
#  '촬영': 9,
#  '편집': 7,
#  '인터페이스': 1,
#  '생기다': 6,
#  '초상권': 3,
#  '정보': 10,
#  '침해': 3,
#  '같다': 60,
#  '해결': 1,
#  '그리고': 19,
#  '강사': 1,
#  '분과': 1,
#  '가르치다': 1,
#  '드리다': 7,
#  '컨설팅': 1,
#  '모르다': 14,
#  '그러면': 12,
#  '어느': 6,
#  '저희': 6,
#  '특성': 4,
#  '9만': 5,
#  '이제': 14,
#  '돌파': 2,
#  '주변': 6,
#  '잔치': 1,
#  '중요하다': 6,
#  '건가': 5,
#  '로부터': 7,
#  '실버': 4,
#  '버튼': 6,
#  '색깔': 1,
#  '붙이다': 6,
#  '계정': 4,
#  '실제': 37,
#  '실물': 2,
#  '보내다': 3,
#  '그러니까': 9,
#  '약간': 4,
#  '플랫폼': 4,
#  '인정': 8,
#  '번째': 6,
#  '관문': 1,
#  '뿌듯하다': 1,
#  '잠시': 2,
#  '책상': 1,
#  '놓이다': 1,
#  '감사하다': 3,
#  '이야기': 33,
#  '들어가다': 10,
#  '즐기다': 4,
#  '자다': 9,
#  '우리나라': 11,
#  '회수': 12,
#  '상당하다': 8,
#  '편이': 2,
#  '유튜버로': 2,
#  '로서': 1,
#  '말씀': 6,
#  '줄다': 2,
#  '수가': 31,
#  '어마': 2,
#  '훨씬': 5,
#  '나라': 2,
#  '견주어': 1,
#  '전혀': 5,
#  '중인': 7,
#  '보나': 1,
#  '정말': 10,
#  '신기하다': 3,
#  '일이': 8,
#  '대한민국': 17,
#  '세계': 21,
#  '특별하다': 2,
#  '뭐라다': 2,
#  '나이': 5,
#  '비슷하다': 14,
#  '심리': 1,
#  '단합': 1,
#  '좋다': 20,
#  '서로서로': 1,
#  '건지다': 4,
#  '나누다': 7,
#  '누가': 3,
#  '유저': 1,
#  '공부': 23,
#  '우리': 51,
#  '어리다': 12,
#  '살이': 1,
#  '확인': 19,
#  '하지만': 18,
#  '그거': 5,
#  '접속': 1,
#  '대략': 1,
#  '짐작': 2,
#  '조금': 12,
#  '성격': 1,
#  '경우': 47,
#  '크게': 8,
#  '따라서': 5,
#  '대가': 9,
#  '달라지다': 7,
#  '보지': 2,
#  '어쨌든': 5,
#  '10': 13,
#  '그러하다': 1,
#  '사용자': 1,
#  '소비': 6,
#  '화제': 32,
#  '운영자': 17,
#  '모시': 1,
#  '갑자기': 3,
#  '되게': 1,
#  '올드': 1,
#  '속물': 1,
#  '질문': 18,
#  '으악': 1,
#  '벌어지다': 5,
#  '일단': 3,
#  '처음': 10,
#  '돌아가다': 1,
#  '건너': 6,
#  '뛰다': 7,
#  'PC': 1,
#  '화면': 9,
#  '아래': 2,
#  '배너': 3,
#  '뜨다': 6,
#  '기도': 11,
#  '옆쪽': 1,
#  '정사각형': 2,
#  '그것': 6,
#  '집행': 3,
#  '금액': 5,
#  '보시': 5,
#  '그냥': 3,
#  '갈다': 3,
#  '되어다': 4,
#  '들어오다': 11,
#  '고요': 6,
#  '광고인': 2,
#  '클릭': 10,
#  '그런데': 16,
#  '브랜디': 1,
#  '광고주': 3,
#  '서비스': 7,
#  '제공': 11,
#  '업체': 7,
#  '자체': 15,
#  '추세': 2,
#  '그게': 4,
#  '워낙': 1,
#  '당연하다': 9,
#  '나가다': 3,
#  '수십만': 1,
#  '기준': 20,
#  '잡다': 4,
#  '아깝다': 3,
#  '모이다': 2,
#  '전업': 3,
#  '투잡': 1,
#  '사표': 1,
#  '부분': 7,
#  '오해': 1,
#  '계세': 1,
#  '대로': 8,
#  '무조건': 2,
#  '열심히': 9,
#  '붙다': 10,
#  '나뉘다': 3,
#  '명예': 3,
#  '적다': 7,
#  '자로': 1,
#  '실패하다': 1,
#  '특정': 8,
#  '너무': 8,
#  '사랑': 5,
#  '켜다': 1,
#  '방면': 2,
#  '어디서': 2,
#  '거지': 2,
#  '수나': 1,
#  '가늠': 1,
#  '불가능하다': 3,
#  '주위': 1,
#  '20만': 1,
#  '30만': 1,
#  '지니다': 2,
#  '노하우': 1,
#  '구체': 4,
#  '부치다': 2,
#  '바뀌다': 6,
#  '뜯다': 1,
#  '미화': 1,
#  '수표로': 1,
#  '지금': 36,
#  '줍다': 1,
#  '이후': 10,
#  '결정': 6,
#  '말다': 4,
#  '알기': 1,
#  '어렵다': 10,
#  '지정': 1,
#  '역할': 4,
#  '권한': 1,
#  '세금': 6,
#  '천차만별': 1,
#  '맞다': 14,
#  '내시': 2,
#  '불안정하다': 1,
#  '가면': 1,
#  '사건': 13,
#  '하나': 12,
#  '터지다': 2,
#  '현관': 2,
#  '비밀번호': 1,
#  '괴한': 1,
#  '바로': 2,
#  '얼마': 8,
#  '신림동': 1,
#  '성폭행': 1,
#  '미수범': 1,
#  '장면': 9,
#  '공포': 6,
#  '홍보': 4,
#  '목적': 8,
#  '밝혀지다': 1,
#  '제작자': 2,
#  '경찰': 15,
#  '수사': 12,
#  '자극': 19,
#  '만들어지다': 2,
#  '가끔': 1,
#  'BJ': 1,
#  '사고': 7,
#  '더불다': 2,
#  '완전': 1,
#  '장점': 3,
#  '표현': 6,
#  '자유': 6,
#  '명확하다': 8,
#  '잘못': 3,
#  '활용': 2,
#  '지다': 11,
#  '그렇게': 4,
#  '성장하다': 7,
#  '시점': 2,
#  '경험': 4,
#  '친하다': 1,
#  '끼리': 2,
#  '장난': 1,
#  '수준': 16,
#  '통용': 1,
#  '강의': 1,
#  '가볍다': 2,
#  '아예': 2,
#  '필터': 1,
#  '스스로': 9,
#  '기르다': 2,
#  '재미있다': 6,
#  '방식': 5,
#  '엄중': 1,
#  '대목': 1,
#  '간과': 1,
#  '뛰어들다': 8,
#  '피싱': 1,
#  '낚시질': 1,
#  '한다는': 18,
#  '왕왕': 1,
#  '당하다': 12,
#  '자동차': 25,
#  '도로': 8,
#  '몰다': 5,
#  '혹은': 2,
#  '별로': 3,
#  '좋아하다': 13,
#  '강요': 2,
#  '느낌': 3,
#  '신고': 4,
#  '고소': 2,
#  '이루어지다': 1,
#  '법정': 2,
#  '싸움': 1,
#  '내려오다': 1,
#  '상태': 7,
#  '올라오다': 21,
#  '신경': 1,
#  '쓰다': 1,
#  '보이다': 27,
#  '동시': 2,
#  '인하다': 4,
#  '논쟁': 2,
#  'SNS': 13,
#  '다시': 4,
#  '아빠': 19,
#  '항의': 9,
#  '표정': 2,
#  '자가': 1,
#  '민감하다': 3,
#  '올린다': 1,
#  '시장': 4,
#  '많아지다': 7,
#  '이미': 6,
#  '성공하다': 11,
#  '선배': 1,
#  '입장': 7,
#  '현상': 2,
#  '흐름': 6,
#  '초점': 3,
#  '맞추다': 3,
#  '계시': 2,
#  '자연스럽다': 3,
#  '미리': 3,
#  '연습': 2,
#  '기회': 6,
#  '당부': 1,
#  '충고': 1,
#  '한마디': 1,
#  '문턱': 1,
#  '만큼': 13,
#  '1,600분': 1,
#  '설문조사': 2,
#  '돌리다': 4,
#  '대답': 1,
#  '18%': 2,
#  '20%': 1,
#  '오래': 2,
#  '버티다': 2,
#  '실정': 1,
#  '물론': 11,
#  '장기전': 1,
#  '자기': 8,
#  '모르거나': 1,
#  '띄우다': 1,
#  '얕다': 1,
#  '오늘': 27,
#  '짧다': 3,
#  '청취': 1,
#  '귀가': 1,
#  '솔깃하다': 1,
#  '나중': 2,
#  '따로': 1,
#  '연락': 1,
#  '인터뷰': 2,
#  '고맙다': 1,
#  '시원하다': 3,
#  '털다': 5,
#  'ㄹㅇ': 3,
#  '당신': 3,
#  '진짜': 6,
#  '케이': 3,
#  '머니투데이': 8,
#  '민선': 6,
#  '24일': 12,
#  '국민': 27,
#  '청원': 32,
#  '불량': 6,
#  '제재': 13,
#  '자랑': 5,
#  '해달라다': 3,
#  '청와대': 14,
#  '게시판': 9,
#  '대형': 8,
#  '규제': 21,
#  '제목': 19,
#  '오전': 10,
#  '9시': 2,
#  '500': 3,
#  '여명': 2,
#  '동의': 5,
#  '의사': 7,
#  '1750만': 3,
#  '거대': 2,
#  '차지': 11,
#  '40억': 3,
#  '이르다': 21,
#  '3일': 9,
#  '덧붙이다': 4,
#  '라며': 17,
#  '몇몇': 4,
#  '정신': 7,
#  '고통': 9,
#  '행동': 18,
#  '이러하다': 12,
#  '모습': 33,
#  '담기다': 8,
#  '다수': 9,
#  '금전': 4,
#  '이익': 7,
#  '취했다': 4,
#  '이유': 20,
#  '불거지다': 9,
#  '불건전': 3,
#  '컨텐츠': 17,
#  '어쩌면': 2,
#  '과연': 8,
#  '정상': 6,
#  '양산': 2,
#  '40억원': 10,
#  '공정': 2,
#  ...}

# %%
# 방법 2
# 위 cell에서의 작업과 동일한 작업을 아래의 코드로 대체할 수 있습니다.

from collections import Counter
result = Counter(word_cleaned) #자료형 Counter
word_dic = dict(result) # Counter=>Dict
word_dic
# Out:
# {'서울': 46,
#  '뉴시스': 5,
#  'CNN': 16,
#  '27일': 1,
#  '한국': 71,
#  '인기': 55,
#  '아동': 75,
#  '유튜브': 316,
#  '콘텐츠': 100,
#  '보람': 517,
#  '채널': 276,
#  '흥행': 2,
#  '소개': 22,
#  '기사': 14,
#  '실었다': 2,
#  '사진': 36,
#  '인터넷': 16,
#  '보도': 12,
#  '내용': 18,
#  '갈무리': 4,
#  '2019.07': 1,
#  '27': 1,
#  '기자': 58,
#  '튜브': 356,
#  '최근': 57,
#  '부동산': 17,
#  '매입': 74,
#  '소식': 19,
#  '26일': 9,
#  '현지': 4,
#  '시간': 34,
#  '3000만': 12,
#  '구독': 59,
#  '자수': 12,
#  '가지다': 10,
#  '스타': 14,
#  '95억원': 46,
#  '짜다': 21,
#  '건물': 40,
#  '사들이다': 33,
#  '출연': 13,
#  '이보람': 35,
#  '양은': 11,
#  '1360만': 3,
#  '독자': 118,
#  '토이': 66,
#  '리뷰': 77,
#  '오다': 42,
#  '1760만': 1,
#  '브이': 68,
#  '로그': 70,
#  '주인공': 21,
#  '부모': 74,
#  '설립': 1,
#  '패밀리': 69,
#  '지난': 42,
#  '4월': 15,
#  '강남구': 27,
#  '청담동': 45,
#  '빌딩': 146,
#  '알려지다': 62,
#  '업계': 15,
#  '등기': 4,
#  '따르다': 72,
#  '대지면적': 6,
#  '258.3': 9,
#  '지하': 2,
#  '지상': 2,
#  '규모': 8,
#  '단독': 9,
#  '2017년': 35,
#  '일부': 18,
#  '정서': 10,
#  '윤리': 4,
#  '영향': 7,
#  '미치다': 6,
#  '소송': 1,
#  '당한': 2,
#  '사실': 66,
#  '분석': 48,
#  '사이트': 34,
#  '소셜': 26,
#  '블레이드': 23,
#  '통해': 21,
#  '각각': 6,
#  '160만달러': 2,
#  '19억원': 6,
#  '150만달러': 2,
#  '17억': 10,
#  '8000만원': 7,
#  '37억원': 5,
#  '이상': 43,
#  '광고': 155,
#  '매출': 28,
#  '내다': 8,
#  '국내': 47,
#  '가장': 27,
#  '많다': 85,
#  '수익': 187,
#  '올리다': 76,
#  '포브스': 2,
#  '지난해': 15,
#  '수입': 49,
#  '유튜버': 144,
#  '라이언': 10,
#  '진행자': 1,
#  '역시': 20,
#  '소년': 1,
#  '2080만': 1,
#  '기록': 11,
#  '2200만달러': 3,
#  '260억': 1,
#  '6000만원': 3,
#  '벌다': 33,
#  '들이다': 21,
#  '밉다': 4,
#  '가족': 79,
#  '트라브': 1,
#  '타이': 1,
#  '더스': 1,
#  '늘다': 81,
#  '310만': 5,
#  '비디오': 2,
#  '삽입': 1,
#  '함께': 20,
#  '제품': 9,
#  '노출': 8,
#  '브랜드': 1,
#  '제휴': 1,
#  '다양하다': 15,
#  '방법': 6,
#  '관계자': 16,
#  '미성년': 15,
#  '관련': 35,
#  '아동학대': 62,
#  '논란': 58,
#  '수천': 4,
#  '건의': 1,
#  '부적절하다': 5,
#  '댓글': 22,
#  '검토': 3,
#  '삭제': 12,
#  '400': 1,
#  '여개': 2,
#  '중단': 2,
#  '밝히다': 27,
#  '.eswoo@newsis.com': 1,
#  '네이버': 43,
#  '빅데이터': 1,
#  'MSI': 1,
#  '주가': 3,
#  '시세': 6,
#  '바로가기': 13,
#  '저작권': 22,
#  '공감': 3,
#  '언론': 9,
#  '통신사': 1,
#  '무단': 61,
#  '배포': 55,
#  '금지': 57,
#  '뉴스': 93,
#  '이원준': 1,
#  '유명': 21,
#  '둘러싸다': 6,
#  '외신': 3,
#  '주목': 9,
#  '받다': 102,
#  '미국': 36,
#  '방송': 33,
#  '3천만': 9,
#  '보유': 20,
#  '수백만': 4,
#  '달러': 31,
#  '구입': 3,
#  '대해': 24,
#  '조회': 30,
#  '수만': 5,
#  '3억': 10,
#  '7600만': 2,
#  '넘다': 51,
#  '동영상': 66,
#  '장난감': 59,
#  '주방': 2,
#  '사용': 12,
#  '라면': 5,
#  '만들다': 23,
#  '다음': 6,
#  '카메라': 4,
#  '열정': 2,
#  '후루룩': 1,
#  '먹다': 24,
#  '그러나': 13,
#  '영상': 188,
#  '불러일으키다': 1,
#  '일례': 2,
#  '9월': 9,
#  '국제': 17,
#  '구호': 15,
#  '개발': 20,
#  '단체': 25,
#  '세이브더칠드런': 25,
#  '고발': 33,
#  '자세하다': 4,
#  '당시': 19,
#  '가정법원': 11,
#  '보호': 23,
#  '기관': 6,
#  '상담': 5,
#  '보호처분': 10,
#  '또한': 8,
#  '학대': 24,
#  '일으키다': 3,
#  '모두': 21,
#  '비공개': 11,
#  '전환': 11,
#  '크다': 32,
#  '사업': 20,
#  '다른': 21,
#  '사례': 10,
#  '새롭다': 7,
#  '나오다': 61,
#  '이스': 2,
#  'Ryan': 1,
#  'ToysReview': 1,
#  '2018년': 5,
#  '한해': 1,
#  '260억원': 2,
#  '집계': 5,
#  '과거': 25,
#  '사람': 35,
#  '정책': 13,
#  '우려': 18,
#  '표시': 4,
#  '소아성애': 2,
#  '해당': 35,
#  '악용': 4,
#  '제기': 6,
#  '부연': 1,
#  '.wonjun44@news1.kr': 1,
#  '크립': 4,
#  '허브': 4,
#  '피펫': 4,
#  '메인': 18,
#  '코리아': 6,
#  'news': 4,
#  'kr': 4,
#  '캡처': 30,
#  '시작': 11,
#  '대한': 49,
#  '전하': 2,
#  '면서': 5,
#  '유튜': 3,
#  '버들': 3,
#  '범죄': 2,
#  '대상': 18,
#  '지목': 1,
#  '가능성': 10,
#  '부르다': 7,
#  '설명': 9,
#  '지적': 19,
#  '성오': 1,
#  'cso86@mt.co.kr': 1,
#  '고수': 1,
#  '재테크': 4,
#  '비법': 1,
#  '박학': 1,
#  '다식': 1,
#  '은희': 6,
#  '칼럼': 5,
#  '성공': 11,
#  '꿈꾸다': 5,
#  '경제': 37,
#  '멀다': 2,
#  '키즈': 61,
#  '영유': 6,
#  '시청': 22,
#  '비례': 4,
#  '스마트폰': 13,
#  '의존': 3,
#  '아이': 123,
#  '유아기': 3,
#  '과도': 5,
#  '미디어': 33,
#  '이용': 35,
#  'ADHD': 2,
#  '이어지다': 4,
#  '문제': 46,
#  '의식': 1,
#  '중요': 4,
#  '미디어오늘': 4,
#  '정철운': 2,
#  '자괴': 3,
#  '느끼다': 17,
#  '어른': 6,
#  '매일경제': 14,
#  '얼마나': 7,
#  '95억': 29,
#  '사나': 1,
#  '중앙': 19,
#  '일보': 19,
#  '주요': 10,
#  '또는': 5,
#  '정작': 1,
#  '지점': 2,
#  '시청자': 25,
#  '1770만': 1,
#  '명의': 10,
#  '정확하다': 8,
#  '미만': 5,
#  '어린이': 50,
#  '국회입법조사처': 3,
#  '발표': 9,
#  '유아': 30,
#  '디지털': 15,
#  '현황': 2,
#  '해외': 16,
#  '개선': 3,
#  '방안': 4,
#  '보고서': 3,
#  '연령': 6,
#  '낮아지다': 2,
#  '증가': 7,
#  '전국': 2,
#  '1만': 1,
#  '가구': 1,
#  '3~69': 1,
#  '이용자': 7,
#  '조사': 17,
#  '의하다': 6,
#  '3~9': 2,
#  '19.1%': 1,
#  '가다': 62,
#  '위험': 3,
#  '2015년': 4,
#  '대비': 5,
#  '비다': 4,
#  '상승': 1,
#  '과학기술': 1,
#  '정보통신부': 1,
#  '진흥': 1,
#  '실태': 2,
#  '일주일': 2,
#  '평균': 18,
#  '7.2시간': 2,
#  '나타나다': 10,
#  '하루': 11,
#  '빼앗다': 1,
#  '넘겨받다': 1,
#  '자신': 16,
#  '틱톡': 1,
#  '추정': 42,
#  '해보다': 5,
#  '체감': 1,
#  '훌쩍': 8,
#  '뛰어넘다': 2,
#  '현실': 13,
#  '안산시': 1,
#  '키우다': 14,
#  '김아무개': 2,
#  '보통': 6,
#  '일어나다': 2,
#  '30분': 3,
#  '보고': 20,
#  '어린이집': 3,
#  '다녀오다': 1,
#  '1시간': 3,
#  '정도': 50,
#  '보다': 131,
#  '주말': 1,
#  '가지': 20,
#  '때문': 47,
#  '많이': 38,
#  '통계': 1,
#  '비현실적': 1,
#  '게티': 1,
#  '이미지': 6,
#  '소득': 19,
#  '높다': 27,
#  '줄어들다': 3,
#  '낮다': 10,
#  '늘어나다': 7,
#  '일반': 6,
#  '태권도': 1,
#  '피아노': 1,
#  '학원': 6,
#  '등원': 1,
#  '여부': 5,
#  '엄격하다': 4,
#  '관리': 22,
#  '차이': 11,
#  '비롯': 12,
#  '맞벌이': 1,
#  '거나': 18,
#  '야근': 1,
#  '잦다': 2,
#  '더욱': 11,
#  '2012년': 4,
#  '1694': 1,
#  '연구': 6,
#  '결과': 15,
#  '주의력': 1,
#  '결핍': 1,
#  '과잉행동': 1,
#  '장애': 1,
#  '주의': 1,
#  '집중': 6,
#  '떨어뜨리다': 1,
#  '걱정': 6,
#  '인천': 4,
#  '중독': 2,
#  '싶다': 22,
#  '평소': 1,
#  '쉬다': 12,
#  '당장': 1,
#  '식당': 6,
#  '편하다': 3,
#  '먹기': 2,
#  '위해': 26,
#  '고속도로': 1,
#  '조용하다': 2,
#  '운전': 19,
#  '쥐다': 3,
#  '주기도': 4,
#  '보호자': 3,
#  '허락': 1,
#  '통제': 2,
#  '달다': 4,
#  '청소년': 3,
#  '책임': 11,
#  '없다': 50,
#  '특히': 13,
#  '자녀': 10,
#  '건전하다': 1,
#  '인식': 11,
#  '필요하다': 11,
#  '강조': 6,
#  '소아과': 1,
#  '학회': 1,
#  '2016년': 3,
#  '18': 1,
#  '개월': 8,
#  '이하': 7,
#  '스크린': 1,
#  '18~24': 1,
#  '제안': 1,
#  '2~5': 1,
#  '이내': 1,
#  '제한': 8,
#  '종류': 4,
#  '적절하다': 2,
#  '수면': 2,
#  '신체': 3,
#  '활동': 9,
#  '대체': 4,
#  '유의': 1,
#  '권고': 2,
#  '현재': 24,
#  '국가': 11,
#  '정보화': 1,
#  '기본': 2,
#  '30조': 1,
#  '유치원': 1,
#  '1회': 2,
#  '예방': 1,
#  '해소': 1,
#  '교육': 14,
#  '실시': 4,
#  '정부': 17,
#  '기적': 1,
#  '이용실': 1,
#  '태조': 1,
#  '사르다': 1,
#  '등장': 15,
#  '세부': 1,
#  '지침': 3,
#  '마련': 9,
#  '지키다': 5,
#  '고함': 1,
#  '기기': 1,
#  '고해': 1,
#  '부러워하다': 2,
#  '돌아보다': 1,
#  '우선': 3,
#  'TV': 21,
#  'Copyright': 5,
#  '위상': 2,
#  '어마어마하다': 9,
#  '크리에이터': 22,
#  '견줘': 1,
#  '치다': 11,
#  '글로벌': 6,
#  '기획': 3,
#  '비결': 7,
#  '또래': 4,
#  '친구': 12,
#  '마음': 6,
#  '알다': 18,
#  '굉장하다': 28,
#  '노력': 18,
#  '구조': 17,
#  '먼저': 7,
#  '스킵': 3,
#  '누르다': 6,
#  '발생': 14,
#  '30초': 2,
#  '플레이': 2,
#  '단시간': 2,
#  '빠르다': 3,
#  '얻다': 15,
#  'PPL': 5,
#  '요즘': 14,
#  '주로': 11,
#  '추다': 12,
#  '10만': 8,
#  '보장': 3,
#  '서로': 3,
#  '달라': 4,
#  '라이브': 6,
#  '슈퍼': 2,
#  '후원': 6,
#  '가능하다': 11,
#  '시스템': 3,
#  '수도': 5,
#  '구글': 14,
#  '계좌': 6,
#  '직접': 14,
#  '이체': 5,
#  '해주다': 12,
#  '예전': 9,
#  '수표': 2,
#  '우편': 4,
#  '전달': 3,
#  '1천': 4,
#  '1년': 8,
#  '동안': 9,
#  '4,000시간': 2,
#  '확보': 12,
#  '허가': 3,
#  '피에로': 2,
#  '강도': 3,
#  '대부분': 9,
#  '개인': 14,
#  '부족': 2,
#  '외국': 3,
#  '계속': 13,
#  '프로그램': 7,
#  '오태훈': 1,
#  '시사': 4,
#  '본부': 5,
#  '코너': 2,
#  '이슈': 13,
#  '7월': 4,
#  '금요일': 1,
#  '12:20': 1,
#  '14:00': 1,
#  'KBS': 8,
#  '라디오': 5,
#  '출연자': 3,
#  '강민': 49,
#  '대표': 18,
#  '최영일': 46,
#  '운영': 39,
#  '강남': 61,
#  '원대': 3,
#  '사다': 9,
#  '혹시': 1,
#  '들다': 35,
#  '올해': 3,
#  '살인': 7,
#  '한편': 16,
#  '허탈하다': 1,
#  '나다': 9,
#  '회사': 66,
#  '두다': 8,
#  '때리다': 2,
#  '치우다': 1,
#  '한번': 3,
#  '이렇게': 30,
#  '생각': 46,
#  '분들': 8,
#  '아마': 2,
#  '계시다': 10,
#  '유튜버들': 14,
#  '차다': 4,
#  '궁금하다': 7,
#  '비밀': 2,
#  '풀다': 3,
#  '전문가': 11,
#  '스튜디오': 3,
#  '모시다': 1,
#  '안녕하다': 3,
#  '버시겠네': 1,
#  '아주': 3,
#  '약소': 2,
#  '편입': 1,
#  '업로드': 9,
#  '주다': 19,
#  '전문': 3,
#  '그래서': 24,
#  '브랜딩': 1,
#  '디자인': 1,
#  '촬영': 9,
#  '편집': 7,
#  '인터페이스': 1,
#  '생기다': 6,
#  '초상권': 3,
#  '정보': 10,
#  '침해': 3,
#  '같다': 60,
#  '해결': 1,
#  '그리고': 19,
#  '강사': 1,
#  '분과': 1,
#  '가르치다': 1,
#  '드리다': 7,
#  '컨설팅': 1,
#  '모르다': 14,
#  '그러면': 12,
#  '어느': 6,
#  '저희': 6,
#  '특성': 4,
#  '9만': 5,
#  '이제': 14,
#  '돌파': 2,
#  '주변': 6,
#  '잔치': 1,
#  '중요하다': 6,
#  '건가': 5,
#  '로부터': 7,
#  '실버': 4,
#  '버튼': 6,
#  '색깔': 1,
#  '붙이다': 6,
#  '계정': 4,
#  '실제': 37,
#  '실물': 2,
#  '보내다': 3,
#  '그러니까': 9,
#  '약간': 4,
#  '플랫폼': 4,
#  '인정': 8,
#  '번째': 6,
#  '관문': 1,
#  '뿌듯하다': 1,
#  '잠시': 2,
#  '책상': 1,
#  '놓이다': 1,
#  '감사하다': 3,
#  '이야기': 33,
#  '들어가다': 10,
#  '즐기다': 4,
#  '자다': 9,
#  '우리나라': 11,
#  '회수': 12,
#  '상당하다': 8,
#  '편이': 2,
#  '유튜버로': 2,
#  '로서': 1,
#  '말씀': 6,
#  '줄다': 2,
#  '수가': 31,
#  '어마': 2,
#  '훨씬': 5,
#  '나라': 2,
#  '견주어': 1,
#  '전혀': 5,
#  '중인': 7,
#  '보나': 1,
#  '정말': 10,
#  '신기하다': 3,
#  '일이': 8,
#  '대한민국': 17,
#  '세계': 21,
#  '특별하다': 2,
#  '뭐라다': 2,
#  '나이': 5,
#  '비슷하다': 14,
#  '심리': 1,
#  '단합': 1,
#  '좋다': 20,
#  '서로서로': 1,
#  '건지다': 4,
#  '나누다': 7,
#  '누가': 3,
#  '유저': 1,
#  '공부': 23,
#  '우리': 51,
#  '어리다': 12,
#  '살이': 1,
#  '확인': 19,
#  '하지만': 18,
#  '그거': 5,
#  '접속': 1,
#  '대략': 1,
#  '짐작': 2,
#  '조금': 12,
#  '성격': 1,
#  '경우': 47,
#  '크게': 8,
#  '따라서': 5,
#  '대가': 9,
#  '달라지다': 7,
#  '보지': 2,
#  '어쨌든': 5,
#  '10': 13,
#  '그러하다': 1,
#  '사용자': 1,
#  '소비': 6,
#  '화제': 32,
#  '운영자': 17,
#  '모시': 1,
#  '갑자기': 3,
#  '되게': 1,
#  '올드': 1,
#  '속물': 1,
#  '질문': 18,
#  '으악': 1,
#  '벌어지다': 5,
#  '일단': 3,
#  '처음': 10,
#  '돌아가다': 1,
#  '건너': 6,
#  '뛰다': 7,
#  'PC': 1,
#  '화면': 9,
#  '아래': 2,
#  '배너': 3,
#  '뜨다': 6,
#  '기도': 11,
#  '옆쪽': 1,
#  '정사각형': 2,
#  '그것': 6,
#  '집행': 3,
#  '금액': 5,
#  '보시': 5,
#  '그냥': 3,
#  '갈다': 3,
#  '되어다': 4,
#  '들어오다': 11,
#  '고요': 6,
#  '광고인': 2,
#  '클릭': 10,
#  '그런데': 16,
#  '브랜디': 1,
#  '광고주': 3,
#  '서비스': 7,
#  '제공': 11,
#  '업체': 7,
#  '자체': 15,
#  '추세': 2,
#  '그게': 4,
#  '워낙': 1,
#  '당연하다': 9,
#  '나가다': 3,
#  '수십만': 1,
#  '기준': 20,
#  '잡다': 4,
#  '아깝다': 3,
#  '모이다': 2,
#  '전업': 3,
#  '투잡': 1,
#  '사표': 1,
#  '부분': 7,
#  '오해': 1,
#  '계세': 1,
#  '대로': 8,
#  '무조건': 2,
#  '열심히': 9,
#  '붙다': 10,
#  '나뉘다': 3,
#  '명예': 3,
#  '적다': 7,
#  '자로': 1,
#  '실패하다': 1,
#  '특정': 8,
#  '너무': 8,
#  '사랑': 5,
#  '켜다': 1,
#  '방면': 2,
#  '어디서': 2,
#  '거지': 2,
#  '수나': 1,
#  '가늠': 1,
#  '불가능하다': 3,
#  '주위': 1,
#  '20만': 1,
#  '30만': 1,
#  '지니다': 2,
#  '노하우': 1,
#  '구체': 4,
#  '부치다': 2,
#  '바뀌다': 6,
#  '뜯다': 1,
#  '미화': 1,
#  '수표로': 1,
#  '지금': 36,
#  '줍다': 1,
#  '이후': 10,
#  '결정': 6,
#  '말다': 4,
#  '알기': 1,
#  '어렵다': 10,
#  '지정': 1,
#  '역할': 4,
#  '권한': 1,
#  '세금': 6,
#  '천차만별': 1,
#  '맞다': 14,
#  '내시': 2,
#  '불안정하다': 1,
#  '가면': 1,
#  '사건': 13,
#  '하나': 12,
#  '터지다': 2,
#  '현관': 2,
#  '비밀번호': 1,
#  '괴한': 1,
#  '바로': 2,
#  '얼마': 8,
#  '신림동': 1,
#  '성폭행': 1,
#  '미수범': 1,
#  '장면': 9,
#  '공포': 6,
#  '홍보': 4,
#  '목적': 8,
#  '밝혀지다': 1,
#  '제작자': 2,
#  '경찰': 15,
#  '수사': 12,
#  '자극': 19,
#  '만들어지다': 2,
#  '가끔': 1,
#  'BJ': 1,
#  '사고': 7,
#  '더불다': 2,
#  '완전': 1,
#  '장점': 3,
#  '표현': 6,
#  '자유': 6,
#  '명확하다': 8,
#  '잘못': 3,
#  '활용': 2,
#  '지다': 11,
#  '그렇게': 4,
#  '성장하다': 7,
#  '시점': 2,
#  '경험': 4,
#  '친하다': 1,
#  '끼리': 2,
#  '장난': 1,
#  '수준': 16,
#  '통용': 1,
#  '강의': 1,
#  '가볍다': 2,
#  '아예': 2,
#  '필터': 1,
#  '스스로': 9,
#  '기르다': 2,
#  '재미있다': 6,
#  '방식': 5,
#  '엄중': 1,
#  '대목': 1,
#  '간과': 1,
#  '뛰어들다': 8,
#  '피싱': 1,
#  '낚시질': 1,
#  '한다는': 18,
#  '왕왕': 1,
#  '당하다': 12,
#  '자동차': 25,
#  '도로': 8,
#  '몰다': 5,
#  '혹은': 2,
#  '별로': 3,
#  '좋아하다': 13,
#  '강요': 2,
#  '느낌': 3,
#  '신고': 4,
#  '고소': 2,
#  '이루어지다': 1,
#  '법정': 2,
#  '싸움': 1,
#  '내려오다': 1,
#  '상태': 7,
#  '올라오다': 21,
#  '신경': 1,
#  '쓰다': 1,
#  '보이다': 27,
#  '동시': 2,
#  '인하다': 4,
#  '논쟁': 2,
#  'SNS': 13,
#  '다시': 4,
#  '아빠': 19,
#  '항의': 9,
#  '표정': 2,
#  '자가': 1,
#  '민감하다': 3,
#  '올린다': 1,
#  '시장': 4,
#  '많아지다': 7,
#  '이미': 6,
#  '성공하다': 11,
#  '선배': 1,
#  '입장': 7,
#  '현상': 2,
#  '흐름': 6,
#  '초점': 3,
#  '맞추다': 3,
#  '계시': 2,
#  '자연스럽다': 3,
#  '미리': 3,
#  '연습': 2,
#  '기회': 6,
#  '당부': 1,
#  '충고': 1,
#  '한마디': 1,
#  '문턱': 1,
#  '만큼': 13,
#  '1,600분': 1,
#  '설문조사': 2,
#  '돌리다': 4,
#  '대답': 1,
#  '18%': 2,
#  '20%': 1,
#  '오래': 2,
#  '버티다': 2,
#  '실정': 1,
#  '물론': 11,
#  '장기전': 1,
#  '자기': 8,
#  '모르거나': 1,
#  '띄우다': 1,
#  '얕다': 1,
#  '오늘': 27,
#  '짧다': 3,
#  '청취': 1,
#  '귀가': 1,
#  '솔깃하다': 1,
#  '나중': 2,
#  '따로': 1,
#  '연락': 1,
#  '인터뷰': 2,
#  '고맙다': 1,
#  '시원하다': 3,
#  '털다': 5,
#  'ㄹㅇ': 3,
#  '당신': 3,
#  '진짜': 6,
#  '케이': 3,
#  '머니투데이': 8,
#  '민선': 6,
#  '24일': 12,
#  '국민': 27,
#  '청원': 32,
#  '불량': 6,
#  '제재': 13,
#  '자랑': 5,
#  '해달라다': 3,
#  '청와대': 14,
#  '게시판': 9,
#  '대형': 8,
#  '규제': 21,
#  '제목': 19,
#  '오전': 10,
#  '9시': 2,
#  '500': 3,
#  '여명': 2,
#  '동의': 5,
#  '의사': 7,
#  '1750만': 3,
#  '거대': 2,
#  '차지': 11,
#  '40억': 3,
#  '이르다': 21,
#  '3일': 9,
#  '덧붙이다': 4,
#  '라며': 17,
#  '몇몇': 4,
#  '정신': 7,
#  '고통': 9,
#  '행동': 18,
#  '이러하다': 12,
#  '모습': 33,
#  '담기다': 8,
#  '다수': 9,
#  '금전': 4,
#  '이익': 7,
#  '취했다': 4,
#  '이유': 20,
#  '불거지다': 9,
#  '불건전': 3,
#  '컨텐츠': 17,
#  '어쩌면': 2,
#  '과연': 8,
#  '정상': 6,
#  '양산': 2,
#  '40억원': 10,
#  '공정': 2,
#  ...}

# %% [markdown]
# #### -> You can preceed to [3. 워드클라우드 만들기] from here.

# %%
word_dic.items()
# Out:
# dict_items([('서울', 46), ('뉴시스', 5), ('CNN', 16), ('27일', 1), ('한국', 71), ('인기', 55), ('아동', 75), ('유튜브', 316), ('콘텐츠', 100), ('보람', 517), ('채널', 276), ('흥행', 2), ('소개', 22), ('기사', 14), ('실었다', 2), ('사진', 36), ('인터넷', 16), ('보도', 12), ('내용', 18), ('갈무리', 4), ('2019.07', 1), ('27', 1), ('기자', 58), ('튜브', 356), ('최근', 57), ('부동산', 17), ('매입', 74), ('소식', 19), ('26일', 9), ('현지', 4), ('시간', 34), ('3000만', 12), ('구독', 59), ('자수', 12), ('가지다', 10), ('스타', 14), ('95억원', 46), ('짜다', 21), ('건물', 40), ('사들이다', 33), ('출연', 13), ('이보람', 35), ('양은', 11), ('1360만', 3), ('독자', 118), ('토이', 66), ('리뷰', 77), ('오다', 42), ('1760만', 1), ('브이', 68), ('로그', 70), ('주인공', 21), ('부모', 74), ('설립', 1), ('패밀리', 69), ('지난', 42), ('4월', 15), ('강남구', 27), ('청담동', 45), ('빌딩', 146), ('알려지다', 62), ('업계', 15), ('등기', 4), ('따르다', 72), ('대지면적', 6), ('258.3', 9), ('지하', 2), ('지상', 2), ('규모', 8), ('단독', 9), ('2017년', 35), ('일부', 18), ('정서', 10), ('윤리', 4), ('영향', 7), ('미치다', 6), ('소송', 1), ('당한', 2), ('사실', 66), ('분석', 48), ('사이트', 34), ('소셜', 26), ('블레이드', 23), ('통해', 21), ('각각', 6), ('160만달러', 2), ('19억원', 6), ('150만달러', 2), ('17억', 10), ('8000만원', 7), ('37억원', 5), ('이상', 43), ('광고', 155), ('매출', 28), ('내다', 8), ('국내', 47), ('가장', 27), ('많다', 85), ('수익', 187), ('올리다', 76), ('포브스', 2), ('지난해', 15), ('수입', 49), ('유튜버', 144), ('라이언', 10), ('진행자', 1), ('역시', 20), ('소년', 1), ('2080만', 1), ('기록', 11), ('2200만달러', 3), ('260억', 1), ('6000만원', 3), ('벌다', 33), ('들이다', 21), ('밉다', 4), ('가족', 79), ('트라브', 1), ('타이', 1), ('더스', 1), ('늘다', 81), ('310만', 5), ('비디오', 2), ('삽입', 1), ('함께', 20), ('제품', 9), ('노출', 8), ('브랜드', 1), ('제휴', 1), ('다양하다', 15), ('방법', 6), ('관계자', 16), ('미성년', 15), ('관련', 35), ('아동학대', 62), ('논란', 58), ('수천', 4), ('건의', 1), ('부적절하다', 5), ('댓글', 22), ('검토', 3), ('삭제', 12), ('400', 1), ('여개', 2), ('중단', 2), ('밝히다', 27), ('.eswoo@newsis.com', 1), ('네이버', 43), ('빅데이터', 1), ('MSI', 1), ('주가', 3), ('시세', 6), ('바로가기', 13), ('저작권', 22), ('공감', 3), ('언론', 9), ('통신사', 1), ('무단', 61), ('배포', 55), ('금지', 57), ('뉴스', 93), ('이원준', 1), ('유명', 21), ('둘러싸다', 6), ('외신', 3), ('주목', 9), ('받다', 102), ('미국', 36), ('방송', 33), ('3천만', 9), ('보유', 20), ('수백만', 4), ('달러', 31), ('구입', 3), ('대해', 24), ('조회', 30), ('수만', 5), ('3억', 10), ('7600만', 2), ('넘다', 51), ('동영상', 66), ('장난감', 59), ('주방', 2), ('사용', 12), ('라면', 5), ('만들다', 23), ('다음', 6), ('카메라', 4), ('열정', 2), ('후루룩', 1), ('먹다', 24), ('그러나', 13), ('영상', 188), ('불러일으키다', 1), ('일례', 2), ('9월', 9), ('국제', 17), ('구호', 15), ('개발', 20), ('단체', 25), ('세이브더칠드런', 25), ('고발', 33), ('자세하다', 4), ('당시', 19), ('가정법원', 11), ('보호', 23), ('기관', 6), ('상담', 5), ('보호처분', 10), ('또한', 8), ('학대', 24), ('일으키다', 3), ('모두', 21), ('비공개', 11), ('전환', 11), ('크다', 32), ('사업', 20), ('다른', 21), ('사례', 10), ('새롭다', 7), ('나오다', 61), ('이스', 2), ('Ryan', 1), ('ToysReview', 1), ('2018년', 5), ('한해', 1), ('260억원', 2), ('집계', 5), ('과거', 25), ('사람', 35), ('정책', 13), ('우려', 18), ('표시', 4), ('소아성애', 2), ('해당', 35), ('악용', 4), ('제기', 6), ('부연', 1), ('.wonjun44@news1.kr', 1), ('크립', 4), ('허브', 4), ('피펫', 4), ('메인', 18), ('코리아', 6), ('news', 4), ('kr', 4), ('캡처', 30), ('시작', 11), ('대한', 49), ('전하', 2), ('면서', 5), ('유튜', 3), ('버들', 3), ('범죄', 2), ('대상', 18), ('지목', 1), ('가능성', 10), ('부르다', 7), ('설명', 9), ('지적', 19), ('성오', 1), ('cso86@mt.co.kr', 1), ('고수', 1), ('재테크', 4), ('비법', 1), ('박학', 1), ('다식', 1), ('은희', 6), ('칼럼', 5), ('성공', 11), ('꿈꾸다', 5), ('경제', 37), ('멀다', 2), ('키즈', 61), ('영유', 6), ('시청', 22), ('비례', 4), ('스마트폰', 13), ('의존', 3), ('아이', 123), ('유아기', 3), ('과도', 5), ('미디어', 33), ('이용', 35), ('ADHD', 2), ('이어지다', 4), ('문제', 46), ('의식', 1), ('중요', 4), ('미디어오늘', 4), ('정철운', 2), ('자괴', 3), ('느끼다', 17), ('어른', 6), ('매일경제', 14), ('얼마나', 7), ('95억', 29), ('사나', 1), ('중앙', 19), ('일보', 19), ('주요', 10), ('또는', 5), ('정작', 1), ('지점', 2), ('시청자', 25), ('1770만', 1), ('명의', 10), ('정확하다', 8), ('미만', 5), ('어린이', 50), ('국회입법조사처', 3), ('발표', 9), ('유아', 30), ('디지털', 15), ('현황', 2), ('해외', 16), ('개선', 3), ('방안', 4), ('보고서', 3), ('연령', 6), ('낮아지다', 2), ('증가', 7), ('전국', 2), ('1만', 1),  ...

# %%
# lambda 함수를 활용하여,
# 앞서 만든 dict를 item 단위(tuple)로 꺼내어, tuple(x)의 value(x[1])를 기준으로 하여 내림차순(reverse=True) 정렬합니다.

sorted_word_dic = sorted(word_dic.items(), key=lambda x:x[1], reverse=True)
sorted_word_dic
# Out:
# [('보람', 517),
#  ('튜브', 356),
#  ('유튜브', 316),
#  ('채널', 276),
#  ('영상', 188),
#  ('수익', 187),
#  ('광고', 155),
#  ('빌딩', 146),
#  ('유튜버', 144),
#  ('보다', 131),
#  ('아이', 123),
#  ('독자', 118),
#  ('받다', 102),
#  ('콘텐츠', 100),
#  ('뉴스', 93),
#  ('많다', 85),
#  ('늘다', 81),
#  ('가족', 79),
#  ('리뷰', 77),
#  ('올리다', 76),
#  ('아동', 75),
#  ('매입', 74),
#  ('부모', 74),
#  ('따르다', 72),
#  ('한국', 71),
#  ('로그', 70),
#  ('패밀리', 69),
#  ('브이', 68),
#  ('토이', 66),
#  ('사실', 66),
#  ('동영상', 66),
#  ('회사', 66),
#  ('알려지다', 62),
#  ('아동학대', 62),
#  ('가다', 62),
#  ('무단', 61),
#  ('나오다', 61),
#  ('키즈', 61),
#  ('강남', 61),
#  ('같다', 60),
#  ('구독', 59),
#  ('장난감', 59),
#  ('기자', 58),
#  ('논란', 58),
#  ('최근', 57),
#  ('금지', 57),
#  ('인기', 55),
#  ('배포', 55),
#  ('넘다', 51),
#  ('우리', 51),
#  ('어린이', 50),
#  ('정도', 50),
#  ('없다', 50),
#  ('수입', 49),
#  ('대한', 49),
#  ('강민', 49),
#  ('분석', 48),
#  ('국내', 47),
#  ('때문', 47),
#  ('경우', 47),
#  ('서울', 46),
#  ('95억원', 46),
#  ('문제', 46),
#  ('최영일', 46),
#  ('생각', 46),
#  ('청담동', 45),
#  ('이상', 43),
#  ('네이버', 43),
#  ('일본', 43),
#  ('오다', 42),
#  ('지난', 42),
#  ('추정', 42),
#  ('건물', 40),
#  ('운영', 39),
#  ('많이', 38),
#  ('경제', 37),
#  ('실제', 37),
#  ('사진', 36),
#  ('미국', 36),
#  ('지금', 36),
#  ('이보람', 35),
#  ('2017년', 35),
#  ('관련', 35),
#  ('사람', 35),
#  ('해당', 35),
#  ('이용', 35),
#  ('들다', 35),
#  ('시간', 34),
#  ('사이트', 34),
#  ('사들이다', 33),
#  ('벌다', 33),
#  ('방송', 33),
#  ('고발', 33),
#  ('미디어', 33),
#  ('이야기', 33),
#  ('모습', 33),
#  ('크다', 32),
#  ('화제', 32),
#  ('청원', 32),
#  ('달러', 31),
#  ('수가', 31),
#  ('상황', 31),
#  ('조회', 30),
#  ('캡처', 30),
#  ('유아', 30),
#  ('이렇게', 30),
#  ('95억', 29),
#  ('일상', 29),
#  ('부자', 29),
#  ('매출', 28),
#  ('굉장하다', 28),
#  ('23일', 28),
#  ('담다', 28),
#  ('강남구', 27),
#  ('가장', 27),
#  ('밝히다', 27),
#  ('높다', 27),
#  ('보이다', 27),
#  ('오늘', 27),
#  ('국민', 27),
#  ('최고', 27),
#  ('YTN', 27),
#  ('러시아', 27),
#  ('소셜', 26),
#  ('위해', 26),
#  ('혐의', 26),
#  ('반응', 26),
#  ('단체', 25),
#  ('세이브더칠드런', 25),
#  ('과거', 25),
#  ('시청자', 25),
#  ('자동차', 25),
#  ('대해', 24),
#  ('먹다', 24),
#  ('학대', 24),
#  ('현재', 24),
#  ('그래서', 24),
#  ('제작', 24),
#  ('관심', 24),
#  ('영공', 24),
#  ('블레이드', 23),
#  ('만들다', 23),
#  ('보호', 23),
#  ('공부', 23),
#  ('소개', 22),
#  ('댓글', 22),
#  ('저작권', 22),
#  ('시청', 22),
#  ('관리', 22),
#  ('싶다', 22),
#  ('크리에이터', 22),
#  ('연출', 22),
#  ('주장', 22),
#  ('플루', 22),
#  ('민기', 22),
#  ('짜다', 21),
#  ('주인공', 21),
#  ('통해', 21),
#  ('들이다', 21),
#  ('유명', 21),
#  ('모두', 21),
#  ('다른', 21),
#  ('TV', 21),
#  ('세계', 21),
#  ('올라오다', 21),
#  ('규제', 21),
#  ('이르다', 21),
#  ('역시', 20),
#  ('함께', 20),
#  ('보유', 20),
#  ('개발', 20),
#  ('사업', 20),
#  ('보고', 20),
#  ('가지', 20),
#  ('좋다', 20),
#  ('기준', 20),
#  ('이유', 20),
#  ('훔치다', 20),
#  ('상당', 20),
#  ('소식', 19),
#  ('당시', 19),
#  ('지적', 19),
#  ('중앙', 19),
#  ('일보', 19),
#  ('소득', 19),
#  ('운전', 19),
#  ('주다', 19),
#  ('그리고', 19),
#  ('확인', 19),
#  ('자극', 19),
#  ('아빠', 19),
#  ('제목', 19),
#  ('가운데', 19),
#  ('내용', 18),
#  ('일부', 18),
#  ('우려', 18),
#  ('메인', 18),
#  ('대상', 18),
#  ('평균', 18),
#  ('거나', 18),
#  ('알다', 18),
#  ('노력', 18),
#  ('대표', 18),
#  ('하지만', 18),
#  ('질문', 18),
#  ('한다는', 18),
#  ('행동', 18),
#  ('사회', 18),
#  ('갖다', 18),
#  ('매달', 18),
#  ('시키다', 18),
#  ('군용기', 18),
#  ('부동산', 17),
#  ('국제', 17),
#  ('느끼다', 17),
#  ('조사', 17),
#  ('정부', 17),
#  ('구조', 17),
#  ('대한민국', 17),
#  ('운영자', 17),
#  ('라며', 17),
#  ('컨텐츠', 17),
#  ('온라인', 17),
#  ('어제', 17),
#  ('WTO', 17),
#  ('CNN', 16),
#  ('인터넷', 16),
#  ('관계자', 16),
#  ('해외', 16),
#  ('자신', 16),
#  ('한편', 16),
#  ('그런데', 16),
#  ('수준', 16),
#  ('투자', 16),
#  ('과정', 16),
#  ('전해지다', 16),
#  ('지갑', 16),
#  ('쌍둥이', 16),
#  ('영어', 16),
#  ('임대', 16),
#  ('콘텐트', 16),
#  ('중국', 16),
#  ('침범', 16),
#  ('4월', 15),
#  ('업계', 15),
#  ('지난해', 15),
#  ('다양하다', 15),
#  ('미성년', 15),
#  ('구호', 15),
#  ('디지털', 15),
#  ('결과', 15),
#  ('등장', 15),
#  ('얻다', 15),
#  ('자체', 15),
#  ('경찰', 15),
#  ('위치', 15),
#  ('비판', 15),
#  ('중심', 15),
#  ('여기', 15),
#  ('목소리', 15),
#  ('전체', 15),
#  ('놀이', 15),
#  ('독도', 15),
#  ('기사', 14),
#  ('스타', 14),
#  ('매일경제', 14),
#  ('키우다', 14),
#  ('교육', 14),
#  ('발생', 14),
#  ('요즘', 14),
#  ('구글', 14),
#  ('직접', 14),
#  ('개인', 14),
#  ('유튜버들', 14),
#  ('모르다', 14),
#  ('이제', 14),
#  ('비슷하다', 14),
#  ('맞다', 14),
#  ('청와대', 14),
#  ('최대', 14),
#  ('커뮤니티', 14),
#  ('1700만', 14),
#  ('자산', 14),
#  ('ID', 14),
#  ('출연', 13),
#  ('바로가기', 13),
#  ('그러나', 13),
#  ('정책', 13),
#  ('스마트폰', 13),
#  ('현실', 13),
#  ('특히', 13),
#  ('계속', 13),
#  ('이슈', 13),
#  ('10', 13),
#  ('사건', 13),
#  ('좋아하다', 13),
#  ('SNS', 13),
#  ('만큼', 13),
#  ('제재', 13),
#  ('의견', 13),
#  ('안전', 13),
#  ('놀다', 13),
#  ('언어', 13),
#  ('설정', 13),
#  ('찍다', 13),
#  ('보도', 12),
#  ('3000만', 12),
#  ('자수', 12),
#  ('삭제', 12),
#  ('사용', 12),
#  ('비롯', 12),
#  ('쉬다', 12),
#  ('친구', 12),
#  ('추다', 12),
#  ('해주다', 12),
#  ('확보', 12),
#  ('그러면', 12),
#  ('회수', 12),
#  ('어리다', 12),
#  ('조금', 12),
#  ('하나', 12),
#  ('수사', 12),
#  ('당하다', 12),
#  ('24일', 12),
#  ('이러하다', 12),
#  ('반복', 12),
#  ('내리다', 12),
#  ('대다', 12),
#  ('비난', 12),
#  ('보기', 12),
#  ('읽다', 12),
#  ('능력', 12),
#  ('의원', 12),
#  ('회장', 12),
#  ('양은', 11),
#  ('기록', 11),
#  ('가정법원', 11),
#  ('비공개', 11),
#  ('전환', 11),
#  ('시작', 11),
#  ('성공', 11),
#  ('하루', 11),
#  ('차이', 11),
#  ('더욱', 11),
#  ('책임', 11),
#  ('인식', 11),
#  ('필요하다', 11),
#  ('국가', 11),
#  ('치다', 11),
#  ('주로', 11),
#  ('가능하다', 11),
#  ('전문가', 11),
#  ('우리나라', 11),
#  ('기도', 11),
#  ('들어오다', 11),
#  ('제공', 11),
#  ('지다', 11),
#  ('성공하다', 11),
#  ('물론', 11),
#  ('차지', 11),
#  ('박탈', 11),
#  ('서울시', 11),
#  ('인턴', 11),
#  ('임신', 11),
#  ('신문', 11),
#  ('공개', 11),
#  ('수요', 11),
#  ('직장인', 11),
#  ('앵커', 11),
#  ('불매운동', 11),
#  ('가지다', 10),
#  ('정서', 10),
#  ('17억', 10),
#  ('라이언', 10),
#  ('3억', 10),
#  ('보호처분', 10),
#  ('사례', 10),
#  ('가능성', 10),
#  ('주요', 10),
#  ('명의', 10),
#  ('나타나다', 10),
#  ('낮다', 10),
#  ('자녀', 10),
#  ('계시다', 10),
#  ('정보', 10),
#  ('들어가다', 10),
#  ('정말', 10),
#  ('처음', 10),
#  ('클릭', 10),
#  ('붙다', 10),
#  ('이후', 10),
#  ('어렵다', 10),
#  ('오전', 10),
#  ('40억원', 10),
#  ('상대', 10),
#  ('시대', 10),
#  ('요리', 10),
#  ('출산', 10),
#  ('연기', 10),
#  ('연예인', 10),
#  ('측은', 10),
#  ('1억', 10),
#  ('꼽히다', 10),
#  ('진입', 10),
#  ('진행', 10),
#  ('카페', 10),
#  ('포함', 10),
#  ('최소', 10),
#  ('경고', 10),
#  ('모으다', 10),
#  ('협찬', 10),
#  ('월세', 10),
#  ('직업', 10),
#  ('이사회', 10),
#  ('볼턴', 10),
#  ('검찰', 10),
#  ('선수', 10),
#  ('삼성', 10),
#  ('26일', 9),
#  ('258.3', 9),
#  ('단독', 9),
#  ('제품', 9),
#  ('언론', 9),
#  ('주목', 9),
#  ('3천만', 9),
#  ('9월', 9),
#  ('설명', 9),
#  ('발표', 9),
#  ('활동', 9),
#  ('마련', 9),
#  ('어마어마하다', 9),
#  ('예전', 9),
#  ('동안', 9),
#  ('대부분', 9),
#  ('사다', 9),
#  ('나다', 9),
#  ('업로드', 9),
#  ('촬영', 9),
#  ('그러니까', 9),
#  ('자다', 9),
#  ('대가', 9),
#  ('화면', 9),
#  ('당연하다', 9),
#  ('열심히', 9),
#  ('장면', 9),
#  ('스스로', 9),
#  ('항의', 9),
#  ('게시판', 9),
#  ('3일', 9),
#  ('고통', 9),
#  ('다수', 9),
#  ('불거지다', 9),
#  ('변호사', 9),
#  ('14', 9),
#  ('무리하다', 9),
#  ('노동', 9),
#  ('장벽', 9),
#  ('네티즌', 9),
#  ('150만', 9),
#  ('37억', 9),
#  ('상위', 9),
#  ('자리', 9),
#  ('홈페이지', 9),
#  ('제보', 9),
#  ('누리꾼', 9),
#  ('이양', 9),
#  ('조치', 9),
#  ('연간', 9),
#  ('소재', 9),
#  ('징역', 9),
#  ('수출', 9),
#  ('이번', 9),
#  ('규모', 8),
#  ('내다', 8),
#  ('노출', 8),
#  ('또한', 8),
#  ('정확하다', 8),
#  ('훌쩍', 8),
#  ('개월', 8),
#  ('제한', 8),
#  ('10만', 8),
#  ('1년', 8),
#  ('KBS', 8),
#  ('두다', 8),
#  ('분들', 8),
#  ('인정', 8),
#  ('상당하다', 8),
#  ('일이', 8),
#  ('크게', 8),
#  ('대로', 8),
#  ('특정', 8),
#  ('너무', 8),
#  ('얼마', 8),
#  ('목적', 8),
#  ('명확하다', 8),
#  ('뛰어들다', 8),
#  ('도로', 8),
#  ('자기', 8),
#  ('머니투데이', 8),
#  ('대형', 8),
#  ('담기다', 8),
#  ('과연', 8),
#  ('뜨겁다', 8),
#  ('인형', 8),
#  ('다리', 8),
#  ('사과', 8),
#  ('성인', 8),
#  ('산업', 8),
#  ('기업', 8),
#  ('지역', 8),
#  ('겁니다', 8),
#  ('적지', 8),
#  ('3.3', 8),
#  ('1975년', 8),
#  ('동요', 8),
#  ('160만', 8),
#  ('결국', 8),
#  ('행위', 8),
#  ('헤어', 8),
#  ('유통', 8),
#  ('유통업', 8),
#  ('세상', 8),
#  ('먹방', 8),
#  ('가격', 8),
#  ('꼬마', 8),
#  ('비교', 8),
#  ('5년', 8),
#  ('잠수함', 8),
#  ('영향', 7),
#  ('8000만원', 7),
#  ('새롭다', 7),
#  ('부르다', 7),
#  ('얼마나', 7),
#  ('증가', 7),
#  ('이용자', 7),
#  ('늘어나다', 7),
#  ('이하', 7),
#  ('비결', 7),
#  ('먼저', 7),
#  ('프로그램', 7),
#  ('살인', 7),
#  ('궁금하다', 7),
#  ('편집', 7),
#  ('드리다', 7),
#  ('로부터', 7),
#  ('중인', 7),
#  ('나누다', 7),
#  ('달라지다', 7),
#  ('뛰다', 7),
#  ('서비스', 7),
#  ('업체', 7),
#  ('부분', 7),
#  ('적다', 7),
#  ('사고', 7),
#  ('성장하다', 7),
#  ('상태', 7),
#  ('많아지다', 7),
#  ('입장', 7),
#  ('의사', 7),
#  ('정신', 7),
#  ('이익', 7),
#  ('평범하다', 7),
#  ('6월', 7),
#  ('모든', 7),
#  ('중이', 7),
#  ('게시', 7),
#  ('그대로', 7),
#  ('통감', 7),
#  ('인근', 7),
#  ('모델링', 7),
#  ('용도', 7),
#  ('2000만원', 7),
#  ('기능', 7),
#  ('분위기', 7),
#  ('엄청나다', 7),
#  ('24시간', 7),
#  ('생방송', 7),
#  ('PLUS', 7),
#  ('여러', 7),
#  ('페이스북', 7),
#  ('추가', 7),
#  ('성장', 7),
#  ('커지다', 7),
#  ('아직', 7),
#  ('예상', 7),
#  ('재생', 7),
#  ('댄스', 7),
#  ('직장', 7),
#  ('위반', 7),
#  ('신청', 7),
#  ('오르다', 7),
#  ('중개업', 7),
#  ('차례', 7),
#  ('보증금', 7),
#  ('법인', 7),
#  ('고등학교', 7),
#  ('오히려', 7),
#  ('회의', 7),
#  ('논의', 7),
#  ('사격', 7),
#  ('이태임', 7),
#  ('연세대', 7),
#  ('반면', 7),
#  ('그다음', 7),
#  ('MBC', 7),
#  ('공표', 7),
#  ('대지면적', 6),
#  ('미치다', 6),
#  ('각각', 6),
#  ('19억원', 6),
#  ('방법', 6),
#  ('시세', 6),
#  ('둘러싸다', 6),
#  ('다음', 6),
#  ('기관', 6),
#  ('제기', 6),
#  ('코리아', 6),
#  ('은희', 6),
#  ('영유', 6),
#  ('어른', 6),
#  ('연령', 6),
#  ('의하다', 6),
#  ('보통', 6),
#  ('이미지', 6),
#  ('일반', 6),
#  ('학원', 6),
#  ('연구', 6),
#  ('집중', 6),
#  ('걱정', 6),
#  ('식당', 6),
#  ('강조', 6),
#  ('글로벌', 6),
#  ('마음', 6),
#  ('누르다', 6),
#  ('라이브', 6),
#  ('후원', 6),
#  ('계좌', 6),
#  ('생기다', 6),
#  ('어느', 6),
#  ('저희', 6),
#  ('주변', 6),
#  ('중요하다', 6),
#  ('버튼', 6),
#  ('붙이다', 6),
#  ('번째', 6),
#  ('말씀', 6),
#  ('소비', 6),
#  ('건너', 6),
#  ('뜨다', 6),
#  ('그것', 6),
#  ('고요', 6),
#  ('바뀌다', 6),
#  ('결정', 6),
#  ('세금', 6),
#  ('공포', 6),
#  ('표현', 6),
#  ('자유', 6),
#  ('재미있다', 6),
#  ('이미', 6),
#  ('흐름', 6),
#  ('기회', 6),
#  ('진짜', 6),
#  ('민선', 6),
#  ('불량', 6),
#  ('정상', 6),
#  ('일정', 6),
#  ('일상생활', 6),
#  ('법원', 6),
#  ('조명', 6),
#  ('억대', 6),
#  ('막대', 6),
#  ('절단', 6),
#  ('필요', 6),
#  ('이름', 6),
#  ('무려', 6),
#  ('충분하다', 6),
#  ('보여주다', 6),
#  ('마치', 6),
#  ('자연', 6),
#  ('마땅하다', 6),
#  ('이처럼', 6),
#  ('일본어', 6),
#  ('추산', 6),
#  ('따다', 6),
#  ('경쟁', 6),
#  ('오후', 6),
#  ('요인', 6),
#  ('높아지다', 6),
#  ('피해', 6),
#  ('엄마', 6),
#  ('SBS', 6),
#  ('대사', 6),
#  ('단어', 6),
#  ('공연', 6),
#  ('경영', 6),
#  ('준비', 6),
#  ('게재', 6),
#  ('한경닷컴', 6),
#  ('25일', 6),
#  ('음악', 6),
#  ('순위', 6),
#  ('문화', 6),
#  ('해먹', 6),
#  ('사무실', 6),
#  ('올라가다', 6),
#  ('나서다', 6),
#  ('제소', 6),
#  ('게임', 6),
#  ('등기부', 6),
#  ('등본', 6),
#  ('창업', 6),
#  ('생활', 6),
#  ('구급차', 6),
#  ('2년', 6),
#  ('선고', 6),
#  ('서다', 6),
#  ('재산', 6),
#  ('본인', 6),
#  ('시각', 6),
#  ('예정', 6),
#  ('워드', 6),
#  ('보좌', 6),
#  ('갈등', 6),
#  ('KADIZ', 6),
#  ('학생', 6),
#  ('효과', 6),
#  ('올림픽', 6),
#  ('북한', 6),
#  ('회복', 6),
#  ('단가', 6),
#  ('이재용', 6),
#  ('뉴시스', 5),
#  ('37억원', 5),
#  ('310만', 5),
#  ('부적절하다', 5),
#  ('수만', 5),
#  ('라면', 5),
#  ('상담', 5),
#  ('2018년', 5),
#  ('집계', 5),
#  ('면서', 5),
#  ('칼럼', 5),
#  ('꿈꾸다', 5),
#  ('과도', 5),
#  ('또는', 5),
#  ('미만', 5),
#  ('대비', 5),
#  ('해보다', 5),
#  ('여부', 5),
#  ('지키다', 5),
#  ('Copyright', 5),
#  ('PPL', 5),
#  ('수도', 5),
#  ('이체', 5),
#  ('본부', 5),
#  ('라디오', 5),
#  ('9만', 5),
#  ('건가', 5),
#  ('훨씬', 5),
#  ('전혀', 5),
#  ('나이', 5),
#  ('그거', 5),
#  ('따라서', 5),
#  ('어쨌든', 5),
#  ('벌어지다', 5),
#  ('금액', 5),
#  ('보시', 5),
#  ('사랑', 5),
#  ('방식', 5),
#  ('몰다', 5),
#  ('털다', 5),
#  ('자랑', 5),
#  ('동의', 5),
#  ('강력하다', 5),
#  ('인권', 5),
#  ('개다', 5),
#  ('중간', 5),
#  ('넘기다', 5),
#  ('문어', 5),
#  ('없이', 5),
#  ('끄다', 5),
#  ('외국인', 5),
#  ('각국', 5),
#  ('육박', 5),
#  ('걸다', 5),
#  ('45%', 5),
#  ('육아', 5),
#  ('끌다', 5),
#  ('구청', 5),
#  ('2100만원', 5),
#  ('거치다', 5),
#  ('관측', 5),
#  ('합치다', 5),
#  ('숫자', 5),
#  ('한국어', 5),
#  ('스페인어', 5),
#  ('전망', 5),
#  ('만화', 5),
#  ('12월', 5),
#  ('아침', 5),
#  ('소유', 5),
#  ('월급', 5),
#  ('누적', 5),
#  ('판단', 5),
#  ('(https://joongang.co.kr', 5),
#  ('스포츠서울', 5),
#  ('공식', 5),
#  ('비도덕적', 5),
#  ('얼굴', 5),
#  ('긍정', 5),
#  ('평가', 5),
#  ('죄송', 5),
#  ('시행', 5),
#  ('아시아', 5),
#  ('남기다', 5),
#  ('바디', 5),
#  ('쓰이다', 5),
#  ('2억', 5),
#  ('아기', 5),
#  ('여성', 5),
#  ('달리다', 5),
#  ('자막', 5),
#  ('제조', 5),
#  ('엔터테인먼트', 5),
#  ('매매', 5),
#  ('쿠션', 5),
#  ('못지않다', 5),
#  ('수십', 5),
#  ('대다수', 5),
#  ('가이드라인', 5),
#  ('방문', 5),
#  ('모바일', 5),
#  ('모델', 5),
#  ('강화', 5),
#  ('내놓다', 5),
#  ('캡쳐', 5),
#  ('3억원', 5),
#  ('연관', 5),
#  ('눈물', 5),
#  ('다니다', 5),
#  ('부상', 5),
#  ('40', 5),
#  ('문의', 5),
#  ('다만', 5),
#  ('묻다', 5),
#  ('상상', 5),
#  ('다르다', 5),
#  ('조물주', 5),
#  ('KB', 5),
#  ('살다', 5),
#  ('전투기', 5),
#  ('폭격기', 5),
#  ('카디즈', 5),
#  ('구역', 5),
#  ('외교부', 5),
#  ('이데일리', 5),
#  ('김성태', 5),
#  ('기소', 5),
#  ('구속', 5),
#  ('2014년', 5),
#  ('나무숲', 5),
#  ('대학', 5),
#  ('재밌다', 5),
#  ('방사', 5),
#  ('훈련', 5),
#  ('조선일보', 5),
#  ('흘리다', 5),
#  ('반도체', 5),
#  ('차유람', 5),
#  ('이병철', 5),
#  ('1993년', 5),
#  ('행복하다', 5),
#  ('구형', 5),
#  ('갈무리', 4),
#  ('현지', 4),
#  ('등기', 4),
#  ('윤리', 4),
#  ('밉다', 4),
#  ('수천', 4),
#  ('수백만', 4),
#  ('카메라', 4),
#  ('자세하다', 4),
#  ('표시', 4),
#  ('악용', 4),
#  ('크립', 4),
#  ('허브', 4),
#  ('피펫', 4),
#  ('news', 4),
#  ('kr', 4),
#  ('재테크', 4),
#  ('비례', 4),
#  ('이어지다', 4),
#  ('중요', 4),
#  ('미디어오늘', 4),
#  ('방안', 4),
#  ('2015년', 4),
#  ('비다', 4),
#  ('엄격하다', 4),
#  ('2012년', 4),
#  ('인천', 4),
#  ('주기도', 4),
#  ('달다', 4),
#  ('종류', 4),
#  ('대체', 4),
#  ('실시', 4),
#  ('또래', 4),
#  ('달라', 4),
#  ('우편', 4),
#  ('1천', 4),
#  ('시사', 4),
#  ('7월', 4),
#  ('차다', 4),
#  ('특성', 4),
#  ('실버', 4),
#  ('계정', 4),
#  ('약간', 4),
#  ('플랫폼', 4),
#  ('즐기다', 4),
#  ('건지다', 4),
#  ('되어다', 4),
#  ('그게', 4),
#  ('잡다', 4),
#  ('구체', 4),
#  ('말다', 4),
#  ('역할', 4),
#  ('홍보', 4),
#  ('그렇게', 4),
#  ('경험', 4),
#  ('신고', 4),
#  ('인하다', 4),
#  ('다시', 4),
#  ('시장', 4),
#  ('돌리다', 4),
#  ('덧붙이다', 4),
#  ('몇몇', 4),
#  ('금전', 4),
#  ('취했다', 4),
#  ('서민', 4),
#  ('심정은', 4),
#  ('이코노미스트', 4),
#  ('가정', 4),
#  ('담소', 4),
#  ('리얼타임', 4),
#  ('노컷뉴스', 4),
#  ('가량', 4),
#  ('핵심', 4),
#  ('중소기업', 4),
#  ('케이팝', 4),
#  ('전기', 4),
#  ('왕문', 4),
#  ('기존', 4),
#  ('순간', 4),
#  ('안되다', 4),
#  ('걸리다', 4),
#  ('30억원', 4),
#  ('안팎', 4),
#  ('55%', 4),
#  ('억원', 4),
#  ('대박', 4),
#  ('8000만', 4),
#  ('열리다', 4),
#  ('구성', 4),
#  ('매체', 4),
#  ('응답', 4),
#  ('이루다', 4),
#  ('이해', 4),
#  ('자료', 4),
#  ('예측', 4),
#  ('챙기다', 4),
#  ('자만', 4),
#  ('주식회사', 4),
#  ('움직임', 4),
#  ('폭발', 4),
#  ('배경', 4),
#  ('이끌다', 4),
#  ('사기', 4),
#  ('꾸준하다', 4),
#  ('초창', 4),
#  ('가슴', 4),
#  ('상처', 4),
#  ('지하철', 4),
#  ('보이', 4),
#  ('이뤄지다', 4),
#  ('개설', 4),
#  ('무료', 4),
#  ('프렌', 4),
#  ('확장', 4),
#  ('유도', 4),
#  ('유행', 4),
#  ('도전', 4),
#  ('서은', 4),
#  ('악플', 4),
#  ('한경', 4),
#  ('hankyung.com', 4),
#  ('쏟아내다', 4),
#  ('내보내다', 4),
#  ('국민일보', 4),
#  ('써다', 4),
#  ('짚다', 4),
#  ('로만', 4),
#  ...]

# %%
# 내림차순 정렬된 단어 중 상위 50개를 살펴보면 다음과 같습니다.

# ('보람', 517),
for word, count in sorted_word_dic[:50]:
    print("{0}({1})".format(word, count), end=" ") #print("{}({})".format(word, count)
# Out:
# 보람(517) 튜브(356) 유튜브(316) 채널(276) 영상(188) 수익(187) 광고(155) 빌딩(146) 유튜버(144) 보다(131) 아이(123) 독자(118) 받다(102) 콘텐츠(100) 뉴스(93) 많다(85) 늘다(81) 가족(79) 리뷰(77) 올리다(76) 아동(75) 매입(74) 부모(74) 따르다(72) 한국(71) 로그(70) 패밀리(69) 브이(68) 토이(66) 사실(66) 동영상(66) 회사(66) 알려지다(62) 아동학대(62) 가다(62) 무단(61) 나오다(61) 키즈(61) 강남(61) 같다(60) 구독(59) 장난감(59) 기자(58) 논란(58) 최근(57) 금지(57) 인기(55) 배포(55) 넘다(51) 우리(51)

# %% [markdown]
# <br>
#
# ### 2-4) 단어 등장 빈도 시각화

# %%
# matplot 에서 한글을 표시하기 위한 설정입니다.
# 맑은고딕 대신 나눔고딕 폰트를 사용하려면 [나눔고딕파일] 폴더의 파일들을 복사하여, C drive -> Windows -> Fonts 폴더 안에 붙여넣기합니다.

import nltk
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# 한글 폰트 위치를 넣어주세요 (위에서 나눔고딕 파일을 해당 경로에 복사붙여넣기 했을 경우 그대로 실행하셔도 무방합니다.)
font_name = matplotlib.font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name() # NanumGothic.otf
matplotlib.rc('font', family=font_name)

# %%
# nltk 라이브러리는 단어의 등장 빈도를 더욱 쉽게 셀 수 있는 .Text() 함수를 제공합니다.

word_counted = nltk.Text(word_cleaned) 
plt.figure(figsize=(15, 7)) # plot 영역(그래프 영역)의 크기를 지정합니다.
word_counted.plot(50) # "plot" the graph, 상위 50개 단어를 보여줍니다.

# %% [markdown]
# <br>
#
# ### 2-5) 단어 등장 빈도 시각화 (막대그래프)

# %%
# 막대그래프로의 시각화는 NLTK 의 함수만으로 진행하기 어려우므로,
# NLTK의 FreqDist 함수를 적용한 후 Pandas의 Dataframe에 데이터를 담은 다음 시각화를 진행합니다.

word_frequency = nltk.FreqDist(word_cleaned) # Frequency Distribution
word_frequency
# Out:
# FreqDist({'보람': 517, '튜브': 356, '유튜브': 316, '채널': 276, '영상': 188, '수익': 187, '광고': 155, '빌딩': 146, '유튜버': 144, '보다': 131, ...})

# %%
# 단어 빈도가 담긴 Dict 로부터 값을 가져와 DataFrame 을 만듭니다.
df = pd.DataFrame(list(word_frequency.values()), word_frequency.keys()) 

# df.head()

# 빈도 내림차순으로 정렬합니다.
result = df.sort_values([0], ascending=False)

# 전체 데이터(단어 수)는 너무 많기 때문에 출현 횟수 상위 50개만 가져와 시각화합니다.
result = result[:50]
# result

# %%
# 데이터프레임에 담긴 단어 및 빈도 수를 막대그래프로 표현하기 위한 코드입니다.

result.plot(kind='bar', legend=False, figsize=(15,5)) # 'bar' graph
# 그림 사이즈를 변경하고 싶을 경우 figsize=(가로, 세로) 를 변경합니다.
# 기타 그래프 관련 옵션은 https://goo.gl/YNejGt 에서 확인하고 적용하실 수 있습니다.

plt.show()

# %% [markdown]
# <br>
# <br>
#
# ## 3. 워드클라우드 만들기

# %% [markdown]
# - 워드클라우드를 만들기에 앞서 WordCloud library 를 설치해주어야 합니다.
#
# - [ 시작메뉴 -  모든 프로그램 - Anaconda 3 - **Anaconda Prompt** ] 에서 아래 명령어를 입력합니다. (우클릭 후 **"관리자권한으로 실행"**)
# <br>**conda install -c https://conda.anaconda.org/conda-forge wordcloud==1.5.0**

# %%
# WordCloud 패키지를 import 합니다.
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image # 만약 "No module named 'PIL'" 에러가 발생하면 [ pip install Pillow==5.4.1 ] 로 라이브러리를 설치해줍니다.

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <br>
#
# #### 3-1) WordCloud - 하얀 바탕

# %%
# WordCloud 객체를 생성합니다.
# 아래 보이는 코드의 font_path 에 해당하는 부분이 워드클라우드의 폰트에 적용됩니다. (대체로 고딕 계열 폰트가 이쁘게 나옵니다)
# 만약 다른 폰트를 적용하려면, C > Windows > Fonts 폴더에 원하시는 폰트 파일(.ttf)을 넣은 후 아래 코드에서 font 이름을 수정해줍니다.

# word_cloud = WordCloud().generate(text) : dict 가 아닌 줄글 텍스트 원문으로부터 워드클라우드를 만들 수 있습니다.
word_cloud = WordCloud(font_path="C:/Windows/Fonts/malgun.ttf", # font_path="C:/Windows/Fonts/NanumSquareB.ttf"
                       width=2000, height=1000, # 이 부분을 수정하시면 실제 워드클라우드의 크기가 바뀝니다 (해상도가 바뀝니다)
                       # prefer_horizontal= 1.0, # 이 부분의 주석을 해제하시면 단어들이 가로로만 그려지게 됩니다. (0~1)
                       background_color='white')

# %%
word_cloud.generate_from_frequencies(word_dic) # Generate wordcloud from word "frequency" data.

# %%
# 생성한 WordCloud 객체로부터 워드클라우드를 보여주는 코드입니다.

plt.figure(figsize=(15,15)) # 이 부분을 수정하시면 화면에서 보여지는 워드클라우드의 크기가 바뀝니다 
plt.imshow(word_cloud) # image show
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# <br>
#
# #### 3-2) WordCloud - 하얀 바탕, 최대 단어 갯수 50

# %%
# max_words 라는 옵션을 통해 워드클라우드에 담길 단어의 최대 갯수를 제한할 수 있습니다.
# 기본적으로 옵션을 지정하지 않으면 200 으로 default 값이 지정되어 있습니다.

word_cloud = WordCloud(font_path="C:/Windows/Fonts/malgun.ttf", # font_path="C:/Windows/Fonts/NanumSquareB.ttf"
                       max_words=50, # max words
                       width=2000, height=1000, 
                       background_color='white').generate_from_frequencies(word_dic)


# 생성한 WordCloud 객체로부터 워드클라우드를 보여주는 코드입니다.

plt.figure(figsize=(15,15)) # 이 부분을 수정하시면 화면에서 보여지는 워드클라우드의 크기가 바뀝니다 
plt.imshow(word_cloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# <br>
#
# #### 3-3) WordCloud - 검정 바탕, 최대 폰트 사이즈 100

# %%
# max_font_size 라는 옵션을 통해 최대 글자 크기를 제한할 수 있습니다.

# 아래 옵션 중 어느 것을 지워줘야 바탕이 검정(default)이 될까요?
word_cloud = WordCloud(font_path="C:/Windows/Fonts/malgun.ttf", # font_path="C:/Windows/Fonts/NanumSquareB.ttf"
                       width=2000, height=1000, 
#                        background_color='black', 
                       max_font_size=100).generate_from_frequencies(word_dic) # Max font-size

plt.figure(figsize=(15,15))
plt.imshow(word_cloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# <br>
#
# #### 3-4) WordCloud - masking 적용 (특정 그림 테두리 내에 워드클라우드 그리기)

# %%
youtube_coloring = np.array(Image.open("youtube_mask.jpg"))

word_cloud = WordCloud(font_path="C:/Windows/Fonts/malgun.ttf", # font_path="C:/Windows/Fonts/NanumSquareB.ttf"
                       width=2000, height=1000, 
                       mask=youtube_coloring, # "마스크를 씌운다"라고 표현합니다. (masking)
                       background_color='white').generate_from_frequencies(word_dic)

plt.figure(figsize=(15,15))
plt.imshow(word_cloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# <br>
#
# #### 3-5) WordCloud - masking 적용 (특정 그림 테두리 내에 워드클라우드 그리기 & 그림 색상으로 전체 색상 통일)

# %%
from wordcloud import ImageColorGenerator # Image 로부터 Color 를 생성(Generate)해내는 객체입니다.

youtube_coloring = np.array(Image.open("youtube_mask.jpg"))
image_colors = ImageColorGenerator(youtube_coloring)

word_cloud = WordCloud(font_path="C:/Windows/Fonts/malgun.ttf", # font_path="C:/Windows/Fonts/NanumSquareB.ttf"
                       width=2000, height=1000,  
                       mask=youtube_coloring, 
                       background_color='white').generate_from_frequencies(word_dic)

plt.figure(figsize=(15,15))
plt.imshow(word_cloud.recolor(color_func=image_colors), interpolation='bilinear') # 다시(re) 색칠하기
# plt.imshow(word_cloud.?(colormap='Blues'), interpolation='bilinear') # Matplotlib colormap 활용 (http://j.mp/32UXOQ6)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# <br>
# <br>
#
# #### 3-6) 워드클라우드를 이미지 파일로 저장하기

# %%
# 아래 코드를 실행하시면 jupyter notebook 과 동일한 폴더에 워드클라우드가 이미지 파일로 저장된 것을 확인하실 수 있습니다.

word_cloud.to_file("word_cloud_completed.png") # Save "to file"

# %% [markdown]
# <br>
#
# #### 3-7) WordCloud 요약 (완성본)

# %%
# 아래 옵션들을 원하시는대로 지정하셔서 가장 마음에 드는 워드클라우드를 활용하시면 됩니다.

word_cloud = WordCloud(font_path="C:/Windows/Fonts/malgun.ttf", # 한글 폰트 변경
                       width=2000, height=1000, # 실제 워드클라우드 크기 변경 (해상도 변경)
                       max_words=100, # 최대로 보여질 단어 수 제한
                       background_color='white', # 바탕색 지정 (주석처리할 경우 검정으로 변경됨)
#                        max_font_size=100, # 최대 단어 크기 제한
                      ).generate_from_frequencies(word_dic)

plt.figure(figsize=(15,15)) # Jupyter notebook 상에서 보여지는 워드클라우드 크기 지정 
plt.imshow(word_cloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# word_cloud.to_file("word_cloud_7 (white, squared, max100).png")

# %% [markdown]
# <br>
#
# #### Appendix) Try other masks!

# %%
from wordcloud import ImageColorGenerator # Image 로부터 Color 를 생성(Generate)해내는 객체입니다.

korea_coloring = np.array(Image.open("other masks/korea_mask.jpg"))
# image_colors = ImageColorGenerator(korea_coloring)

word_cloud = WordCloud(font_path="fonts/NanumSquareB.ttf", 
                       width=1600, height=1000, 
                       mask=korea_coloring, 
                       background_color='white').generate_from_frequencies(word_dic)

plt.figure(figsize=(10,10))
plt.imshow(word_cloud.recolor(colormap='Reds'), interpolation='bilinear') # Matplotlib colormap 활용 (http://j.mp/32UXOQ6)
# plt.imshow(word_cloud.recolor(color_func=image_colors), interpolation='bilinear') # 다시(re) 색칠하기
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# word_cloud.to_file("other_masks_applied.png")
