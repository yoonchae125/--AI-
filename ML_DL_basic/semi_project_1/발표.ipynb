# %% [markdown]
# ## 필요한 Library import

# %%
import requests 
from bs4 import BeautifulSoup

import pandas as pd
from datetime import datetime
import time
import re

# %% [markdown]
# ## 네이버 뉴스에서 '부동산 대책 검사' 해 5페이지까지 기사 URL 수집

# %%
query = '부동산+대책'
url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query='+query 

urls_list = [] #기사 url 담을 list
for i in range(4): #0~4=> 5페이지까지
    url=url+"&start="+str(i*10+1) 

    web = requests.get(url).content
    source = BeautifulSoup(web, 'html.parser')

    for urls in source.find_all('a', {'class' : "_sp_each_url"}):
        if urls["href"].startswith("https://news.naver.com"): # 네이버 기사만 담기
            urls_list.append(urls["href"])

# %% [markdown]
# ## Selenium 과 BeautifulSoup <mark>이용한 기사의 댓글 수집</mark>

# %%
from selenium import webdriver

from bs4 import BeautifulSoup

import time


driver = webdriver.Chrome('./chromedriver') 
comments=[] #댓글들 담을 list
for url in urls_list:
    try:
        print(url+' 크롤링중')
        driver.get(url+'&m_view=1&includeAllCount=true') #댓글 페이지
        time.sleep(3) #댓글 불러오는 거 기다리기

        try:
            for i in range(0, 2) : #댓글 더보기 2페이지만
                driver.find_element_by_css_selector(".u_cbox_btn_more").click() #댓글 더보기 클릭
                time.sleep(3)
                i +=1



            html = driver.page_source

            bs = BeautifulSoup(html, 'html.parser')
        
            contents = bs.find_all("span", {"class" : "u_cbox_contents"}) #댓글 담긴 span tag 찾기
            for content in contents :
                comments.append(content.text)

        except: 
            print("댓글 2페이지까지 없어")
    except:
        print("없는 url")

print(comments)
# Out:
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=055&aid=0000779436 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=025&aid=0002961267 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004344799 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=023&aid=0003494200 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=215&aid=0000832238 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=022&aid=0003423147 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=469&aid=0000449640 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=032&aid=0002981303 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=047&aid=0002250186 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=020&aid=0003259416 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=277&aid=0004591342 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0011283042 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=214&aid=0001001360 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=032&aid=0002981291 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=029&aid=0002575224 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=214&aid=0001001359 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=016&aid=0001615445 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=119&aid=0002371329 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=366&aid=0000458863 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=003&aid=0009613531 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=055&aid=0000779436 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=025&aid=0002961267 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004344799 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=023&aid=0003494200 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=215&aid=0000832238 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=022&aid=0003423147 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=469&aid=0000449640 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=032&aid=0002981303 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=047&aid=0002250186 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=020&aid=0003259416 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=277&aid=0004591342 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0011283042 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=214&aid=0001001360 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=032&aid=0002981291 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=029&aid=0002575224 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=214&aid=0001001359 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=016&aid=0001615445 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=119&aid=0002371329 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=366&aid=0000458863 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=003&aid=0009613531 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=055&aid=0000779436 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=025&aid=0002961267 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004344799 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=023&aid=0003494200 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=215&aid=0000832238 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=022&aid=0003423147 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=469&aid=0000449640 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=032&aid=0002981303 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=047&aid=0002250186 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=020&aid=0003259416 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=277&aid=0004591342 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0011283042 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=214&aid=0001001360 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=032&aid=0002981291 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=029&aid=0002575224 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=214&aid=0001001359 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=016&aid=0001615445 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=119&aid=0002371329 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=366&aid=0000458863 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=003&aid=0009613531 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=055&aid=0000779436 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=025&aid=0002961267 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004344799 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=023&aid=0003494200 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=215&aid=0000832238 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=022&aid=0003423147 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=469&aid=0000449640 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=032&aid=0002981303 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=047&aid=0002250186 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=020&aid=0003259416 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=277&aid=0004591342 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0011283042 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=214&aid=0001001360 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=032&aid=0002981291 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=029&aid=0002575224 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=214&aid=0001001359 크롤링중
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=016&aid=0001615445 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=119&aid=0002371329 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=366&aid=0000458863 크롤링중
# 댓글 2페이지까지 없어
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=003&aid=0009613531 크롤링중
# 댓글 2페이지까지 없어
# ['서울시상 급여는 최저임수준으로 낮추어야합니다.박원순시장 말고도  잘 할사람 많습니다.', '10년 가까운 세월동안 서울시 경쟁력 망가트린 못난이 그런대도 시장 노릇을 하고 있으니 이게 서울의 민도인가... 하기사 지방선거 대부분이 북풍 영향 받아 싹쓸이 좌파세상으로 변했지. 아들이나 찾아라 이것아.. 뭔 애비가 자식 어디 있는지 모른다 시침이를 떼는것인지. 사회주의화 되는 서울시를 더는 못 보것다', '김현미장관과 비슷하게 시장을 잘못 파악하고 있구먼... 그런 식견으로 무슨 대권을 넘보시나? 시골내려가셔서 이장님 하시면 딱인데...', '시민의 혈세를 물쓰듯 펑펑 쓰는 박원순 시장은 퇴진하라.', '왜 차라리 몰수해서 정은이에게 바치지', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
오던집인데~  갑자기 집값올랐다고 죄인된거마냥~ 그렇게 세금으로 왕창 뜯어내려는건~ 이건 아니지~ 이게 공산주의지 뭐냐~ 날강도같은 자슥아~ 박원순 딱 200만원만 받자 그 이상도 그이하도 아니다 전라도 빼고 총선에서 더불당 정의당은 OUT 이 등신은 아침부터 무어라고 씨부리노 평생을 남의 돈을 지 쌈짓돈 처럼 쓴 박원숭 같은 새끼들은 기생세로 월급 차압해야 할 것 같은데?? 시장 관사 없애고 밖에서 사세요국민 세금 아깝습니다 아웃될듯하다.오로지 세금 걷을 목적이군요. 박원순  협찬인생으로  살았잔아  개소리 하지말고  사라저라  이  개같은 인간아  너희는 숨쉬는것외는  다 것말 ...

# %%
# comments_str 저장
save=open("naver_comments.txt", 'w' , encoding='utf-8' )
save.write(comments_str)
save.close()

# %% [markdown]
# ## 단어 정규화 및 어근화, 품사 태깅

# %%
from collections import Counter
from konlpy.tag import Twitter

twitter = Twitter()
raw_pos_tagged = twitter.pos(comments_str, norm=True, stem=True)

# raw_pos_tagged

# 조사, 어미, 구두점을 제외한 나머지 단어들을 모두 word_cleaned 리스트에 담습니다.
# 유의미한 의미를 갖고 있지 않은 단어를 제외할 수 있습니다.
del_list = ['하다', '있다', '되다', '이다', '돼다', '않다', '그렇다', '아니다', '이렇다', '그렇다','어떻다','ㅋㅋ','ㅋㅋㅋ','ㅠㅠ','ㅉㅉ','ㅎㅎ','없다','위해','완전','절대','그게','아무','건가','나다','모두','이미','저런','같다'] #삭제할 것들
word_cleaned = []
for word in raw_pos_tagged:
    if not word[1] in ["Josa", "Eomi", "Punctuation", "Foreign","Adverb","Suffix"]: # Foreign == ”, “ 와 같이 제외되어야할 항목들
        if (len(word[0]) != 1) & (word[0] not in del_list): # 한 글자로 이뤄진 단어들을 제외 & 원치 않는 단어들을 제외
            if(word[0].isalpha()): #숫자 뺌
                word_cleaned.append(word[0])
# Out:
# /Users/chaeyoon/opt/anaconda3/lib/python3.7/site-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# /Users/chaeyoon/opt/anaconda3/lib/python3.7/site-packages/jpype/_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)

# %%
word_cleaned
# Out:
# ['서울시',
#  '급여',
#  '최저',
#  '수준',
#  '낮추다',
#  '야하다',
#  '박원순',
#  '시장',
#  '자다',
#  '사람',
#  '많다',
#  '가깝다',
#  '세월',
#  '동안',
#  '서울시',
#  '경쟁력',
#  '가트',
#  '못난이',
#  '그런',
#  '대도',
#  '시장',
#  '노릇',
#  '서울',
#  '도인',
#  '지방선거',
#  '대부분',
#  '북풍',
#  '영향',
#  '받다',
#  '쓸다',
#  '좌파',
#  '세상',
#  '변하다',
#  '아들',
#  '찾다',
#  '애비',
#  '자식',
#  '어디',
#  '모르다',
#  '시침',
#  '떼다',
#  '사회주의',
#  '서울시',
#  '보다',
#  '김현미',
#  '장관',
#  '비슷하다',
#  '시장',
#  '잘못',
#  '파악',
#  '식견',
#  '무슨',
#  '대권',
#  '넘다',
#  '보시',
#  '시골',
#  '내려가다',
#  '이장님',
#  '딱이다',
#  '시민',
#  '혈세',
#  '쓰다',
#  '펑펑',
#  '쓰다',
#  '박원순',
#  '시장',
#  '퇴진',
#  '차라리',
#  '몰수',
#  '정은',
#  '바치',
#  '지다',
#  '재산',
#  '돌리다',
#  '마이너스',
#  '지랄',
#  '재산',
#  '마이너스',
#  '어찌',
#  '그리다',
#  '고급',
#  '갖다',
#  '사다',
#  '그리고',
#  '아들',
#  '새끼',
#  '유학',
#  '보내다',
#  '아들',
#  '찾다',
#  '정권',
#  '바뀌다',
#  '좋다',
#  '나라',
#  '혼란',
#  '숭숭',
#  '정치',
#  '경제',
#  '안보',
#  '민생',
#  '불안하다',
#  '바람',
#  '잘나다',
#  '살다',
#  '진짜',
#  '사회주의',
#  '정권',
#  '잡다',
#  '하향',
#  '평준화',
#  '고만고만하다',
#  '좋다',
#  '기회',
#  '공정하다',
#  '지다',
#  '결과',
#  '공정하다',
#  '북한',
#  '북한',
#  '좋다',
#  '제발',
#  '가라',
#  '좌파',
#  '세금',
#  '뜯다',
#  '국민',
#  '가난하다',
#  '만들다',
#  '지다',
#  '들이다',
#  '펑펑',
#  '쓰다',
#  '해처',
#  '먹다',
#  '안다',
#  '효과',
#  '나라',
#  '점점',
#  '가난하다',
#  '박원순',
#  '지난',
#  '서울',
#  '서울',
#  '점점',
#  '퇴보하다',
#  '집값',
#  '폭등',
#  '기생충',
#  '살찌다',
#  '국민',
#  '점점',
#  '가난하다',
#  '지다',
#  '아이러니',
#  '민주당',
#  '인사',
#  '번지르르하다',
#  '서민',
#  '보다',
#  '한국',
#  '교활하다',
#  '악랄하다',
#  '미세먼지',
#  '잡다',
#  '세금',
#  '무료',
#  '교통',
#  '쓸다',
#  '인간',
#  '머리',
#  '나오다',
#  '얘기',
#  '집값',
#  '폭등',
#  '공감',
#  '해법',
#  '사회주의',
#  '생각',
#  '씁쓸하다',
#  '정책',
#  '당국자',
#  '잘못',
#  '서울',
#  '갖다',
#  '살다',
#  '사람',
#  '무슨',
#  '지다',
#  '등록세',
#  'OECD',
#  '평균',
#  '높다',
#  '인하',
#  '평균',
#  '정도',
#  '맞추다',
#  '야하다',
#  '내리다',
#  '내리다',
#  '올리다',
#  '야하다',
#  '서울시',
#  'OECD',
#  '국가',
#  '도시',
#  '경쟁력',
#  '하락',
#  '박원순',
#  '시장',
#  '책임지다',
#  '물러나다',
#  '위선',
#  '인종',
#  '뮌소릴',
#  '세금',
#  '걷다',
#  '처럼',
#  '세금',
#  '쓰다',
#  '그대',
#  '가을',
#  '톡톡하다',
#  '받다',
#  '야하다',
#  '시장님',
#  '시장님',
#  '의하다',
#  '서울',
#  '재건축',
#  '재개발',
#  '아파트',
#  '규제',
#  '깍두기',
#  '아파트',
#  '규제',
#  '부동산',
#  '가격',
#  '폭등',
#  '만들다',
#  '일조',
#  '공정하다',
#  '공평하다',
#  '세금',
#  '인상',
#  '필요하다',
#  '규제',
#  '파다',
#  '고층',
#  '건설',
#  '급량',
#  '증가',
#  '검토',
#  '대상',
#  '아들',
#  '어딨다',
#  '면제',
#  '받다',
#  '엑스레이',
#  '제출',
#  '아들',
#  '었다',
#  '돌리다',
#  '끄다',
#  '당장',
#  '부동산',
#  '국민',
#  '공유',
#  '머릿속',
#  '빨갱이',
#  '수준',
#  '종부세',
#  '올리다',
#  '세수',
#  '누구',
#  '퍼주려',
#  '시장',
#  '보이다',
#  '지다',
#  '책임',
#  '하나',
#  '서울시',
#  '올리다',
#  '박원숭',
#  '서울시장',
#  '걷다',
#  '김어준',
#  '고요',
#  '총선',
#  '더불다',
#  '작살',
#  '날다',
#  '종부세',
#  'ㅁㅊ',
#  '처음',
#  '아파트',
#  '가격',
#  '자다',
#  '조정',
#  '뒷북',
#  '발등',
#  '찍다',
#  '한국',
#  '싫다',
#  '하지만',
#  '다음',
#  '선거',
#  '한국',
#  '찍다',
#  '가다',
#  '그냥',
#  '잡다',
#  '죽이다',
#  '누가',
#  '집값',
#  '올리다',
#  '달라',
#  '집값덕',
#  '이익',
#  '보다',
#  '그냥',
#  '아파트',
#  '채다',
#  '세금',
#  '때리다',
#  '수입',
#  '살라',
#  '누가',
#  '서울',
#  '시집',
#  '올리다',
#  '용산',
#  '여의도',
#  '이제',
#  '서다',
#  '충격',
#  '종부세',
#  '올리다',
#  '공급',
#  '충분하다',
#  '서울시장',
#  '자격',
#  '사람',
#  '먹다',
#  '시장',
#  '지내다',
#  '멍청하다',
#  '미세먼지',
#  '때문',
#  '헛돈',
#  '쓰다',
#  '저러다',
#  '세금',
#  '월급',
#  '챙기다',
#  '화가',
#  '세번',
#  '찍다',
#  '무상급식',
#  '이제야',
#  '정신',
#  '차려',
#  '시민',
#  '박원순',
#  '시장',
#  '서울',
#  '용성',
#  '신축',
#  '일반',
#  '아파트',
#  '기준',
#  '유세',
#  '대략',
#  '현재',
#  '올린다',
#  '정부',
#  '이전',
#  '집값',
#  '주택',
#  '사람',
#  '올리다',
#  '투기',
#  '따다',
#  '가도',
#  '가격',
#  '아파트',
#  '이사',
#  '가면',
#  '도세',
#  '거래',
#  '그렇다고',
#  '지방',
#  '갈다',
#  '평범하다',
#  '중산층',
#  '잡아먹다',
#  '안달',
#  '집값',
#  '오르다',
#  '세금',
#  '왕창',
#  '걷다',
#  '열광하다',
#  '희다',
#  '들다',
#  '살다',
#  '거지',
#  '국가',
#  '북한',
#  '베네수엘라',
#  '내버리다',
#  '시기',
#  '질투',
#  '산다',
#  '밥맛',
#  '떨어지다',
#  '면상',
#  '주다',
#  '사회주의',
#  '국가',
#  '시장',
#  '맡다',
#  '실패하다',
#  '안되다',
#  '논리',
#  '처음',
#  '어보',
#  '미국',
#  '유세',
#  '이야기',
#  '미국',
#  '공시지가',
#  '시세',
#  '변동',
#  '기준',
#  '구매',
#  '당시',
#  '금액',
#  '기준',
#  '유세',
#  '과세',
#  '일단',
#  '구매',
#  '이후',
#  '상승',
#  '대해',
#  '서다',
#  '도세',
#  '내면',
#  '이야기',
#  '우리',
#  '나라',
#  '상승',
#  '대해',
#  '유세',
#  '도세',
#  '이중',
#  '과세',
#  '구조',
#  '종부세',
#  '작년',
#  '비다',
#  '오르다',
#  '강남',
#  '근처',
#  '집도',
#  '그것',
#  '가다',
#  '노원구',
#  '아파트',
#  '올린다',
#  '파다',
#  '강남',
#  '채다',
#  '살다',
#  '금액',
#  '정권',
#  '해도',
#  '정권',
#  '지지',
#  '찍다',
#  '이런',
#  '계속',
#  '정책',
#  '펴다',
#  '우리나라',
#  '재벌',
#  '빈민',
#  '살아나다',
#  '무조건',
#  '세금',
#  '올리다',
#  '중산층',
#  '사라지다',
#  '아끼다',
#  '절약',
#  '저축',
#  '성실하다',
#  '살다',
#  '구입',
#  '인하다',
#  '국가',
#  '세금',
#  '빙자',
#  '강제징수',
#  '간다',
#  '굳이',
#  '살피다',
#  '요가',
#  '뺏다',
#  '가버리다',
#  'ㅜㅜ',
#  '주택',
#  '사형',
#  '시키다',
#  '주택',
#  '무기',
#  '때리다',
#  '고가',
#  '주택',
#  '실형',
#  '때리다',
#  '사고',
#  '어찌',
#  '정도',
#  '안되다',
#  '서울시장',
#  '사람',
#  '세배',
#  '어이',
#  '자유',
#  '시장',
#  '경제',
#  '인위',
#  '방법',
#  '누르다',
#  '억제',
#  '사고',
#  '방식',
#  '자체',
#  '박원숭',
#  '시장',
#  '해주다',
#  '서울시장',
#  '수고',
#  '많다',
#  '남다',
#  '국민',
#  '책임지다',
#  '야하다',
#  '감옥',
#  '보호',
#  '해주다',
#  '야하다',
#  '안철수',
#  '원망',
#  '스럽다',
#  '시키다',
#  '서울',
#  '시민',
#  '수준',
#  '밀다',
#  '안철수',
#  '새끼',
#  '죽이다',
#  '사람',
#  '이명박',
#  '버스',
#  '지하철',
#  '환승',
#  '제도',
#  '들어서다',
#  '지금',
#  '얼마나',
#  '편하다',
#  '다니다',
#  '청계천',
#  '복원',
#  '원숭이',
#  '도대체',
#  '생각',
#  '이런',
#  '벌어지다',
#  '설마',
#  '지랄',
#  '풍년',
#  '능력',
#  '내려오다',
#  '사유재산',
#  '세금',
#  '뜯다',
#  '당신',
#  '보태',
#  '주다',
#  '정부',
#  '끝나다',
#  '좋다',
#  '그냥',
#  '정신병원',
#  '입원',
#  '시키다',
#  '시장',
#  '선거',
#  '언제',
#  '정신',
#  '차리다',
#  '박원순',
#  '시장',
#  '정말',
#  '역사',
#  '종부세',
#  '올린다',
#  '부동산',
#  '시장',
#  '가라',
#  '앉다',
#  '세금',
#  '견디다',
#  '사람',
#  '파다',
#  '세금',
#  '여력',
#  '부자',
#  '부동산',
#  '매입',
#  '사람',
#  '여력',
#  '안되다',
#  '사람',
#  '추락',
#  '빈부격차',
#  '커지다',
#  '세금',
#  '해결',
#  '보다',
#  '단순하다',
#  '생각',
#  '커다랗다',
#  '대안',
#  '내놓다',
#  '신건',
#  '인간',
#  '넘다',
#  '살다',
#  '세금',
#  '얼마나',
#  '내다',
#  '시민단체',
#  '활동',
#  '구라',
#  '공갈',
#  '협박',
#  '살다',
#  '도독',
#  '심보',
#  '구먼',
#  '이제',
#  '아웃',
#  '서울시장',
#  '월급',
#  '세금',
#  '지금',
#  '세배',
#  '올리다',
#  '야하다',
#  '이명박',
#  '집값',
#  '한번',
#  '잡다',
#  '버리다',
#  '부동산',
#  '안정',
#  '덕분',
#  '싸다',
#  '집산',
#  '사람',
#  '많다',
#  '정부',
#  '부동산',
#  '부풀리다',
#  '세금',
#  '뜯다',
#  '생각',
#  '원숭',
#  '나랏일',
#  '감정',
#  '안되다',
#  '나이',
#  '먹다',
#  '평생',
#  '자녀',
#  '뒷바라지',
#  '이제',
#  '전부',
#  '연금',
#  '많다',
#  '소득',
#  '사람',
#  '죄인',
#  '누가',
#  '집값',
#  '올리다',
#  '달래다',
#  '갖다',
#  '살아오다',
#  '갑자기',
#  '집값',
#  '오르다',
#  '죄인',
#  '된거',
#  '마냥',
#  '세금',
#  '왕창',
#  '뜯다',
#  '공산주의',
#  '강도',
#  '자슥',
#  '박원순',
#  '받다',
#  '이상',
#  '그이',
#  '전라도',
#  '빼다',
#  '총선',
#  '더불다',
#  '정의당',
#  'OUT',
#  '등신',
#  '아침',
#  '무어',
#  '씨부리다',
#  '평생',
#  '지다',
#  '쌈짓돈',
#  '처럼',
#  '쓸다',
#  '박원숭',
#  '새끼',
#  '기생',
#  '세로',
#  '월급',
#  '차압',
#  '시장',
#  '관사',
#  '없애다',
#  '사다',
#  '국민',
#  '세금',
#  '아깝다',
#  '아웃',
#  '세금',
#  '걷다',
#  '목적',
#  '이군',
#  '박원순',
#  '협찬',
#  '인생',
#  '살다',
#  '소리',
#  '사라',
#  '인간',
#  '너희',
#  '숨쉬다',
#  '외다',
#  '것말',
#  '사라',
#  '재산',
#  '몰수',
#  '민노총',
#  '주다',
#  '박원순',
#  '공산주의',
#  '빨갱이',
#  '어쩔',
#  '엠벼헐',
#  '사람',
#  '세금',
#  '걷다',
#  '생각',
#  '알다',
#  '차다',
#  '실감',
#  '유세',
#  '올리다',
#  '한다는',
#  '종부세',
#  '강화',
#  '지지',
#  '을해',
#  '벌다',
#  '아파트',
#  '가지',
#  '달다',
#  '생각',
#  '야하다',
#  '맞다',
#  '유세',
#  '높이다',
#  '야하다',
#  '부동산',
#  '투기',
#  '잡다',
#  '출산율',
#  '기업',
#  '투자',
#  '경제',
#  '사다',
#  '주택',
#  '종부세',
#  '가중',
#  '부담',
#  '가즈',
#  '박원숭',
#  '구속',
#  '사하라',
#  '인간',
#  '지다',
#  '일찍이',
#  '써다',
#  '두다',
#  '보다',
#  '누구',
#  '비리',
#  '쩔다',
#  '양반',
#  '하나',
#  '모르다',
#  '세금',
#  '올리다',
#  '전세',
#  '월세',
#  '올리다',
#  '서민',
#  '죽다',
#  '풍선',
#  '효과',
#  '원숭',
#  '가라',
#  '미치다',
#  '찬성',
#  '유세',
#  '아깝다',
#  '팔고',
#  '싸다',
#  '가다',
#  '파다',
#  '아깝다',
#  '누가',
#  '비싸다',
#  '사래',
#  '너무하다',
#  'ㅠㅠㅠ',
#  '국민',
#  '거지',
#  '만들다',
#  '작정',
#  '작자',
#  '수도',
#  '서울',
#  '찍다',
#  '손가락',
#  '제발',
#  '보이다',
#  '원수',
#  '맞다',
#  '소리',
#  '작다',
#  '덩이',
#  '큰집',
#  '살리다',
#  '그만하다',
#  '대가',
#  '치르다',
#  '선거',
#  '얻다',
#  '굽신대다',
#  '들이다',
#  '자리',
#  '차지',
#  '국민',
#  '주무르다',
#  '드니',
#  '공산당',
#  '싫다',
#  '헐다',
#  '강남',
#  '서초',
#  '잠실',
#  '분당',
#  '수도권',
#  '근거리',
#  '회사',
#  '밀집',
#  '구역',
#  '몽창',
#  '짓다',
#  '쉽다',
#  '놔두다',
#  '세금',
#  '받다',
#  '정권',
#  '넘기다',
#  '튀다',
#  '궁리',
#  '사람',
#  '구역',
#  '오다',
#  '압구',
#  '모르다',
#  '진심',
#  '어보',
#  '싶다',
#  '진짜',
#  '우동',
#  '사리',
#  '들다',
#  '공급',
#  '부족하다',
#  '확실하다',
#  '올리다',
#  '원숭',
#  '돌리지',
#  '아들',
#  '병역',
#  '미필',
#  '해외',
#  '도피',
#  '들어오다',
#  '고해',
#  '올리다',
#  '일조',
#  '사람',
#  '지금',
#  '소리',
#  '넘다',
#  '치다',
#  '도르다',
#  '이제',
#  '지다',
#  '끝나다',
#  '인심',
#  '쓰다',
#  '폭탄',
#  '시장',
#  '넘겨주다',
#  '지다',
#  '청와대',
#  '가다',
#  '싶다',
#  '얘기',
#  '위선',
#  '기회',
#  '주의자',
#  '문제',
#  '하나',
#  '질리다',
#  '겪다',
#  '맞다',
#  '서울시장',
#  '무언가',
#  '혼자',
#  '자화자찬',
#  '과거',
#  '낙천',
#  '낙선',
#  '윤동',
#  '시민단체',
#  '대표',
#  '정치',
#  '늘다',
#  '질문',
#  '서울시장',
#  '번하다',
#  '국가',
#  '운영',
#  '대통령',
#  '설치다',
#  '나중',
#  '대통령',
#  '후보',
#  '나서다',
#  '자기',
#  '손바닥',
#  '뒤지다',
#  '궁금하다',
#  '수십억',
#  '주택',
#  '들이다',
#  '세금',
#  '백만원',
#  '꿈쩍',
#  '아예',
#  '주택',
#  '투기',
#  '불가능하다',
#  '정책',
#  '내놓다',
#  '공유',
#  '활용',
#  '필요하다',
#  '사람',
#  ...]

# %% [markdown]
# ## 단어 등장 빈도 Counting

# %%
word_counted = Counter(word_cleaned)
word_dic = dict(word_counted)
        
sorted_word = sorted(word_dic.items(), key=lambda x:x[1], reverse=True)

# 빈도 순으로 상위 100개에 해당하는 단어까지만 추려내기
top100_words= sorted_word[:100] 
type(top100_words)

# dict type으로 저장
top100_words_dic = dict(top100_words)

# %%
# print(top100_words_dic)
# top100_words_dic
# Out:
# {'세금': 588, '부동산': 464, '사람': 333, '정책': 300, '집값': 291, '올리다': 270, '국민': 244, '서울': 242, '시장': 239, '정부': 231, '살다': 221, '보다': 206, '정권': 199, '주택': 197, '종부세': 186, '투기': 178, '생각': 177, '지다': 176, '박원순': 167, '믿다': 154, '오르다': 152, '아파트': 145, '들다': 143, '잡다': 140, '나라': 138, '내다': 138, '가다': 131, '시키다': 131, '만들다': 130, '유세': 128, '원숭이': 120, '공급': 113, '폭등': 111, '하나': 110, '서울시장': 110, '들이다': 106, '그냥': 105, '시민': 103, '인간': 101, '쓰다': 100, '국가': 100, '알다': 96, '걷다': 95, '주다': 95, '모르다': 91, '이상': 90, '야하다': 89, '경제': 89, '문재인': 89, '대출': 88, '신뢰': 88, '넘다': 87, '나오다': 87, '뽑다': 85, '누가': 84, '치다': 83, '진짜': 82, '무슨': 80, '좋다': 80, '강남': 80, '많다': 78, '전세': 78, '받다': 76, '이제': 74, '사회주의': 72, '서민': 72, '안되다': 71, '때문': 70, '사다': 69, '가격': 69, '맞다': 69, '먹다': 68, '규제': 68, '때리다': 68, '미치다': 68, '문제': 66, '아들': 64, '정말': 64, '부자': 64, '지금': 61, '대통령': 61, '떨어지다': 60, '공산주의': 60, '소리': 59, '서울시': 58, '자다': 58, '수준': 56, '거래': 56, '진보': 56, '인상': 52, '해주다': 52, '죽다': 52, '싶다': 52, '정치': 51, '전라도': 51, '그리고': 50, '뜯다': 50, '해보다': 50, '좌파': 49, '새끼': 48}
# {'세금': 588,
#  '부동산': 464,
#  '사람': 333,
#  '정책': 300,
#  '집값': 291,
#  '올리다': 270,
#  '국민': 244,
#  '서울': 242,
#  '시장': 239,
#  '정부': 231,
#  '살다': 221,
#  '보다': 206,
#  '정권': 199,
#  '주택': 197,
#  '종부세': 186,
#  '투기': 178,
#  '생각': 177,
#  '지다': 176,
#  '박원순': 167,
#  '믿다': 154,
#  '오르다': 152,
#  '아파트': 145,
#  '들다': 143,
#  '잡다': 140,
#  '나라': 138,
#  '내다': 138,
#  '가다': 131,
#  '시키다': 131,
#  '만들다': 130,
#  '유세': 128,
#  '원숭이': 120,
#  '공급': 113,
#  '폭등': 111,
#  '하나': 110,
#  '서울시장': 110,
#  '들이다': 106,
#  '그냥': 105,
#  '시민': 103,
#  '인간': 101,
#  '쓰다': 100,
#  '국가': 100,
#  '알다': 96,
#  '걷다': 95,
#  '주다': 95,
#  '모르다': 91,
#  '이상': 90,
#  '야하다': 89,
#  '경제': 89,
#  '문재인': 89,
#  '대출': 88,
#  '신뢰': 88,
#  '넘다': 87,
#  '나오다': 87,
#  '뽑다': 85,
#  '누가': 84,
#  '치다': 83,
#  '진짜': 82,
#  '무슨': 80,
#  '좋다': 80,
#  '강남': 80,
#  '많다': 78,
#  '전세': 78,
#  '받다': 76,
#  '이제': 74,
#  '사회주의': 72,
#  '서민': 72,
#  '안되다': 71,
#  '때문': 70,
#  '사다': 69,
#  '가격': 69,
#  '맞다': 69,
#  '먹다': 68,
#  '규제': 68,
#  '때리다': 68,
#  '미치다': 68,
#  '문제': 66,
#  '아들': 64,
#  '정말': 64,
#  '부자': 64,
#  '지금': 61,
#  '대통령': 61,
#  '떨어지다': 60,
#  '공산주의': 60,
#  '소리': 59,
#  '서울시': 58,
#  '자다': 58,
#  '수준': 56,
#  '거래': 56,
#  '진보': 56,
#  '인상': 52,
#  '해주다': 52,
#  '죽다': 52,
#  '싶다': 52,
#  '정치': 51,
#  '전라도': 51,
#  '그리고': 50,
#  '뜯다': 50,
#  '해보다': 50,
#  '좌파': 49,
#  '새끼': 48}

# %% [markdown]
# ## WordCloud 만들기

# %%
#워드 클라우드
# WordCloud 패키지를 import 합니다.
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# from wordcloud import ImageColorGenerator # Image 로부터 Color 를 생성(Generate)해내는 객체입니다.

# coloring = np.array(Image.open("./yellow-house.png"))
image_colors = ImageColorGenerator(coloring)

word_cloud = WordCloud(font_path="fonts/malgun.ttf", 
                       width=2000, height=1000,  
                       mask=coloring, 
                       background_color='white').generate_from_frequencies(top100_words_dic)

plt.figure(figsize=(15,15))
plt.imshow(word_cloud) 
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
word_cloud.to_file("word_cloud_coloring.png")
